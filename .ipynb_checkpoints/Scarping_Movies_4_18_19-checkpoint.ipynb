# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import matplotlib
import matplotlib.pyplot as plt

# %%
urls = ['https://www.the-numbers.com/movie/budgets/all', 'https://www.the-numbers.com/movie/budgets/all/101',
      'https://www.the-numbers.com/movie/budgets/all/201', 'https://www.the-numbers.com/movie/budgets/all/301',
      'https://www.the-numbers.com/movie/budgets/all/401', 'https://www.the-numbers.com/movie/budgets/all/501',
       'https://www.the-numbers.com/movie/budgets/all/601', 'https://www.the-numbers.com/movie/budgets/all/701',
       'https://www.the-numbers.com/movie/budgets/all/801', 'https://www.the-numbers.com/movie/budgets/all/901',
       'https://www.the-numbers.com/movie/budgets/all/1001', 'https://www.the-numbers.com/movie/budgets/all/1101',
       'https://www.the-numbers.com/movie/budgets/all/1201', 'https://www.the-numbers.com/movie/budgets/all/1301',
       'https://www.the-numbers.com/movie/budgets/all/1401', 'https://www.the-numbers.com/movie/budgets/all/1501',
        'https://www.the-numbers.com/movie/budgets/all/1601', 'https://www.the-numbers.com/movie/budgets/all/1701',
        'https://www.the-numbers.com/movie/budgets/all/1801', 'https://www.the-numbers.com/movie/budgets/all/1901',
        'https://www.the-numbers.com/movie/budgets/all/2001', 'https://www.the-numbers.com/movie/budgets/all/2101',
        'https://www.the-numbers.com/movie/budgets/all/2201', 'https://www.the-numbers.com/movie/budgets/all/2301',
        'https://www.the-numbers.com/movie/budgets/all/2401', 'https://www.the-numbers.com/movie/budgets/all/2501',
        'https://www.the-numbers.com/movie/budgets/all/2601', 'https://www.the-numbers.com/movie/budgets/all/2701',
        'https://www.the-numbers.com/movie/budgets/all/2801', 'https://www.the-numbers.com/movie/budgets/all/2901',
        'https://www.the-numbers.com/movie/budgets/all/3001', 'https://www.the-numbers.com/movie/budgets/all/3101',
        'https://www.the-numbers.com/movie/budgets/all/3201', 'https://www.the-numbers.com/movie/budgets/all/3301',
        'https://www.the-numbers.com/movie/budgets/all/3401', 'https://www.the-numbers.com/movie/budgets/all/3501',
        'https://www.the-numbers.com/movie/budgets/all/3601', 'https://www.the-numbers.com/movie/budgets/all/3701',
        'https://www.the-numbers.com/movie/budgets/all/3801', 'https://www.the-numbers.com/movie/budgets/all/3901',
        'https://www.the-numbers.com/movie/budgets/all/4001', 'https://www.the-numbers.com/movie/budgets/all/4101',
        'https://www.the-numbers.com/movie/budgets/all/4201', 'https://www.the-numbers.com/movie/budgets/all/4301',
        'https://www.the-numbers.com/movie/budgets/all/4401', 'https://www.the-numbers.com/movie/budgets/all/4501',
        'https://www.the-numbers.com/movie/budgets/all/4601', 'https://www.the-numbers.com/movie/budgets/all/4701',
        'https://www.the-numbers.com/movie/budgets/all/4801', 'https://www.the-numbers.com/movie/budgets/all/4901',
        'https://www.the-numbers.com/movie/budgets/all/5001', 'https://www.the-numbers.com/movie/budgets/all/5101',
        'https://www.the-numbers.com/movie/budgets/all/5201', 'https://www.the-numbers.com/movie/budgets/all/5301',
        'https://www.the-numbers.com/movie/budgets/all/5401', 'https://www.the-numbers.com/movie/budgets/all/5501',
        'https://www.the-numbers.com/movie/budgets/all/5601', 'https://www.the-numbers.com/movie/budgets/all/5701',
        ]

raw_list = []

for url in urls:
#   print(url)
  r = requests.get(url)
  soup = BeautifulSoup(r.text)
  for x in soup.find_all('tr'):
#     print(x.get_text())
    raw_list.append(x.get_text())

data = pd.Series(raw_list)
df = data.str.split('\n', expand=True)

# %%
df.head()
# Out:
#                                                    0             1  \
# 0   Release DateMovieProduction BudgetDomestic Gr...          None
# 1                                                  1  Dec 18, 2009
# 2                                                  2  May 20, 2011
# 3                                                  3   May 1, 2015
# 4                                                  4  Dec 15, 2017
#
#                                              2             3             4  \
# 0                                         None          None          None
# 1                                       Avatar  $425,000,000  $760,507,625
# 2  Pirates of the Caribbean: On Stranger Tides  $410,600,000  $241,063,875
# 3                      Avengers: Age of Ultron  $330,600,000  $459,005,868
# 4            Star Wars Ep. VIII: The Last Jedi  $317,000,000  $620,181,382
#
#                 5     6
# 0            None  None
# 1  $2,776,345,279
# 2  $1,045,663,875
# 3  $1,403,013,963
# 4  $1,316,721,747

# %%
r = requests.get('https://www.the-numbers.com/movie/budgets/all')
soup= BeautifulSoup(r.text)

frames = pd.DataFrame()
the_list = []

for x in soup.find_all('tr'):
  the_list.append(x.get_text())

data = pd.Series(the_list)
df = data.str.split('\n', expand=True)

# %%
# download data at the end of work
from google.colab import files
df.to_csv('df.csv')
files.download('df.csv')

# %%
# upload work file
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4cef771e-efa2-4981-8774-b7901f16aefa" name="files[]" multiple disabled />
#      <output id="result-4cef771e-efa2-4981-8774-b7901f16aefa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving df (1).csv to df (1).csv

# %%
# df = pd.read_csv('df (1).csv')

# %%
df = pd.read_csv('the_numbers_2009.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                                  0          1  \
# 0           0   Release DateMovieProduction BudgetDomestic Gr...        NaN
# 1           1                                                  1  18-Dec-09
# 2           2                                                  2  20-May-11
# 3           3                                                  3   1-May-15
# 4           4                                                  4  15-Dec-17
#
#                                              2              3              4  \
# 0                                          NaN            NaN            NaN
# 1                                       Avatar  $425,000,000   $760,507,625
# 2  Pirates of the Caribbean: On Stranger Tides  $410,600,000   $241,063,875
# 3                      Avengers: Age of Ultron  $330,600,000   $459,005,868
# 4            Star Wars Ep. VIII: The Last Jedi  $317,000,000   $620,181,382
#
#                  5   6
# 0              NaN NaN
# 1  $2,776,345,279  NaN
# 2  $1,045,663,875  NaN
# 3  $1,403,013,963  NaN
# 4  $1,316,721,747  NaN

# %%
df.columns.tolist()
# Out:
# ['Unnamed: 0', '0', '1', '2', '3', '4', '5', '6']

# %%
df.shape
# Out:
# (5787, 8)

# %%
# cleaning column names, and dropping nans
df = df.drop(columns = ['Unnamed: 0', '0', '6']).drop([0]).dropna(how='all').rename(columns={'1': 'Release Date', '2':'Movie',
                                                                                        '3':'Production Budget', '4': 'Domestic Gross', '5':'Worldwide Gross'})
df.shape
# Out:
# (5729, 5)

# %%
# we lost 58 rows, which makes sense, the original list is of 5,731 movies so we lost about 2, 
# the dropped rows were mostly title rows that got caught in the webscraper

# Now we can set dtypes before describing our data
df.dtypes
# Out:
# Release Date         object
# Movie                object
# Production Budget    object
# Domestic Gross       object
# Worldwide Gross      object
# dtype: object

# %%
df.head()
# Out:
#   Release Date                                        Movie Production Budget  \
# 1    18-Dec-09                                       Avatar     $425,000,000
# 2    20-May-11  Pirates of the Caribbean: On Stranger Tides     $410,600,000
# 3     1-May-15                      Avengers: Age of Ultron     $330,600,000
# 4    15-Dec-17            Star Wars Ep. VIII: The Last Jedi     $317,000,000
# 5    18-Dec-15         Star Wars Ep. VII: The Force Awakens     $306,000,000
#
#   Domestic Gross  Worldwide Gross
# 1  $760,507,625   $2,776,345,279
# 2  $241,063,875   $1,045,663,875
# 3  $459,005,868   $1,403,013,963
# 4  $620,181,382   $1,316,721,747
# 5  $936,662,225   $2,053,311,220

# %%
df[df['Movie'] == 'Hud']
# looks like some dates are encoded indirectly
# Out:
#      Release Date Movie Production Budget Domestic Gross Worldwide Gross
# 4817    29-May-63   Hud       $2,500,000    $10,000,000     $10,000,000

# %%
# so everything is an object when we should have dates and budgets

# I'm going to replace dollars with floats now:
df[df.columns[2:]] = df[df.columns[2:]].replace('[$,]', '', regex=True).astype(float)

# and then this re-formats our floats as dollars:
pd.options.display.float_format = '${:,.2f}'.format

# and now I'll cast our dates into datetime objects
df['Release Date'] = pd.to_datetime(df['Release Date'],infer_datetime_format=True)
df['Release Date Year'] = df['Release Date'].dt.year 
df['Release Date Month'] = df['Release Date'].dt.month
df['Release Date Day'] = df['Release Date'].dt.day
df.head()
# Out:
#   Release Date                                        Movie  \
# 1   2009-12-18                                       Avatar
# 2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 3   2015-05-01                      Avengers: Age of Ultron
# 4   2017-12-15            Star Wars Ep. VIII: The Last Jedi
# 5   2015-12-18         Star Wars Ep. VII: The Force Awakens
#
#    Production Budget  Domestic Gross   Worldwide Gross  Release Date Year  \
# 1    $425,000,000.00 $760,507,625.00 $2,776,345,279.00               2009
# 2    $410,600,000.00 $241,063,875.00 $1,045,663,875.00               2011
# 3    $330,600,000.00 $459,005,868.00 $1,403,013,963.00               2015
# 4    $317,000,000.00 $620,181,382.00 $1,316,721,747.00               2017
# 5    $306,000,000.00 $936,662,225.00 $2,053,311,220.00               2015
#
#    Release Date Month  Release Date Day
# 1                  12                18
# 2                   5                20
# 3                   5                 1
# 4                  12                15
# 5                  12                18

# %%
df.dtypes
# now we have dates and numbers along with a title, time to do some exploratory stats and graphing
# Out:
# Release Date          datetime64[ns]
# Movie                         object
# Production Budget            float64
# Domestic Gross               float64
# Worldwide Gross              float64
# Release Date Year              int64
# Release Date Month             int64
# Release Date Day               int64
# dtype: object

# %%
df.describe(), df.shape
# we can see that our money format for floats is messing around with our description, but the count makes sense, no missing values.
# The mean of our production budget is much higher than our mode, so this means we have a heavy skew to the right on budgets, 
# this won't surprise us based on what we know about hollywood
# Out:
# (       Production Budget  Domestic Gross   Worldwide Gross  Release Date Year  \
#  count          $5,729.00       $5,729.00         $5,729.00          $5,729.00
#  mean      $31,428,130.83  $41,955,842.90    $91,578,296.75          $2,006.46
#  std       $41,505,954.69  $68,317,848.02   $174,939,479.15             $12.28
#  min            $1,100.00           $0.00             $0.00          $1,969.00
#  25%        $5,000,000.00   $1,436,000.00     $4,142,507.00          $2,000.00
#  50%       $17,000,000.00  $17,266,505.00    $28,012,862.00          $2,007.00
#  75%       $40,000,000.00  $52,474,616.00    $97,658,712.00          $2,013.00
#  max      $425,000,000.00 $936,662,225.00 $2,776,345,279.00          $2,068.00
#
#         Release Date Month  Release Date Day
#  count           $5,729.00         $5,729.00
#  mean                $7.06            $16.41
#  std                 $3.48             $8.80
#  min                 $1.00             $1.00
#  25%                 $4.00             $9.00
#  50%                 $7.00            $17.00
#  75%                $10.00            $24.00
#  max                $12.00            $31.00  , (5729, 8))

# %%
# However, we have some empty columns with Domestic Gross and Worldwide Gross, I think those are either errors or 
# unreleased films so I'm going to drop them

df = df[df['Domestic Gross'] != 0]

df.describe(), df.shape

# this reduces our height by 536 movies, too bad but they were probably noise
# Out:
# (       Production Budget  Domestic Gross   Worldwide Gross  Release Date Year  \
#  count          $5,193.00       $5,193.00         $5,193.00          $5,193.00
#  mean      $33,897,517.73  $46,286,351.62   $100,725,464.81          $2,005.80
#  std       $42,599,347.59  $70,346,865.13   $181,267,432.83             $12.38
#  min            $1,100.00         $388.00           $401.00          $1,969.00
#  25%        $6,500,000.00   $4,299,773.00     $8,130,727.00          $2,000.00
#  50%       $20,000,000.00  $21,995,263.00    $35,417,162.00          $2,006.00
#  75%       $44,000,000.00  $57,712,751.00   $109,253,745.00          $2,012.00
#  max      $425,000,000.00 $936,662,225.00 $2,776,345,279.00          $2,068.00
#
#         Release Date Month  Release Date Day
#  count           $5,193.00         $5,193.00
#  mean                $6.94            $16.09
#  std                 $3.42             $8.52
#  min                 $1.00             $1.00
#  25%                 $4.00             $9.00
#  50%                 $7.00            $16.00
#  75%                $10.00            $23.00
#  max                $12.00            $31.00  , (5193, 8))

# %%
# from pandas.plotting import scatter_matrix
# scatter_matrix(df, alpha=0.2, figsize=(12,12), diagonal = 'hist');

# df['Production Budget'].hist()

# %%
df.dtypes
# Out:
# Release Date          datetime64[ns]
# Movie                         object
# Production Budget            float64
# Domestic Gross               float64
# Worldwide Gross              float64
# Release Date Year              int64
# Release Date Month             int64
# Release Date Day               int64
# dtype: object

# %%
df.sample(4)
# Out:
#      Release Date                              Movie  Production Budget  \
# 4103   1988-01-15  Return of the Living Dead Part II      $6,200,000.00
# 710    2014-02-07                  The Monuments Men     $70,000,000.00
# 4898   2062-06-13                             Lolita      $2,000,000.00
# 916    2003-10-10                Intolerable Cruelty     $60,000,000.00
#
#       Domestic Gross  Worldwide Gross  Release Date Year  Release Date Month  \
# 4103   $9,205,924.00    $9,205,924.00               1988                   1
# 710   $78,031,620.00  $158,702,748.00               2014                   2
# 4898   $9,250,000.00    $9,250,000.00               2062                   6
# 916   $35,327,628.00  $121,327,628.00               2003                  10
#
#       Release Date Day
# 4103                15
# 710                  7
# 4898                13
# 916                 10

# %%
dates = matplotlib.dates.date2num(df['Release Date'])
budgets = df['Production Budget']
gross = df['Worldwide Gross']

plt.plot_date(dates, budgets, c = 'red')

# plt.scatter(df['Release Date'], df['Production Budget'], s=100, c = 'red')

# %%
df['Release Date'].describe()
# This is problematic as we see movies being released in the future, some manual checking confirms that most of these are 
# filmes were 19xx has been inputed as 20xx
# Out:
# count                    5729
# unique                   2396
# top       2015-12-31 00:00:00
# freq                       24
# first     1969-01-01 00:00:00
# last      2068-12-11 00:00:00
# Name: Release Date, dtype: object

# %%
# df[df['Release Date'].dt.year > 2019].duplicated()#unique().sum()
# looks like quite a few release dates are duplicated, this is important to keep in mind when I deal with the mis
# labeled release dates
df[df.duplicated(subset='Release Date', keep=False) == True].sort_values('Release Date')
# Out:
#      Release Date                               Movie  Production Budget  \
# 4583   1970-01-01                             M*A*S*H      $3,500,000.00
# 2443   1970-01-01                        Darling Lili     $22,000,000.00
# 3507   1970-01-01                  The Molly Maguires     $11,000,000.00
# 5225   1970-01-01      Beyond the Valley of the Dolls      $1,000,000.00
# 2324   1970-01-01                            Waterloo     $25,000,000.00
# 3356   1970-01-01                              Patton     $12,000,000.00
# 3768   1971-01-01                 Fiddler on the Roof      $9,000,000.00
# 5358   1971-01-01                          Billy Jack        $800,000.00
# 4816   1971-01-01  Escape from the Planet of the Apes      $2,500,000.00
# 4086   1971-01-01                The Andromeda Strain      $6,500,000.00
# ...           ...                                 ...                ...
# 1202   2020-12-31              Hannibal the Conqueror     $50,000,000.00
# 111    2020-12-31                         Singularity    $175,000,000.00
# 5164   2051-09-18       The Day the Earth Stood Still      $1,200,000.00
# 5018   2051-09-18            A Streetcar Named Desire      $1,800,000.00
# 4689   2061-12-19               Judgment at Nuremberg      $3,000,000.00
# 4774   2061-12-19               Pocketful of Miracles      $2,900,000.00
# 4817   2063-05-29                                 Hud      $2,500,000.00
# 2898   2063-05-29                   55 Days at Peking     $17,000,000.00
# 1345   2063-06-12                           Cleopatra     $42,000,000.00
# 4793   2063-06-12                      Donovan's Reef      $2,686,000.00
#
#       Domestic Gross  Worldwide Gross  Release Date Year  Release Date Month  \
# 4583  $81,600,000.00   $81,600,000.00               1970                   1
# 2443   $5,000,000.00    $5,000,000.00               1970                   1
# 3507   $2,200,000.00    $2,200,000.00               1970                   1
# 5225   $9,000,000.00    $9,000,000.00               1970                   1
# 2324           $0.00            $0.00               1970                   1
# 3356  $62,500,000.00   $62,500,000.00               1970                   1
# 3768  $80,500,000.00   $80,500,000.00               1971                   1
# 5358  $98,000,000.00   $98,000,000.00               1971                   1
# 4816  $12,300,000.00   $12,300,000.00               1971                   1
# 4086  $12,376,563.00   $12,376,563.00               1971                   1
# ...              ...              ...                ...                 ...
# 1202           $0.00            $0.00               2020                  12
# 111            $0.00            $0.00               2020                  12
# 5164   $3,700,000.00    $3,700,000.00               2051                   9
# 5018   $8,000,000.00    $8,000,000.00               2051                   9
# 4689  $10,000,000.00   $10,000,000.00               2061                  12
# 4774   $5,000,000.00    $5,000,000.00               2061                  12
# 4817  $10,000,000.00   $10,000,000.00               2063                   5
# 2898  $10,000,000.00   $10,000,000.00               2063                   5
# 1345  $57,000,000.00   $71,000,000.00               2063                   6
# 4793   $6,600,000.00    $6,600,000.00               2063                   6
#
#       Release Date Day
# 4583                 1
# 2443                 1
# 3507                 1
# 5225                 1
# 2324                 1
# 3356                 1
# 3768                 1
# 5358                 1
# 4816                 1
# 4086                 1
# ...                ...
# 1202                31
# 111                 31
# 5164                18
# 5018                18
# 4689                19
# 4774                19
# 4817                29
# 2898                29
# 1345                12
# 4793                12
#
# [4603 rows x 8 columns]

# %%
# so I create a mask of movies that have release dates in the future
year_mask = df[df['Release Date'].dt.year > 2019]

# Then I apply a lambda function that subtracts 100 years from these dates
year_mask['Corrected Release Date'] = year_mask['Release Date'].apply(lambda x : pd.datetime(x.year -100, x.month, x.day))

year_mask['Release Date Year'] = year_mask['Corrected Release Date'].dt.year 
year_mask['Release Date Month'] = year_mask['Corrected Release Date'].dt.month
year_mask['Release Date Day'] = year_mask['Corrected Release Date'].dt.day

# now they look about right
# year_mask.head() #year_mask['Release Date'].describe() #, year_mask.shape
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\Lenovo\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\Lenovo\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Lenovo\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
year_mask.isna().sum()
# Out:
# Release Date              0
# Movie                     0
# Production Budget         0
# Domestic Gross            0
# Worldwide Gross           0
# Release Date Year         0
# Release Date Month        0
# Release Date Day          0
# ROI                       0
# Break Even                0
# Corrected Release Date    0
# dtype: int64

# %%
# I will now replace these new values into my original datasest
# df.loc[((df['Movie'] == year_mask['Movie']) & ((df['Release Date Year']-100) == year_mask['Release Date Year'])), 'Release Date'] = year_mask['Corrected Release Date']

df.loc[(df['Movie'].isin(year_mask['Movie'])) & ((df['Release Date Year']-100).isin(year_mask['Release Date Year'])), 'Release Date'] = year_mask['Corrected Release Date']

# %%
df[df['Movie'] == 'King Kong']
# ok so the updated matching worked without killing the date of this remake, now I'll check the others
# Out:
#      Release Date      Movie  Production Budget  Domestic Gross  \
# 39     2005-12-14  King Kong     207,000,000.00  218,080,025.00
# 2371   1976-12-17  King Kong      23,000,000.00   52,614,445.00
# 5397   1933-04-07  King Kong         672,000.00   10,000,000.00
#
#       Worldwide Gross  Release Date Year  Release Date Month  \
# 39     550,517,357.00               2005                  12
# 2371    90,614,445.00               1976                  12
# 5397    10,000,650.00               2033                   4
#
#       Release Date Day   ROI  Break Even
# 39                  14  2.04       False
# 2371                17  3.43       False
# 5397                 7 16.37        True

# %%
df.isna().sum(), df.shape
# ok it looks right, now I'll reset the release date year column to get rid of the future years
df['Release Date Year'] = df['Release Date'].dt.year 
df['Release Date Year'].describe()
# and no extreme values
# Out:
# count   5,193.00
# mean    2,003.24
# std        12.49
# min     1,920.00
# 25%     1,999.00
# 50%     2,006.00
# 75%     2,011.00
# max     2,019.00
# Name: Release Date Year, dtype: float64

# %%
dates = matplotlib.dates.date2num(df['Release Date'])
budgets = df['Production Budget']
gross = df['Worldwide Gross']+df['Domestic Gross']
plt.plot_date(dates, budgets, c = 'red', alpha=1);
plt.plot_date(dates, gross, c = 'blue', alpha = 0.05);

# %%
# # cleaning budget numbers: some films that did not get an international release show up in WW gross with the same value as their
# # DG, I will filter for these and eliminate the distorionary WG value

# df[df['Worldwide Gross'] == df['Domestic Gross']]

# some research shows that while these values aren't necesarily correct, they don't necessarily overstate earnings

# df['Break Even'] = np.where(df['ROI'] >= 3.73, True, False)

# %%
# this is interesting, we can see that until the 80s, most films were not that profitable, but now there are quite
# a few movies that have gross far above their budget, this seems like a good place to start data, exploration, what are 
# the concrete numbers on film profitability
# https://io9.gizmodo.com/how-much-money-does-a-movie-need-to-make-to-be-profitab-5747305  
# https://bombreport.com/articles/when-does-a-movie-break-even-at-the-box-office/
# based on some reading, it is very hard to estimate movie profitability due to the opaque nature of studio accounting, in fact, 
# a model to perform financial analysis on box office and studio balance sheets is probably a good project down the line
# The basic metric is 2x production budget = break even, but there is some economic work on film ROI that suggests 373% ROI 
# is necessary to break even,
# so I will go with this metric: RoI = (0.55 x Box Office$ – Production Budget$) / Production Budget$ and count ROI > 3.73 as break even
# https://storyality.wordpress.com/2012/12/17/storyality-24-on-feature-films-and-roi-return-on-investment/ see more on reasoning here



df['ROI'] = (0.55* (df['Worldwide Gross'] + df['Domestic Gross'])) / df['Production Budget']

df['Break Even'] = np.where(df['ROI'] >= 3.73, True, False)

# Here I'll nail the formatting
pd.options.display.float_format = '{:,.2f}'.format

df.head().style.format({
    'Production Budget': '${:,.2f}'.format,
    'Domestic Gross': '${:,.2f}'.format,
    'Worldwide Gross': '${:,.2f}'.format,
    'ROI': '{:,.2%}'.format,
})
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Release Date</th>
#         <th class="col_heading level0 col1" >Movie</th>
#         <th class="col_heading level0 col2" >Production Budget</th>
#         <th class="col_heading level0 col3" >Domestic Gross</th>
#         <th class="col_heading level0 col4" >Worldwide Gross</th>
#         <th class="col_heading level0 col5" >Release Date Year</th>
#         <th class="col_heading level0 col6" >Release Date Month</th>
#         <th class="col_heading level0 col7" >Release Date Day</th>
#         <th class="col_heading level0 col8" >ROI</th>
#         <th class="col_heading level0 col9" >Break Even</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9level0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row0_col0" class="data row0 col0" >2009-12-18 00:00:00</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row0_col1" class="data row0 col1" >Avatar</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row0_col2" class="data row0 col2" >$425,000,000.00</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row0_col3" class="data row0 col3" >$760,507,625.00</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row0_col4" class="data row0 col4" >$2,776,345,279.00</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row0_col5" class="data row0 col5" >2009</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row0_col6" class="data row0 col6" >12</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row0_col7" class="data row0 col7" >18</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row0_col8" class="data row0 col8" >457.71%</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row0_col9" class="data row0 col9" >True</td>
#     </tr>    <tr>
#         <th id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9level0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row1_col0" class="data row1 col0" >2011-05-20 00:00:00</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row1_col1" class="data row1 col1" >Pirates of the Caribbean: On Stranger Tides</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row1_col2" class="data row1 col2" >$410,600,000.00</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row1_col3" class="data row1 col3" >$241,063,875.00</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row1_col4" class="data row1 col4" >$1,045,663,875.00</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row1_col5" class="data row1 col5" >2011</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row1_col6" class="data row1 col6" >5</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row1_col7" class="data row1 col7" >20</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row1_col8" class="data row1 col8" >172.36%</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row1_col9" class="data row1 col9" >False</td>
#     </tr>    <tr>
#         <th id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9level0_row2" class="row_heading level0 row2" >3</th>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row2_col0" class="data row2 col0" >2015-05-01 00:00:00</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row2_col1" class="data row2 col1" >Avengers: Age of Ultron</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row2_col2" class="data row2 col2" >$330,600,000.00</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row2_col3" class="data row2 col3" >$459,005,868.00</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row2_col4" class="data row2 col4" >$1,403,013,963.00</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row2_col5" class="data row2 col5" >2015</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row2_col6" class="data row2 col6" >5</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row2_col7" class="data row2 col7" >1</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row2_col8" class="data row2 col8" >309.77%</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row2_col9" class="data row2 col9" >False</td>
#     </tr>    <tr>
#         <th id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9level0_row3" class="row_heading level0 row3" >4</th>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row3_col0" class="data row3 col0" >2017-12-15 00:00:00</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row3_col1" class="data row3 col1" >Star Wars Ep. VIII: The Last Jedi</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row3_col2" class="data row3 col2" >$317,000,000.00</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row3_col3" class="data row3 col3" >$620,181,382.00</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row3_col4" class="data row3 col4" >$1,316,721,747.00</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row3_col5" class="data row3 col5" >2017</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row3_col6" class="data row3 col6" >12</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row3_col7" class="data row3 col7" >15</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row3_col8" class="data row3 col8" >336.06%</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row3_col9" class="data row3 col9" >False</td>
#     </tr>    <tr>
#         <th id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9level0_row4" class="row_heading level0 row4" >5</th>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row4_col0" class="data row4 col0" >2015-12-18 00:00:00</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row4_col1" class="data row4 col1" >Star Wars Ep. VII: The Force Awakens</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row4_col2" class="data row4 col2" >$306,000,000.00</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row4_col3" class="data row4 col3" >$936,662,225.00</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row4_col4" class="data row4 col4" >$2,053,311,220.00</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row4_col5" class="data row4 col5" >2015</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row4_col6" class="data row4 col6" >12</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row4_col7" class="data row4 col7" >18</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row4_col8" class="data row4 col8" >537.41%</td>
#         <td id="T_6150e17a_61f5_11e9_ad80_e8b1fcbff3b9row4_col9" class="data row4 col9" >True</td>
#     </tr></tbody>
# </table>

# %%
df[df['Break Even']==True].count()
# Out:
# Release Date          1190
# Movie                 1190
# Production Budget     1190
# Domestic Gross        1190
# Worldwide Gross       1190
# Release Date Year     1190
# Release Date Month    1190
# Release Date Day      1190
# ROI                   1190
# Break Even            1190
# dtype: int64

# %%
df[df['Break Even']==True].count() /df.shape[0]
# looks like about 23% of films in our list break even
# Out:
# Release Date         0.23
# Movie                0.23
# Production Budget    0.23
# Domestic Gross       0.23
# Worldwide Gross      0.23
# Release Date Year    0.23
# Release Date Month   0.23
# Release Date Day     0.23
# ROI                  0.23
# Break Even           0.23
# dtype: float64

# %%
# 23% profitability? Let's graph it by decade

# nuke the size
from pylab import rcParams
rcParams['figure.figsize'] = 19, 10


# choose a style
plt.style.use('seaborn-colorblind')

# bin our years into decades
decades = pd.cut(df['Release Date Year'], 10);

# set our crosstab equal to axis
ax = pd.crosstab(index=decades, columns=df['Break Even'],
           normalize = 'index').plot.bar();

ax.tick_params(labelrotation=70);
ax.set_ylim(0,1)
ax.set_yticklabels(labels=['0','20%','40%','60%','80%'])
ax.set_xticklabels(labels=['20s','30s', '40s', '50s', '60s', '70s', '80s', '90s', '00s', '10s'])


plt.xlabel('Holywood Decades', fontsize=10);
plt.ylabel('Percentage of Movies that Break Even', fontsize=10);
plt.title('Holywood Barely Breaking Even');
ax.legend(('Loss','Profit'));
plt.figure(figsize=(20, 15), facecolor='w', edgecolor='k');
plt.show();

# %%
df.shape
# Out:
# (5193, 10)

# %%
# Star Wars!
df[df['Movie'].str.contains('Star Wars')]
# Out:
#      Release Date                                     Movie  \
# 4      2017-12-15         Star Wars Ep. VIII: The Last Jedi
# 5      2015-12-18      Star Wars Ep. VII: The Force Awakens
# 22     2018-05-25                   Solo: A Star Wars Story
# 44     2016-12-16              Rogue One: A Star Wars Story
# 300    1999-05-19       Star Wars Ep. I: The Phantom Menace
# 301    2005-05-19    Star Wars Ep. III: Revenge of the Sith
# 302    2002-05-16    Star Wars Ep. II: Attack of the Clones
# 1777   1983-05-25      Star Wars Ep. VI: Return of the Jedi
# 2365   1980-05-21  Star Wars Ep. V: The Empire Strikes Back
# 3465   1977-05-25              Star Wars Ep. IV: A New Hope
# 3829   2008-08-15                 Star Wars: The Clone Wars
#
#       Production Budget  Domestic Gross  Worldwide Gross  Release Date Year  \
# 4        317,000,000.00  620,181,382.00 1,316,721,747.00               2017
# 5        306,000,000.00  936,662,225.00 2,053,311,220.00               2015
# 22       250,000,000.00  213,767,512.00   393,151,347.00               2018
# 44       200,000,000.00  532,177,324.00 1,049,102,856.00               2016
# 300      115,000,000.00  474,544,677.00 1,027,044,677.00               1999
# 301      115,000,000.00  380,270,577.00   848,998,877.00               2005
# 302      115,000,000.00  310,676,740.00   656,695,615.00               2002
# 1777      32,500,000.00  309,205,079.00   572,705,079.00               1983
# 2365      23,000,000.00  290,271,960.00   534,161,334.00               1980
# 3465      11,000,000.00  460,998,007.00   786,598,007.00               1977
# 3829       8,500,000.00   35,161,554.00    68,695,443.00               2008
#
#       Release Date Month  Release Date Day   ROI  Break Even
# 4                     12                15  3.36       False
# 5                     12                18  5.37        True
# 22                     5                25  1.34       False
# 44                    12                16  4.35        True
# 300                    5                19  7.18        True
# 301                    5                19  5.88        True
# 302                    5                16  4.63        True
# 1777                   5                25 14.92        True
# 2365                   5                21 19.71        True
# 3465                   5                25 62.38        True
# 3829                   8                15  6.72        True

# %%
df.sort_values(by='ROI', ascending=False).head(20)
# Out:
#      Release Date                            Movie  Production Budget  \
# 5749   1972-06-30                      Deep Throat          25,000.00
# 5494   2009-09-25              Paranormal Activity         450,000.00
# 5407   1999-07-14          The Blair Witch Project         600,000.00
# 5682   2015-07-10                      The Gallows         100,000.00
# 5778   1993-02-26                      El Mariachi           7,000.00
# 5615   1980-03-21                          Mad Max         200,000.00
# 5713   2004-05-07                    Super Size Me          65,000.00
# 5346   1942-08-13                            Bambi         858,000.00
# 5719   1995-08-09            The Brothers McMullen          50,000.00
# 5668   1974-10-18      The Texas Chainsaw Massacre         140,000.00
# 5679   1968-10-01         Night of the Living Dead         114,000.00
# 5537   1978-10-17                        Halloween         325,000.00
# 5210   1976-11-21                            Rocky       1,000,000.00
# 5786   2005-08-05                My Date With Drew           1,100.00
# 5373   1973-08-11                American Graffiti         777,000.00
# 5746   1994-10-19                           Clerks          27,000.00
# 5116   1937-12-21  Snow White and the Seven Dwarfs       1,488,000.00
# 5358   1971-01-01                       Billy Jack         800,000.00
# 5750   1997-08-01            In the Company of Men          25,000.00
# 5508   2004-06-11                Napoleon Dynamite         400,000.00
#
#       Domestic Gross  Worldwide Gross  Release Date Year  Release Date Month  \
# 5749   45,000,000.00    45,000,000.00               1972                   6
# 5494  107,918,810.00   194,183,034.00               2009                   9
# 5407  140,539,099.00   248,300,000.00               1999                   7
# 5682   22,764,410.00    41,656,474.00               2015                   7
# 5778    2,040,920.00     2,041,928.00               1993                   2
# 5615    8,750,000.00    99,750,000.00               1980                   3
# 5713   11,529,368.00    22,233,808.00               2004                   5
# 5346  102,797,000.00   268,000,000.00               1942                   8
# 5719   10,426,506.00    10,426,506.00               1995                   8
# 5668   26,572,439.00    26,572,439.00               1974                  10
# 5679   12,087,064.00    30,087,064.00               1968                  10
# 5537   47,000,000.00    70,000,000.00               1978                  10
# 5210  117,235,147.00   225,000,000.00               1976                  11
# 5786      181,041.00       181,041.00               2005                   8
# 5373  115,000,000.00   140,000,000.00               1973                   8
# 5746    3,073,428.00     3,894,240.00               1994                  10
# 5116  184,925,486.00   184,925,486.00               1937                  12
# 5358   98,000,000.00    98,000,000.00               1971                   1
# 5750    2,883,661.00     2,883,661.00               1997                   8
# 5508   44,540,956.00    46,122,713.00               2004                   6
#
#       Release Date Day      ROI  Break Even
# 5749                30 1,980.00        True
# 5494                25   369.24        True
# 5407                14   356.44        True
# 5682                10   354.31        True
# 5778                26   320.80        True
# 5615                21   298.38        True
# 5713                 7   285.69        True
# 5346                13   237.69        True
# 5719                 9   229.38        True
# 5668                18   208.78        True
# 5679                 1   203.47        True
# 5537                17   198.00        True
# 5210                21   188.23        True
# 5786                 5   181.04        True
# 5373                11   180.50        True
# 5746                19   141.93        True
# 5116                21   136.71        True
# 5358                 1   134.75        True
# 5750                 1   126.88        True
# 5508                11   124.66        True

# %%
df[df['ROI']>220].sort_values(by='ROI', ascending=False)
# Out:
#      Release Date                    Movie  Production Budget  Domestic Gross  \
# 5749   1972-06-30              Deep Throat          25,000.00   45,000,000.00
# 5494   2009-09-25      Paranormal Activity         450,000.00  107,918,810.00
# 5407   1999-07-14  The Blair Witch Project         600,000.00  140,539,099.00
# 5682   2015-07-10              The Gallows         100,000.00   22,764,410.00
# 5778   1993-02-26              El Mariachi           7,000.00    2,040,920.00
# 5615   1980-03-21                  Mad Max         200,000.00    8,750,000.00
# 5713   2004-05-07            Super Size Me          65,000.00   11,529,368.00
# 5346   1942-08-13                    Bambi         858,000.00  102,797,000.00
# 5719   1995-08-09    The Brothers McMullen          50,000.00   10,426,506.00
#
#       Worldwide Gross  Release Date Year  Release Date Month  \
# 5749    45,000,000.00               1972                   6
# 5494   194,183,034.00               2009                   9
# 5407   248,300,000.00               1999                   7
# 5682    41,656,474.00               2015                   7
# 5778     2,041,928.00               1993                   2
# 5615    99,750,000.00               1980                   3
# 5713    22,233,808.00               2004                   5
# 5346   268,000,000.00               1942                   8
# 5719    10,426,506.00               1995                   8
#
#       Release Date Day      ROI  Break Even
# 5749                30 1,980.00        True
# 5494                25   369.24        True
# 5407                14   356.44        True
# 5682                10   354.31        True
# 5778                26   320.80        True
# 5615                21   298.38        True
# 5713                 7   285.69        True
# 5346                13   237.69        True
# 5719                 9   229.38        True

# %%
import datetime as dt
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

dates = matplotlib.dates.date2num(df['Release Date'])
roi = df['ROI']

# nuke the size
from pylab import rcParams
rcParams['figure.figsize'] = 19, 10

fig, ax = plt.subplots()

ax.plot_date(dates, roi, c = 'red', alpha=1);

ax.annotate('Paranormal Activity', xy=(matplotlib.dates.date2num(df[df['Movie'] == 'Paranormal Activity']['Release Date']), 
                                       df[df['Movie'] == 'Paranormal Activity']['ROI']), xytext=(20, 50),
           textcoords='offset points', arrowprops=dict(arrowstyle='-|>'));

ax.annotate('The Blair Witch Project', xy=(matplotlib.dates.date2num(df[df['Movie'] == 'The Blair Witch Project']['Release Date']), 
                                       df[df['Movie'] == 'The Blair Witch Project']['ROI']), xytext=(20, 50),
           textcoords='offset points', arrowprops=dict(arrowstyle='-|>'));

ax.annotate('The Gallows', xy=(matplotlib.dates.date2num(df[df['Movie'] == 'The Gallows']['Release Date']), 
                                       df[df['Movie'] == 'The Gallows']['ROI']), xytext=(20, 50),
           textcoords='offset points', arrowprops=dict(arrowstyle='-|>'));

ax.annotate('El Mariachi', xy=(matplotlib.dates.date2num(df[df['Movie'] == 'El Mariachi']['Release Date']), 
                                       df[df['Movie'] == 'El Mariachi']['ROI']), xytext=(20, 50),
           textcoords='offset points', arrowprops=dict(arrowstyle='-|>'));

ax.annotate('Mad Max', xy=(matplotlib.dates.date2num(df[df['Movie'] == 'Mad Max']['Release Date']), 
                                       df[df['Movie'] == 'Mad Max']['ROI']), xytext=(20, 50),
           textcoords='offset points', arrowprops=dict(arrowstyle='-|>'));

ax.annotate('Super Size Me', xy=(matplotlib.dates.date2num(df[df['Movie'] == 'Super Size Me']['Release Date']), 
                                       df[df['Movie'] == 'Super Size Me']['ROI']), xytext=(20, 50),
           textcoords='offset points', arrowprops=dict(arrowstyle='-|>'));

ax.annotate('Bambi', xy=(matplotlib.dates.date2num(df[df['Movie'] == 'Bambi']['Release Date']), 
                                       df[df['Movie'] == 'Bambi']['ROI']), xytext=(20, 50),
           textcoords='offset points', arrowprops=dict(arrowstyle='-|>'));

ax.set_ylim(0,500)

ax.axhline(y=3.73, animated=True, label='373% ROI = Breakeven');

plt.xlabel('Years', fontsize=20);

plt.ylabel('ROI as a multiple of Production Budget', fontsize=20);
plt.title('Best Returns on Invesement in Hollywood History');


plt.show();
# plt.plot_date(dates, gross, c = 'blue', alpha = 0.05)

# It seems like ROI is pretty stable throughout time, though there are some outliers. That huge 1000x ROI? That's Deep Throat

# %%
# %%latex
#
# $$RoI = \frac{0.55 \, x \, Box  \: Office \: – \, Production \: Budget}{Production \: Budget}\\ $$
# Out:
# $$RoI = \frac{0.55 \, x \, Box  \: Office \: – \, Production \: Budget}{Production \: Budget}\\ $$

# %%
# Generate a dataframe of the largest budget films, plot it against gross first
big_spenders = df.sort_values(by='Production Budget', ascending=False).head(10)
# big_spenders.loc[big_spenders['Movie'] == 'Pirates of the Caribbean: At Worldâs End', 'Movie'] = 'Pirates of the Caribbean: At Worlds End'
big_spenders
# Out:
#    Release Date                                        Movie  \
# 1    2009-12-18                                       Avatar
# 2    2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 3    2015-05-01                      Avengers: Age of Ultron
# 4    2017-12-15            Star Wars Ep. VIII: The Last Jedi
# 5    2015-12-18         Star Wars Ep. VII: The Force Awakens
# 6    2018-04-27                       Avengers: Infinity War
# 7    2007-05-24      Pirates of the Caribbean: At Worlds End
# 8    2017-11-17                               Justice League
# 9    2015-11-06                                      Spectre
# 10   2012-07-20                        The Dark Knight Rises
#
#     Production Budget  Domestic Gross  Worldwide Gross  Release Date Year  \
# 1      425,000,000.00  760,507,625.00 2,776,345,279.00               2009
# 2      410,600,000.00  241,063,875.00 1,045,663,875.00               2011
# 3      330,600,000.00  459,005,868.00 1,403,013,963.00               2015
# 4      317,000,000.00  620,181,382.00 1,316,721,747.00               2017
# 5      306,000,000.00  936,662,225.00 2,053,311,220.00               2015
# 6      300,000,000.00  678,815,482.00 2,048,797,682.00               2018
# 7      300,000,000.00  309,420,425.00   963,420,425.00               2007
# 8      300,000,000.00  229,024,295.00   655,945,209.00               2017
# 9      300,000,000.00  200,074,175.00   879,620,923.00               2015
# 10     275,000,000.00  448,139,099.00 1,084,439,099.00               2012
#
#     Release Date Month  Release Date Day  ROI  Break Even
# 1                   12                18 4.58        True
# 2                    5                20 1.72       False
# 3                    5                 1 3.10       False
# 4                   12                15 3.36       False
# 5                   12                18 5.37        True
# 6                    4                27 5.00        True
# 7                    5                24 2.33       False
# 8                   11                17 1.62       False
# 9                   11                 6 1.98       False
# 10                   7                20 3.07       False

# %%
# nuke the size
from pylab import rcParams
rcParams['figure.figsize'] = 19, 10

fig, ax = plt.subplots()

# wrangle data
# big_dates = matplotlib.dates.date2num(big_spenders['Release Date'])
big_roi = big_spenders['ROI']
big_budget = big_spenders['Production Budget']
big_gross = big_spenders['Worldwide Gross'] + big_spenders['Domestic Gross']

# plot
ax.scatter(big_budget, big_gross, c = 'red');


# title and axis labels
plt.xlabel('Production Budget', fontsize=20);
plt.ylabel('Total Take Globally', fontsize=20);
plt.title('Biggest Hollywood Budgets vs Gross Take', fontsize=30);

# axis tick labels
ax.set_yticklabels(labels=['$1bn','$1.5bn','$2bn','$2.5bn','$3bn', '$3.5bn'])
ax.set_xticklabels(labels=['$280m', '$300m', '$320m', '$340m', '$360m', '$380m', '$400m', '$420m'])



# annotating the points
# for title in big_spenders['Movie']:
# ax.annotate('title', xy=(big_spenders[big_spenders['Movie'] == 'Avatar']['Production Budget'], (big_spenders[big_spenders['Movie'] == 'Avatar']['Worldwide Gross'] + big_spenders[big_spenders['Movie'] == 'Avatar']['Domestic Gross'])), xytext=(-30, -20), textcoords='offset points', arrowprops=dict(arrowstyle='-|>'))

for title in big_spenders['Movie']:
    ax.annotate(title, xy=(big_spenders[big_spenders['Movie'] == title]['Production Budget'], (big_spenders[big_spenders['Movie'] == title]['Worldwide Gross'] + big_spenders[big_spenders['Movie'] == title]['Domestic Gross'])), 
                xytext=(-30, 20), textcoords='offset points', arrowprops=dict(arrowstyle='-|>'))

plt.show();

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 19, 10

fig, ax = plt.subplots()

# wrangle data
# big_dates = matplotlib.dates.date2num(big_spenders['Release Date'])
# big_roi = big_spenders['ROI']
# big_budget = big_spenders['Production Budget']
# big_gross = big_spenders['Worldwide Gross'] + big_spenders['Domestic Gross']

roi = df['ROI']
pbudget = df['Production Budget']

big_roi = big_spenders['ROI']
big_budget = big_spenders['Production Budget']


# plot
ax.scatter(big_budget, big_roi, c = 'red');
ax.scatter(pbudget, roi, c = 'blue', alpha=0.3);

# title and axis labels
plt.xlabel('Production Budget', fontsize=20);
plt.ylabel('Return on Investment', fontsize=20);
plt.title('Biggest Hollywood Budgets vs ROI', fontsize=30);

plt.ylim(0,5)

# axis tick labels
# ax.set_yticklabels(labels=['$1bn','$1.5bn','$2bn','$2.5bn','$3bn', '$3.5bn'])
ax.set_xticklabels(labels=['$280m', '$300m', '$320m', '$340m', '$360m', '$380m', '$400m', '$420m'])



# annotating the points
# for title in big_spenders['Movie']:
# ax.annotate('title', xy=(big_spenders[big_spenders['Movie'] == 'Avatar']['Production Budget'], (big_spenders[big_spenders['Movie'] == 'Avatar']['Worldwide Gross'] + big_spenders[big_spenders['Movie'] == 'Avatar']['Domestic Gross'])), xytext=(-30, -20), textcoords='offset points', arrowprops=dict(arrowstyle='-|>'))

for title in big_spenders['Movie']:
    ax.annotate(title, xy=(big_spenders[big_spenders['Movie'] == title]['Production Budget'], (big_spenders[big_spenders['Movie'] == title]['ROI'])), 
                xytext=(-30, -20), textcoords='offset points', arrowprops=dict(arrowstyle='-|>'))

plt.show();

# %%
# annotating the points
for title in big_spenders['Movie']:
    ax.annotate(title, xy=(big_spenders[big_spenders['Movie'] == title]['Production Budget'], (big_spenders[big_spenders['Movie'] == title]['Worldwide Gross'] + big_spenders[big_spenders['Movie'] == title]['Domestic Gross'])), 
                xytext=(20, 50), textcoords='offset points', arrowprops=dict(arrowstyle='-|>'))

for title in big_spenders['Movie']:
    print((title))
# Out:
# Avatar
# Pirates of the Caribbean: On Stranger Tides
# Avengers: Age of Ultron
# Star Wars Ep. VIII: The Last Jedi
# Star Wars Ep. VII: The Force Awakens
# Avengers: Infinity War
# Pirates of the Caribbean: At Worldâs End
# Justice League
# Spectre
# The Dark Knight Rises

# %%
# Our first release date is 1920-0-7, which is important because this will be the start of our price adjustment for inflation
df['Release Date'].min()
# I've downloaded all urban consumers cpi from https://fred.stlouisfed.org/series/CPIAUCNS (I chose 
# this metric because it starts early enough for our dataset)
# Index 1982-1984=100, Not Seasonally Adjusted

i_df = pd.read_csv('CPIAUCNS-Copy1.csv')
i_df.dtypes, i_df.columns.tolist()
# Out:
# (DATE         object
#  CPIAUCNS    float64
#  dtype: object, ['DATE', 'CPIAUCNS'])

# %%
# and now I'll cast our dates into datetime objectsb
i_df['DATE'] = pd.to_datetime(i_df['DATE'],infer_datetime_format=True)

i_df['Release Date Year'] = i_df['DATE'].dt.year 
i_df['Release Date Month'] = i_df['DATE'].dt.month
i_df['Release Date Day'] = i_df['DATE'].dt.day

i_df.sample(10)
# i_df.isna().sum()
# Out:
#            DATE  CPIAUCNS  Release Date Year  Release Date Month  \
# 1138 2007-11-01    210.18               2007                  11
# 1052 2000-09-01    173.70               2000                   9
# 272  1935-09-01     13.70               1935                   9
# 592  1962-05-01     30.20               1962                   5
# 1255 2017-08-01    245.52               2017                   8
# 46   1916-11-01     11.50               1916                  11
# 135  1924-04-01     17.00               1924                   4
# 635  1965-12-01     31.80               1965                  12
# 557  1959-06-01     29.10               1959                   6
# 356  1942-09-01     16.50               1942                   9
#
#       Release Date Day
# 1138                 1
# 1052                 1
# 272                  1
# 592                  1
# 1255                 1
# 46                   1
# 135                  1
# 635                  1
# 557                  1
# 356                  1

# %%
# now that we have a datetime object associated with an inflation level, 
# I need to match these monthly datapoints 


df = df.merge(i_df[['Release Date Year', 'Release Date Month','CPIAUCNS']], 
              how='left', on=['Release Date Year', 'Release Date Month'])

# %%
# and rename column to price leve
# df = df.drop(columns=['CPIAUCNS_x'])
df = df.rename(columns={'CPIAUCNS':'Price Level'})
df.head()
# Out:
#   Release Date                                        Movie  \
# 0   2009-12-18                                       Avatar
# 1   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   2015-05-01                      Avengers: Age of Ultron
# 3   2017-12-15            Star Wars Ep. VIII: The Last Jedi
# 4   2015-12-18         Star Wars Ep. VII: The Force Awakens
#
#    Production Budget  Domestic Gross  Worldwide Gross  Release Date Year  \
# 0     425,000,000.00  760,507,625.00 2,776,345,279.00               2009
# 1     410,600,000.00  241,063,875.00 1,045,663,875.00               2011
# 2     330,600,000.00  459,005,868.00 1,403,013,963.00               2015
# 3     317,000,000.00  620,181,382.00 1,316,721,747.00               2017
# 4     306,000,000.00  936,662,225.00 2,053,311,220.00               2015
#
#    Release Date Month  Release Date Day  ROI  Break Even  Price Level
# 0                  12                18 3.59        True       215.95
# 1                   5                20 1.40       False       225.96
# 2                   5                 1 2.33        True       237.81
# 3                  12                15 2.28        True       246.52
# 4                  12                18 3.69        True       236.53

# %%
# I'm paranoid about data integrity so I'm going to check for Nans/weird dates, etc
# df[df['Price Level'].isna() == True]
df.isna().sum()
# Out:
# Release Date          0
# Movie                 0
# Production Budget     0
# Domestic Gross        0
# Worldwide Gross       0
# Release Date Year     0
# Release Date Month    0
# Release Date Day      0
# ROI                   0
# Break Even            0
# Price Level           0
# dtype: int64

# %%
# Now we inflation adjust our dollar amounts, per our inflation Index 1982-1984=100, Not Seasonally Adjusted
# I'm going to inflatoin adjust our dollar amounts
# IA - inflation adjusted

df['IA Production Budget'] = df['Production Budget'] * (df['Price Level'] / 100)
df['IA Domestic Gross'] = df['Domestic Gross'] * (df['Price Level'] / 100)
df['IA Worldwide Gross'] = df['Worldwide Gross'] * (df['Price Level'] / 100)

df['IA ROI'] = (0.55* (df['IA Worldwide Gross'] + df['IA Domestic Gross'])) / df['IA Production Budget']
df['IA Break Even'] = np.where(df['IA ROI'] >= 3.73, True, False)

# %%
# I wonder if this IA ROI was a waste of time, I'm going to see if there any IA Break Even != Break Even 
df[df['IA Break Even'] != df['Break Even']]
# nope, none
# Out:
# Empty DataFrame
# Columns: [Release Date, Movie, Production Budget, Domestic Gross, Worldwide Gross, Release Date Year, Release Date Month, Release Date Day, ROI, Break Even, Price Level, IA Production Budget, IA Domestic Gross, IA Worldwide Gross, IA ROI, IA Break Even]
# Index: []

# %%
dates = matplotlib.dates.date2num(df['Release Date'])
budgets = df['Production Budget']
# gross = df['Worldwide Gross']
IPB = df['IA Production Budget']
plt.plot_date(dates, IPB, c = 'red', alpha=1);
plt.plot_date(dates, budgets, c = 'blue', alpha=0.1);
plt.title('Inflation Adjusted Production Budgets vs Nominal')
# Out:
# Text(0.5,1,'Inflation Adjusted Production Budgets vs Nominal')

# %%
df = df.sort_values(by=['Release Date Year', 'Release Date Month', 'Release Date Day'])

df['Nominal Gross'] = (df['Worldwide Gross'] + df['Domestic Gross'])
df['IA Gross'] = (df['IA Worldwide Gross'] + df['IA Domestic Gross'])

df['Nominal Gross'].describe()
# Out:
# count           5,193.00
# mean      147,011,816.43
# std       248,419,090.77
# min               802.00
# 25%        13,783,510.00
# 50%        58,767,436.00
# 75%       168,333,436.00
# max     3,536,852,904.00
# Name: Nominal Gross, dtype: float64

# %%
# set data

dates = matplotlib.dates.date2num(df['Release Date'])
gross = (df['Worldwide Gross'] + df['Domestic Gross'])
IAG = (df['IA Worldwide Gross'] + df['IA Domestic Gross'])
inflation = df['Price Level']

with plt.xkcd():
    
    ylabels = gross
    
    fig, ax1 =plt.subplots()
    color = 'tab:red'
    ax1.set_xlabel('Year')
    ax1.set_ylabel('Billions of USD', color=color)
    ax1.yaxis.set_major_locator(plt.MaxNLocator(5))
    ax1.set_ylim(bottom=0, top = 6500000000)
#     ax1.set_yticklabels()
#     ax1.tick_params(axis='y', which='both', labelleft=True)
    
    ax1.plot_date(dates, IAG, c = 'red', alpha=1);
    ax1.plot_date(dates, gross, c = 'blue', alpha=0.4);

    ax2 = ax1.twinx()
    color2 = 'tab:blue'
    ax2.plot_date(dates, inflation, linestyle='solid', marker=None, c=color2)
    ax2.tick_params(axis='y', labelcolor=color2)
    ax2.set_ylabel('Inflation over Time', color=color2)


    # Title
    plt.title('Inflation Adjusted Worldwide Gross vs Nominal')
    plt.legend()
    fig.tight_layout()
    plt.show()
