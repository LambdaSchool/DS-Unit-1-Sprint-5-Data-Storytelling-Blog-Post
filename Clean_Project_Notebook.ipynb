# %% [markdown]
# <a href="https://colab.research.google.com/github/DylanGraves/DS-Unit-1-Sprint-5-Data-Storytelling-Blog-Post/blob/master/Clean_Project_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Inital imports, etc.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import io

from IPython.display import display

pd.options.display.max_columns = None
pd.options.display.max_rows = 200
pd.set_option('display.max_colwidth', -1)

from google.colab import files

# %%
# !pip install seaborn --upgrade
# Out:
# Requirement already up-to-date: seaborn in /usr/local/lib/python3.6/dist-packages (0.9.0)
# ...

# %%
import seaborn as sns
sns.__version__
# Out:
# '0.9.0'

# %% [markdown]
# ## Data.

# %% [markdown]
# World Bank Suicide data:

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c94a315b-e10e-4687-b811-5cc621ae72f8" name="files[]" multiple disabled />
#      <output id="result-c94a315b-e10e-4687-b811-5cc621ae72f8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving API_SH.STA.SUIC.P5_DS2_en_csv_v2_10517940.csv to API_SH.STA.SUIC.P5_DS2_en_csv_v2_10517940.csv

# %%
suicide = pd.read_csv(io.BytesIO(uploaded['API_SH.STA.SUIC.P5_DS2_en_csv_v2_10517940.csv']), skiprows=4)

print(suicide.shape)

suicide.head()
# Out:
# (264, 64)
#   Country Name Country Code                                   Indicator Name  \
# 0  Aruba        ABW          Suicide mortality rate (per 100,000 population)
# 1  Afghanistan  AFG          Suicide mortality rate (per 100,000 population)
# 2  Angola       AGO          Suicide mortality rate (per 100,000 population)
# 3  Albania      ALB          Suicide mortality rate (per 100,000 population)
# 4  Andorra      AND          Suicide mortality rate (per 100,000 population)
#
#    Indicator Code  1960  1961  1962  1963  1964  1965  1966  1967  1968  1969  \
# 0  SH.STA.SUIC.P5 NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  SH.STA.SUIC.P5 NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  SH.STA.SUIC.P5 NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  SH.STA.SUIC.P5 NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  SH.STA.SUIC.P5 NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# ...

# %%
suicide = suicide.drop(columns=['Indicator Code', 'Country Code', 'Unnamed: 63', '2017', '2018'])

suicide.head()
# Out:
#   Country Name                                   Indicator Name  1960  1961  \
# 0  Aruba        Suicide mortality rate (per 100,000 population) NaN   NaN
# 1  Afghanistan  Suicide mortality rate (per 100,000 population) NaN   NaN
# 2  Angola       Suicide mortality rate (per 100,000 population) NaN   NaN
# 3  Albania      Suicide mortality rate (per 100,000 population) NaN   NaN
# 4  Andorra      Suicide mortality rate (per 100,000 population) NaN   NaN
#
#    1962  1963  1964  1965  1966  1967  1968  1969  1970  1971  1972  1973  \
# 0 NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1 NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2 NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3 NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4 NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    1974  1975  1976  1977  1978  1979  1980  1981  1982  1983  1984  1985  \
# ...

# %%
suicide = suicide.rename(columns = {'Country Name': 'Country'})

suicide.head()
# Out:
#        Country                                   Indicator Name  1960  1961  \
# 0  Aruba        Suicide mortality rate (per 100,000 population) NaN   NaN
# 1  Afghanistan  Suicide mortality rate (per 100,000 population) NaN   NaN
# 2  Angola       Suicide mortality rate (per 100,000 population) NaN   NaN
# 3  Albania      Suicide mortality rate (per 100,000 population) NaN   NaN
# 4  Andorra      Suicide mortality rate (per 100,000 population) NaN   NaN
#
#    1962  1963  1964  1965  1966  1967  1968  1969  1970  1971  1972  1973  \
# 0 NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1 NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2 NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3 NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4 NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    1974  1975  1976  1977  1978  1979  1980  1981  1982  1983  1984  1985  \
# ...

# %% [markdown]
# World Happiness Report data:

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1f1d96ef-d4d1-440e-8f81-b5ac214dc2cd" name="files[]" multiple disabled />
#      <output id="result-1f1d96ef-d4d1-440e-8f81-b5ac214dc2cd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2016.csv to 2016.csv

# %%
hreport = pd.read_csv(io.BytesIO(uploaded['2016.csv']))

print(hreport.shape)

hreport.head()
# Out:
# (157, 13)
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Denmark      Western Europe  1               7.526
# 1  Switzerland  Western Europe  2               7.509
# 2  Iceland      Western Europe  3               7.501
# 3  Norway       Western Europe  4               7.498
# 4  Finland      Western Europe  5               7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0  7.460                      7.592
# 1  7.428                      7.590
# 2  7.333                      7.669
# 3  7.421                      7.575
# 4  7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0  1.44178                   1.16374  0.79504                   0.57941
# 1  1.52733                   1.14524  0.86303                   0.58557
# 2  1.42666                   1.18326  0.86733                   0.56624
# 3  1.57744                   1.12690  0.79579                   0.59609
# ...

# %% [markdown]
# Making main dataframe:

# %%
df = pd.merge(hreport, suicide, how='left', on='Country')

print(df.shape)

df.head()
# Out:
# (157, 71)
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Denmark      Western Europe  1               7.526
# 1  Switzerland  Western Europe  2               7.509
# 2  Iceland      Western Europe  3               7.501
# 3  Norway       Western Europe  4               7.498
# 4  Finland      Western Europe  5               7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0  7.460                      7.592
# 1  7.428                      7.590
# 2  7.333                      7.669
# 3  7.421                      7.575
# 4  7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0  1.44178                   1.16374  0.79504                   0.57941
# 1  1.52733                   1.14524  0.86303                   0.58557
# 2  1.42666                   1.18326  0.86733                   0.56624
# 3  1.57744                   1.12690  0.79579                   0.59609
# ...

# %%
df = df[['Country', 'Happiness Score', 'Lower Confidence Interval', 
        'Upper Confidence Interval', 'Economy (GDP per Capita)', 'Family', 
        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 
        'Generosity', 'Dystopia Residual', '2016']]

df = df.rename(columns = {'2016': 'Suicide Rate'})

print(df.shape)

df.head(200)
# Out:
# (157, 12)
#                      Country  Happiness Score  Lower Confidence Interval  \
# 0    Denmark                  7.526            7.460
# 1    Switzerland              7.509            7.428
# 2    Iceland                  7.501            7.333
# 3    Norway                   7.498            7.421
# 4    Finland                  7.413            7.351
# 5    Canada                   7.404            7.335
# 6    Netherlands              7.339            7.284
# 7    New Zealand              7.334            7.264
# 8    Australia                7.313            7.241
# 9    Sweden                   7.291            7.227
# 10   Israel                   7.267            7.199
# 11   Austria                  7.119            7.045
# 12   United States            7.104            7.020
# 13   Costa Rica               7.087            6.999
# 14   Puerto Rico              7.039            6.794
# 15   Germany                  6.994            6.930
# ...

# %%
df.iloc[[44], [11]] = 9.19 # Slovakia
df.iloc[[43], [11]] = 3.7 # Venezuela
df.iloc[[55], [11]] = 31 # Russia
df.iloc[[57], [11]] = 26.9 # South Korea
df.iloc[[74], [11]] = 12.5 # Hong Kong
df.iloc[[84], [11]] = 9.1 #Kyrgyzstan
df.iloc[[94], [11]] = 7.9 # Macedonia
df.iloc[[101], [11]] = 9.3 # Laos
df.iloc[[104], [11]] = 4.1 # Iran
df.iloc[[119], [11]] = 4 # Egypt
df.iloc[[124], [11]] = 5.7 # Kinshasa Congo
df.iloc[[126], [11]] = 5.9 # Brazzaville Congo
df.iloc[[138], [11]] = 14.5 # Ivory Coast
df.iloc[[146], [11]] = 8.5 # Yemen
df.iloc[[155], [11]] = 1.9 # Syria

# %%
df.shape
# Out:
# (157, 12)

# %%
df.tail(200)
# Out:
#                      Country  Happiness Score  Lower Confidence Interval  \
# 0    Denmark                  7.526            7.460
# 1    Switzerland              7.509            7.428
# 2    Iceland                  7.501            7.333
# 3    Norway                   7.498            7.421
# 4    Finland                  7.413            7.351
# 5    Canada                   7.404            7.335
# 6    Netherlands              7.339            7.284
# 7    New Zealand              7.334            7.264
# 8    Australia                7.313            7.241
# 9    Sweden                   7.291            7.227
# 10   Israel                   7.267            7.199
# 11   Austria                  7.119            7.045
# 12   United States            7.104            7.020
# 13   Costa Rica               7.087            6.999
# 14   Puerto Rico              7.039            6.794
# 15   Germany                  6.994            6.930
# ...

# %%
df.isna().sum()
# Out:
# Country                          0
# Happiness Score                  0
# Lower Confidence Interval        0
# Upper Confidence Interval        0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# Suicide Rate                     6
# dtype: int64

# %%
# Run this cell AFTER the cell above, because the cell above inserts numbers 
# based off of location in the dataframe.

df = df.dropna()

print(df.shape)

df.head()
# Out:
# (151, 12)
#        Country  Happiness Score  Lower Confidence Interval  \
# 0  Denmark      7.526            7.460
# 1  Switzerland  7.509            7.428
# 2  Iceland      7.501            7.333
# 3  Norway       7.498            7.421
# 4  Finland      7.413            7.351
#
#    Upper Confidence Interval  Economy (GDP per Capita)   Family  \
# 0  7.592                      1.44178                   1.16374
# 1  7.590                      1.52733                   1.14524
# 2  7.669                      1.42666                   1.18326
# 3  7.575                      1.57744                   1.12690
# 4  7.475                      1.40598                   1.13464
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  0.79504                   0.57941  0.44453
# 1  0.86303                   0.58557  0.41203
# 2  0.86733                   0.56624  0.14975
# 3  0.79579                   0.59609  0.35776
# 4  0.81091                   0.57104  0.41004
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 151 entries, 0 to 156
# Data columns (total 12 columns):
# Country                          151 non-null object
# Happiness Score                  151 non-null float64
# Lower Confidence Interval        151 non-null float64
# Upper Confidence Interval        151 non-null float64
# Economy (GDP per Capita)         151 non-null float64
# Family                           151 non-null float64
# Health (Life Expectancy)         151 non-null float64
# Freedom                          151 non-null float64
# Trust (Government Corruption)    151 non-null float64
# Generosity                       151 non-null float64
# Dystopia Residual                151 non-null float64
# Suicide Rate                     151 non-null float64
# dtypes: float64(11), object(1)
# memory usage: 15.3+ KB

# %%
sns.lmplot(x="Happiness Score", y="Suicide Rate", data=df);

# %%
sns.lmplot(x="Family", y="Suicide Rate", data=df);

# %%
sns.lmplot(x="Generosity", y="Suicide Rate", data=df);

# %%
sns.lmplot(x="Economy (GDP per Capita)", y="Suicide Rate", data=df);

# %%
sns.lmplot(x="Health (Life Expectancy)", y="Suicide Rate", data=df);

# %%
sns.lmplot(x="Freedom", y="Suicide Rate", data=df);

# %%
sns.lmplot(x="Trust (Government Corruption)", y="Suicide Rate", data=df);

# %%
sns.lmplot(x="Dystopia Residual", y="Suicide Rate", data=df);

# %% [markdown]
# **World Bank GDP per Capita data**

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-996e2175-c881-4f39-9915-d811f987fd6a" name="files[]" multiple disabled />
#      <output id="result-996e2175-c881-4f39-9915-d811f987fd6a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving API_NY.GDP.PCAP.PP.CD_DS2_en_csv_v2_10515265.csv to API_NY.GDP.PCAP.PP.CD_DS2_en_csv_v2_10515265.csv

# %%
gdp = pd.read_csv(io.BytesIO(uploaded['GDP_API_NY.GDP.PCAP.CD_DS2_en_csv_v2_10515199.csv']), skiprows=4)

print(gdp.shape)

gdp.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-ef06c23c5a41> in <module>()
# ----> 1 gdp = pd.read_csv(io.BytesIO(uploaded['GDP_API_NY.GDP.PCAP.CD_DS2_en_csv_v2_10515199.csv']), skiprows=4)
#       2
#       3 print(gdp.shape)
#       4
#       5 gdp.head()
#
# KeyError: 'GDP_API_NY.GDP.PCAP.CD_DS2_en_csv_v2_10515199.csv'

# %%
df2 = pd.merge(suicide, gdp, how='inner', on='Country Name')

print(df2.shape)

df2.head()

# %%
df2 = df2[['Country Name', 'Indicator Name_x', '2016_x', 'Indicator Name_y', '2016_y']]

print(df2.shape)

df2.head()

# %%
df2 = df2.rename(columns = {'2016_x': 'Suicide Rate',
                           '2016_y': 'GDP per Capita'})

df2.head()

# %%
df2.isna().sum()

# %%
df2.head(200)

# %%
df2 = df2.dropna()

print(df2.shape)

df2.isna().sum()

# %%
df2.head()

# %%
sns.lmplot(x="GDP per Capita", y="Suicide Rate", data=df2);

# %%
sns.relplot(x="GDP per Capita", y="Suicide Rate", alpha = 0.5, data=df2);

# %% [markdown]
# **Doing a left merge this time**

# %%
df3 = pd.merge(suicide, gdp, how='left', on='Country Name')

print(df3.shape)

df3.head()

# %%
df3.head(200)

# %% [markdown]
# **GDP per Capita PPP**

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-94e77225-c07c-4ae9-9618-fbd445875f87" name="files[]" multiple disabled />
#      <output id="result-94e77225-c07c-4ae9-9618-fbd445875f87">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving API_NY.GDP.PCAP.PP.CD_DS2_en_csv_v2_10515265.csv to API_NY.GDP.PCAP.PP.CD_DS2_en_csv_v2_10515265 (1).csv

# %%
ppp = pd.read_csv(io.BytesIO(uploaded['API_NY.GDP.PCAP.PP.CD_DS2_en_csv_v2_10515265.csv']), skiprows=4)

print(ppp.shape)

ppp.head()
# Out:
# (264, 64)
#   Country Name Country Code                                 Indicator Name  \
# 0  Aruba        ABW          GDP per capita, PPP (current international $)
# 1  Afghanistan  AFG          GDP per capita, PPP (current international $)
# 2  Angola       AGO          GDP per capita, PPP (current international $)
# 3  Albania      ALB          GDP per capita, PPP (current international $)
# 4  Andorra      AND          GDP per capita, PPP (current international $)
#
#       Indicator Code  1960  1961  1962  1963  1964  1965  1966  1967  1968  \
# 0  NY.GDP.PCAP.PP.CD NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  NY.GDP.PCAP.PP.CD NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  NY.GDP.PCAP.PP.CD NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  NY.GDP.PCAP.PP.CD NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  NY.GDP.PCAP.PP.CD NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# ...

# %%
suicide = suicide.rename(columns = {'Country': 'Country Name'})

# %%
df_ppp = pd.merge(suicide, ppp, how='inner', on='Country Name')

print(df_ppp.shape)

df_ppp.head(25)
# Out:
# (263, 122)
#               Country Name                                 Indicator Name_x  \
# 0   Aruba                   Suicide mortality rate (per 100,000 population)
# 1   Afghanistan             Suicide mortality rate (per 100,000 population)
# 2   Angola                  Suicide mortality rate (per 100,000 population)
# 3   Albania                 Suicide mortality rate (per 100,000 population)
# 4   Andorra                 Suicide mortality rate (per 100,000 population)
# 5   Arab World              Suicide mortality rate (per 100,000 population)
# 6   United Arab Emirates    Suicide mortality rate (per 100,000 population)
# 7   Argentina               Suicide mortality rate (per 100,000 population)
# 8   Armenia                 Suicide mortality rate (per 100,000 population)
# 9   American Samoa          Suicide mortality rate (per 100,000 population)
# 10  Antigua and Barbuda     Suicide mortality rate (per 100,000 population)
# ...

# %%
df_ppp = df_ppp[['Country Name', 'Indicator Name_x', '2016_x', 'Indicator Name_y', '2016_y']]

df_ppp.shape
# Out:
# (263, 5)

# %%
df_ppp.isna().sum()
# Out:
# Country Name        0
# Indicator Name_x    0
# 2016_x              35
# Indicator Name_y    0
# 2016_y              27
# dtype: int64

# %%
df_ppp = df_ppp.dropna()

print(df_ppp.shape)

df_ppp.head()
# Out:
# (221, 5)
#            Country Name                                 Indicator Name_x  \
# 1  Afghanistan           Suicide mortality rate (per 100,000 population)
# 2  Angola                Suicide mortality rate (per 100,000 population)
# 3  Albania               Suicide mortality rate (per 100,000 population)
# 5  Arab World            Suicide mortality rate (per 100,000 population)
# 6  United Arab Emirates  Suicide mortality rate (per 100,000 population)
#
#      2016_x                               Indicator Name_y        2016_y
# 1  4.700000  GDP per capita, PPP (current international $)  1934.616840
# 2  4.700000  GDP per capita, PPP (current international $)  6756.144137
# 3  6.300000  GDP per capita, PPP (current international $)  11890.500391
# 5  4.266082  GDP per capita, PPP (current international $)  16792.454918
# 6  2.800000  GDP per capita, PPP (current international $)  73017.480010

# %%
df_ppp = df_ppp.rename(columns = {'2016_x': 'Suicide Rate',
                                 '2016_y': 'GDP per Capita, PPP'})

# %%
sns.lmplot(x='GDP per Capita, PPP', y='Suicide Rate', data=df_ppp);

# GDP per Capita is a little bit more confused but there is a trend.
# So it is not totally the fault of the World Happiness Report. There does seem to be at least a slight trend of increased gdp per capita and increased suicide rates.

# %%
sns.lmplot(x='Suicide Rate', y='GDP per Capita, PPP', data=df_ppp);

# %%
df_ppp.sort_values('2016_y', ascending=False)
