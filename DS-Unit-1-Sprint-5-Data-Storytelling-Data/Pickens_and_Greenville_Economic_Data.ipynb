# %% [markdown]
# <a href="https://colab.research.google.com/github/standroidbeta/DS-Unit-1-Sprint-5-Data-Storytelling-Blog-Post/blob/master/DS-Unit-1-Sprint-5-Data-Storytelling-Data/Pickens_and_Greenville_Economic_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import bs4
import requests
import re
import json
import pandas as pd

# %%
url = 'https://api.datausa.io/api/?show=cip&sumlevel=all&geo=05000US45077'

# %%
pickens_data = requests.get(url).json()

pickens_data
# Out:
# {'data': [[4,
#    41.13,
#    21733.9,
#    277,
#    14.242,
#    16347.5,
#    294.003,
#    32.8596,
#    56.0,
#    29335.0,
#    8067.4,
#    178,
#    99,
#    10.2446,
#    0.0,
#    15247.4,
#    1.41934e-12,
#    233.642,
#    163.526,
#    29.1227,
#    40.8708,
#    8.0,
#    16.2663,
#    1.91255,
#    0.0,
#    1.51127,
#    4.56994,
#    1.1027,
#    2014,
#    '79500US4500101',
#    '01'],
#   [1,
#    47.0,
#    50421.2,
#    71,
#    0.0,
#    6.55566e-12,
#    121.153,
#    47.0,
#    None,
#    50421.2,
#    None,
#    71,
#    0,
#    0.0,
#    None,
#    6.55566e-12,
#    None,
#    121.153,
#    None,
#    40.0,
#    40.0,
#    None,
#    0.0,
#    0.0,
#    None,
#    0.592388,
#    None,
#    0.692034,
#    2014,
#    '79500US4500101',
#    '03'],
#   [1,
#    27.0,
#    24202.2,
#    73,
#    0.0,
#    3.78491e-12,
#    129.245,
#    27.0,
#    None,
#    24202.2,
#    None,
#    73,
#    0,
#    0.0,
#    None,
#    3.78491e-12,
#    None,
#    129.245,
# ...

# %%
pickens = pd.DataFrame(pickens_data['data'])

pickens.shape
# Out:
# (82, 31)

# %%
pickens.describe()
# Out:
#               0          1              2            3          4   \
# count  82.000000  82.000000      82.000000    82.000000  82.000000
# mean    7.841463  44.552329   60504.370732   741.292683   6.574121
# std    10.049838   8.077233   25958.776752   987.991347   5.311664
# min     1.000000  27.000000   14924.700000    15.000000   0.000000
# 25%     2.000000  38.383075   40859.300000   142.500000   3.273225
# 50%     4.000000  44.544800   60757.450000   358.000000   6.248385
# 75%     9.750000  49.649850   77592.575000   898.250000   8.836972
# max    52.000000  67.206800  170215.000000  4525.000000  27.179700
#
#                  5            6          7          8              9   \
# count     82.000000    82.000000  80.000000  48.000000      80.000000
# mean   20739.271951   434.614566  45.022589  41.748075   67213.696250
# std    18487.081640   336.102755   7.950535  14.429922   26391.545351
# min        0.000000    26.879500  27.000000  22.000000   14924.700000
# ...

# %%
pickens.dtypes
# Out:
# 0       int64
# 1     float64
# 2     float64
# 3       int64
# 4     float64
# 5     float64
# 6     float64
# 7     float64
# 8     float64
# 9     float64
# 10    float64
# 11      int64
# 12      int64
# 13    float64
# 14    float64
# 15    float64
# 16    float64
# 17    float64
# 18    float64
# 19    float64
# 20    float64
# 21    float64
# 22    float64
# 23    float64
# 24    float64
# 25    float64
# 26    float64
# 27    float64
# 28      int64
# 29     object
# 30     object
# dtype: object

# %%
pickens.head()
# Out:
#    0        1        2    3         4             5        6        7     8   \
# 0   4  41.1300  21733.9  277  14.24200  1.634750e+04  294.003  32.8596  56.0
# 1   1  47.0000  50421.2   71   0.00000  6.555660e-12  121.153  47.0000   NaN
# 2   1  27.0000  24202.2   73   0.00000  3.784910e-12  129.245  27.0000   NaN
# 3   5  47.3547  64823.6  561   8.84583  2.296040e+04  476.821  47.3547   NaN
# 4   2  43.1152  25886.8  217   2.12069  2.699920e+04  270.015  43.1152   NaN
#
#         9  ...   21        22       23   24        25       26        27  \
# 0  29335.0 ...  8.0  16.26630  1.91255  0.0  1.511270  4.56994  1.102700
# 1  50421.2 ...  NaN   0.00000  0.00000  NaN  0.592388      NaN  0.692034
# 2  24202.2 ...  NaN   0.00000  0.00000  NaN  0.541583      NaN  0.620465
# 3  64823.6 ...  NaN   5.48281  5.48281  NaN  0.736499      NaN  0.863539
# 4  25886.8 ...  NaN   5.30172  5.30172  NaN  8.286380      NaN  9.763220
#
#      28              29  30
# 0  2014  79500US4500101  01
# ...

# %%
pickens = pickens.rename(columns={ 0:'num_records',
  1: 'avg_age',
  2: 'avg_wage',
  3: 'num_ppl',
  4: 'avg_age_moe',
  5: 'avg_wage_moe',
  6: 'num_ppl_moe',
  7: 'avg_age_ft',
  8:'avg_age_pt',
  9: 'avg_wage_ft',
  10: 'avg_wage_pt',
  11: 'num_ppl_ft',
  12: 'num_ppl_pt',
  13: 'avg_age_ft_moe',
  14: 'avg_age_pt_moe',
  15: 'avg_wage_ft_moe',
  16: 'avg_wage_pt_moe',
  17: 'num_ppl_ft_moe',
  18: 'num_ppl_pt_moe',
  19: 'avg_hrs',
  20: 'avg_hrs_ft',
  21: 'avg_hrs_pt',
  22: 'avg_hrs_moe',
  23: 'avg_hrs_ft_moe',
  24: 'avg_hrs_pt_moe',
  25: 'num_ppl_rca',
  26: 'num_ppl_pt_rca',
  27: 'num_ppl_ft_rca',
  28: 'year',
  29: 'geo',
  30: 'cip'})

pickens.head()
# Out:
#    num_records  avg_age  avg_wage  num_ppl  avg_age_moe  avg_wage_moe  \
# 0            4  41.1300   21733.9      277     14.24200  1.634750e+04
# 1            1  47.0000   50421.2       71      0.00000  6.555660e-12
# 2            1  27.0000   24202.2       73      0.00000  3.784910e-12
# 3            5  47.3547   64823.6      561      8.84583  2.296040e+04
# 4            2  43.1152   25886.8      217      2.12069  2.699920e+04
#
#    num_ppl_moe  avg_age_ft  avg_age_pt  avg_wage_ft ...   avg_hrs_pt  \
# 0      294.003     32.8596        56.0      29335.0 ...          8.0
# 1      121.153     47.0000         NaN      50421.2 ...          NaN
# 2      129.245     27.0000         NaN      24202.2 ...          NaN
# 3      476.821     47.3547         NaN      64823.6 ...          NaN
# 4      270.015     43.1152         NaN      25886.8 ...          NaN
#
#    avg_hrs_moe  avg_hrs_ft_moe  avg_hrs_pt_moe  num_ppl_rca  num_ppl_pt_rca  \
# ...

# %%
pickens.isnull().sum()
# Out:
# num_records         0
# avg_age             0
# avg_wage            0
# num_ppl             0
# avg_age_moe         0
# avg_wage_moe        0
# num_ppl_moe         0
# avg_age_ft          2
# avg_age_pt         34
# avg_wage_ft         2
# avg_wage_pt        34
# num_ppl_ft          0
# num_ppl_pt          0
# avg_age_ft_moe      2
# avg_age_pt_moe     34
# avg_wage_ft_moe     2
# avg_wage_pt_moe    34
# num_ppl_ft_moe      2
# num_ppl_pt_moe     34
# avg_hrs             0
# avg_hrs_ft          2
# avg_hrs_pt         34
# avg_hrs_moe         0
# avg_hrs_ft_moe      2
# avg_hrs_pt_moe     34
# num_ppl_rca         0
# num_ppl_pt_rca     34
# num_ppl_ft_rca      2
# year                0
# geo                 0
# cip                 0
# dtype: int64

# %%
# 05000US45045

url2 = 'https://api.datausa.io/api/?show=cip&sumlevel=all&geo=05000US45045'

# %%
greenville_data = requests.get(url2).json()

greenville_data
# Out:
# {'data': [[54,
#    42.3202,
#    57071.8,
#    4319,
#    5.17919,
#    18012.6,
#    1392.52,
#    40.9242,
#    51.2308,
#    64474.6,
#    9820.51,
#    3734,
#    585,
#    5.64378,
#    5.55834,
#    21131.7,
#    4837.87,
#    1330.13,
#    367.352,
#    42.9599,
#    47.5929,
#    13.388,
#    3.30793,
#    2.94461,
#    7.38941,
#    0.721628,
#    0.934466,
#    0.694951,
#    2014,
#    '04000US45',
#    '01'],
#   [35,
#    40.3383,
#    56169.2,
#    3591,
#    3.92261,
#    12547.3,
#    903.315,
#    39.7787,
#    44.1569,
#    63340.2,
#    7238.03,
#    3132,
#    459,
#    4.06865,
#    11.2953,
#    13492.0,
#    3349.94,
#    901.346,
#    388.186,
#    40.3562,
#    43.743,
#    17.2462,
#    3.01032,
#    1.45479,
#    5.81595,
#    0.917552,
#    0.920381,
#    0.917135,
#    2014,
#    '04000US45',
#    '03'],
#   [31,
#    43.1677,
#    67360.8,
#    2857,
#    5.28421,
#    15213.9,
#    1004.98,
#    43.4454,
#    34.0,
#    69095.8,
#    10084.2,
# ...

# %%
greenville = pd.DataFrame(greenville_data['data'])

greenville.shape
# Out:
# (112, 31)

# %%
greenville.describe()
# Out:
#                 0           1              2              3           4   \
# count   112.000000  112.000000     112.000000     112.000000  112.000000
# mean    173.107143   43.084301   66236.784821   16815.633929    3.264664
# std     281.809256    5.203974   32477.842113   27959.845440    2.448619
# min       1.000000   26.409700   28514.300000      52.000000    0.000000
# 25%      26.250000   40.945875   47789.325000    2153.500000    1.608718
# 50%      59.500000   43.377750   61542.100000    6078.500000    2.663915
# 75%     187.750000   45.083525   76747.650000   17871.500000    3.975635
# max    1545.000000   64.000000  343588.000000  157409.000000   12.351300
#
#                   5            6           7          8              9   \
# count     112.000000   112.000000  112.000000  95.000000     112.000000
# mean    13693.146964  2039.112652   42.792701  45.107621   71772.141071
# std     15364.527765  1634.095762    5.276418   7.811780   32236.097990
# ...

# %%
greenville.dtypes
# Out:
# 0       int64
# 1     float64
# 2     float64
# 3       int64
# 4     float64
# 5     float64
# 6     float64
# 7     float64
# 8     float64
# 9     float64
# 10    float64
# 11      int64
# 12      int64
# 13    float64
# 14    float64
# 15    float64
# 16    float64
# 17    float64
# 18    float64
# 19    float64
# 20    float64
# 21    float64
# 22    float64
# 23    float64
# 24    float64
# 25    float64
# 26    float64
# 27    float64
# 28      int64
# 29     object
# 30     object
# dtype: object

# %%
greenville.head()
# Out:
#     0        1         2      3         4         5         6        7   \
# 0   54  42.3202   57071.8   4319   5.17919  18012.60  1392.520  40.9242
# 1   35  40.3383   56169.2   3591   3.92261  12547.30   903.315  39.7787
# 2   31  43.1677   67360.8   2857   5.28421  15213.90  1004.980  43.4454
# 3    6  59.0000  100432.0    451  12.35130  68815.20   315.525  59.0000
# 4  211  39.8912   61314.5  21638   1.77827   7075.85  2732.110  39.9153
#
#         8         9  ...       21       22        23       24        25  \
# 0  51.2308   64474.6 ...  13.3880  3.30793  2.944610  7.38941  0.721628
# 1  44.1569   63340.2 ...  17.2462  3.01032  1.454790  5.81595  0.917552
# 2  34.0000   69095.8 ...  16.0000  3.81057  3.703210  0.00000  0.649111
# 3      NaN  100432.0 ...      NaN  4.36543  4.365430      NaN  0.237301
# 4  39.6869   66823.9 ...  22.2555  1.33250  0.968458  2.60888  0.869948
#
#          26        27    28         29  30
# 0  0.934466  0.694951  2014  04000US45  01
# ...

# %%
greenville = greenville.rename(columns={ 0:'num_records',
  1: 'avg_age',
  2: 'avg_wage',
  3: 'num_ppl',
  4: 'avg_age_moe',
  5: 'avg_wage_moe',
  6: 'num_ppl_moe',
  7: 'avg_age_ft',
  8:'avg_age_pt',
  9: 'avg_wage_ft',
  10: 'avg_wage_pt',
  11: 'num_ppl_ft',
  12: 'num_ppl_pt',
  13: 'avg_age_ft_moe',
  14: 'avg_age_pt_moe',
  15: 'avg_wage_ft_moe',
  16: 'avg_wage_pt_moe',
  17: 'num_ppl_ft_moe',
  18: 'num_ppl_pt_moe',
  19: 'avg_hrs',
  20: 'avg_hrs_ft',
  21: 'avg_hrs_pt',
  22: 'avg_hrs_moe',
  23: 'avg_hrs_ft_moe',
  24: 'avg_hrs_pt_moe',
  25: 'num_ppl_rca',
  26: 'num_ppl_pt_rca',
  27: 'num_ppl_ft_rca',
  28: 'year',
  29: 'geo',
  30: 'cip'})

greenville.head()
# Out:
#    num_records  avg_age  avg_wage  num_ppl  avg_age_moe  avg_wage_moe  \
# 0           54  42.3202   57071.8     4319      5.17919      18012.60
# 1           35  40.3383   56169.2     3591      3.92261      12547.30
# 2           31  43.1677   67360.8     2857      5.28421      15213.90
# 3            6  59.0000  100432.0      451     12.35130      68815.20
# 4          211  39.8912   61314.5    21638      1.77827       7075.85
#
#    num_ppl_moe  avg_age_ft  avg_age_pt  avg_wage_ft ...   avg_hrs_pt  \
# 0     1392.520     40.9242     51.2308      64474.6 ...      13.3880
# 1      903.315     39.7787     44.1569      63340.2 ...      17.2462
# 2     1004.980     43.4454     34.0000      69095.8 ...      16.0000
# 3      315.525     59.0000         NaN     100432.0 ...          NaN
# 4     2732.110     39.9153     39.6869      66823.9 ...      22.2555
#
#    avg_hrs_moe  avg_hrs_ft_moe  avg_hrs_pt_moe  num_ppl_rca  num_ppl_pt_rca  \
# ...

# %%
greenville.isnull().sum()
# Out:
# num_records         0
# avg_age             0
# avg_wage            0
# num_ppl             0
# avg_age_moe         0
# avg_wage_moe        0
# num_ppl_moe         0
# avg_age_ft          0
# avg_age_pt         17
# avg_wage_ft         0
# avg_wage_pt        17
# num_ppl_ft          0
# num_ppl_pt          0
# avg_age_ft_moe      0
# avg_age_pt_moe     17
# avg_wage_ft_moe     0
# avg_wage_pt_moe    17
# num_ppl_ft_moe      0
# num_ppl_pt_moe     17
# avg_hrs             0
# avg_hrs_ft          0
# avg_hrs_pt         17
# avg_hrs_moe         0
# avg_hrs_ft_moe      0
# avg_hrs_pt_moe     17
# num_ppl_rca         0
# num_ppl_pt_rca     17
# num_ppl_ft_rca      0
# year                0
# geo                 0
# cip                 0
# dtype: int64
