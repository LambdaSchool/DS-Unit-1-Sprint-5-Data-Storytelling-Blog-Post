# %% [markdown]
# <a href="https://colab.research.google.com/github/tesseract314/DS-Unit-1-Sprint-5-Data-Storytelling-Blog-Post/blob/master/Data_Storytelling_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt

# %% [markdown]
# ### Loading Data

# %%
# S&P 500 dataset fro GitHub
url = 'https://raw.githubusercontent.com/datasets/s-and-p-500/master/data/data.csv'

# %%
# Creating dataframe
df = pd.read_csv(url)

# %%
df.head()
# Out:
#          Date  SP500  Dividend  Earnings  Consumer Price Index  \
# 0  1871-01-01   4.44      0.26       0.4                 12.46
# 1  1871-02-01   4.50      0.26       0.4                 12.84
# 2  1871-03-01   4.61      0.26       0.4                 13.03
# 3  1871-04-01   4.74      0.26       0.4                 12.56
# 4  1871-05-01   4.86      0.26       0.4                 12.27
#
#    Long Interest Rate  Real Price  Real Dividend  Real Earnings  PE10
# 0                5.32       89.00           5.21           8.02   NaN
# 1                5.32       87.53           5.06           7.78   NaN
# 2                5.33       88.36           4.98           7.67   NaN
# 3                5.33       94.29           5.17           7.96   NaN
# 4                5.33       98.93           5.29           8.14   NaN

# %% [markdown]
# ### Data Exploration

# %%
# Checking data types
df.dtypes
# Out:
# Date                     object
# SP500                   float64
# Dividend                float64
# Earnings                float64
# Consumer Price Index    float64
# Long Interest Rate      float64
# Real Price              float64
# Real Dividend           float64
# Real Earnings           float64
# PE10                    float64
# dtype: object

# %%
# Looking at stats of all float columns
df.describe()
# Out:
#              SP500     Dividend     Earnings  Consumer Price Index  \
# count  1768.000000  1767.000000  1764.000000           1768.000000
# mean    258.374570     5.636486    12.809932             57.726640
# std     514.103382     9.647723    23.854291             70.812597
# min       2.730000     0.180000     0.160000              6.280000
# 25%       7.737500     0.410000     0.540000             10.100000
# 50%      16.335000     0.830000     1.325000             18.200000
# 75%     122.525000     6.370000    13.607500             90.850000
# max    2789.800000    50.000000   109.880000            249.840000
#
#        Long Interest Rate   Real Price  Real Dividend  Real Earnings  \
# count         1768.000000  1768.000000    1767.000000    1764.000000
# mean             4.569559   508.352856      15.159377      29.856173
# std              2.289630   544.306401       8.475205      23.887573
# min              1.500000    67.630000       4.980000       4.190000
# 25%              3.290000   170.000000       8.525000      12.647500
# 50%              3.860000   253.065000      12.720000      20.445000
# 75%              5.222500   610.942500      19.260000      39.320000
# max             15.320000  2811.960000      50.060000     111.360000
#
#               PE10
# count  1648.000000
# mean     16.851450
# std       6.735498
# min       4.780000
# 25%      11.790000
# 50%      16.170000
# 75%      20.462500
# max      44.200000

# %%
# Looking at Date columns -- not currently in datetime format
df.describe(exclude=np.number)
# Out:
#               Date
# count         1768
# unique        1768
# top     1954-04-01
# freq             1

# %%
# Converting Date to datetime format
df['Date'] = pd.to_datetime(df['Date'], infer_datetime_format=True)

# %%
# Looking at new stats in dt format
df.describe(exclude=np.number)
# Out:
#                        Date
# count                  1768
# unique                 1768
# top     1887-08-01 00:00:00
# freq                      1
# first   1871-01-01 00:00:00
# last    2018-04-01 00:00:00

# %%
# How many null vaules?
df.isnull().sum()
# Out:
# Date                      0
# SP500                     0
# Dividend                  1
# Earnings                  4
# Consumer Price Index      0
# Long Interest Rate        0
# Real Price                0
# Real Dividend             1
# Real Earnings             4
# PE10                    120
# dtype: int64

# %%
# Very basic plot of SP500 data -- It doesn't tell us much
df['SP500'].plot();

# %%
# Basic plot of price-to-earning 10-year moving average
df['PE10'].plot();

# %%
# Recession start and end dates for plot and calculations

start1, end1 = dt.datetime(1873, 10, 1), dt.datetime(1879, 3, 1)
start2, end2 = dt.datetime(1882, 3, 1), dt.datetime(1885, 5, 1)
start3, end3 = dt.datetime(1887, 3, 1), dt.datetime(1888, 4, 1)
start4, end4 = dt.datetime(1890, 7, 1), dt.datetime(1891, 5, 1)
start5, end5 = dt.datetime(1893, 1, 1), dt.datetime(1894, 6, 1)
start6, end6 = dt.datetime(1895, 12, 1), dt.datetime(1897, 6, 1)
start7, end7 = dt.datetime(1899, 6, 1), dt.datetime(1900, 12, 1)
start8, end8 = dt.datetime(1902, 9, 1), dt.datetime(1904, 8, 1)
start9, end9 = dt.datetime(1907, 5, 1), dt.datetime(1908, 6, 1)
start10, end10 = dt.datetime(1910, 1, 1), dt.datetime(1912, 1, 1)
start11, end11 = dt.datetime(1913, 1, 1), dt.datetime(1914, 12, 1)
start12, end12 = dt.datetime(1918, 8, 1), dt.datetime(1919, 3, 1)
start13, end13 = dt.datetime(1920, 1, 1), dt.datetime(1921, 7, 1)
start14, end14 = dt.datetime(1923, 5, 1), dt.datetime(1924, 7, 1)
start15, end15 = dt.datetime(1926, 10, 1), dt.datetime(1927, 11, 1)
start16, end16 = dt.datetime(1929, 8, 1), dt.datetime(1933, 3, 1)
start17, end17 = dt.datetime(1937, 5, 1), dt.datetime(1938, 6, 1)
start18, end18 = dt.datetime(1945, 2, 1), dt.datetime(1945, 10, 1)
start19, end19 = dt.datetime(1948, 11, 1), dt.datetime(1949, 10, 1)
start20, end20 = dt.datetime(1953, 7, 1), dt.datetime(1954, 5, 1)
start21, end21 = dt.datetime(1957, 8, 1), dt.datetime(1958, 4, 1)
start22, end22 = dt.datetime(1960, 4, 1), dt.datetime(1961, 2, 1)
start23, end23 = dt.datetime(1969, 12, 1), dt.datetime(1970, 11, 1)
start24, end24 = dt.datetime(1973, 11, 1), dt.datetime(1975, 3, 1)
start25, end25 = dt.datetime(1980, 1, 1), dt.datetime(1980, 7, 1)
start26, end26 = dt.datetime(1981, 7, 1), dt.datetime(1982, 11, 1)
start27, end27 = dt.datetime(1990, 7, 1), dt.datetime(1991, 3, 1)
start28, end28 = dt.datetime(2001, 3, 1), dt.datetime(2001, 11, 1)
start29, end29 = dt.datetime(2007, 12, 1), dt.datetime(2009, 6, 1)

# %%
# Making function to make a new column that assigns True if in a recession at that time
test = dt.datetime(2010, 1, 3)
test2 = df.loc[0, 'Date']

def is_recession(date):
  if (date >= start1) & (date <= end1):
    return True
  elif (date >= start2) & (date <= end2):
    return True
  elif (date >= start3) & (date <= end3):
    return True
  elif (date >= start4) & (date <= end4):
    return True
  elif (date >= start5) & (date <= end5):
    return True
  elif (date >= start6) & (date <= end6):
    return True
  elif (date >= start7) & (date <= end7):
    return True
  elif (date >= start8) & (date <= end8):
    return True
  elif (date >= start9) & (date <= end9):
    return True
  elif (date >= start10) & (date <= end10):
    return True
  elif (date >= start11) & (date <= end11):
    return True
  elif (date >= start12) & (date <= end12):
    return True
  elif (date >= start13) & (date <= end13):
    return True
  elif (date >= start14) & (date <= end14):
    return True
  elif (date >= start15) & (date <= end15):
    return True
  elif (date >= start16) & (date <= end16):
    return True
  elif (date >= start17) & (date <= end17):
    return True
  elif (date >= start18) & (date <= end18):
    return True
  elif (date >= start19) & (date <= end19):
    return True
  elif (date >= start20) & (date <= end20):
    return True
  elif (date >= start21) & (date <= end21):
    return True
  elif (date >= start22) & (date <= end22):
    return True
  elif (date >= start23) & (date <= end23):
    return True
  elif (date >= start24) & (date <= end24):
    return True
  elif (date >= start25) & (date <= end25):
    return True
  elif (date >= start26) & (date <= end26):
    return True
  elif (date >= start27) & (date <= end27):
    return True
  elif (date >= start28) & (date <= end28):
    return True
  elif (date >= start29) & (date <= end29):
    return True
  else:
    return False

#is_recession(test2)

# %%
# Making new column with above function
df['Recession'] = df['Date'].apply(is_recession)

# %%
df.head()
# Out:
#         Date  SP500  Dividend  Earnings  Consumer Price Index  \
# 0 1871-01-01   4.44      0.26       0.4                 12.46
# 1 1871-02-01   4.50      0.26       0.4                 12.84
# 2 1871-03-01   4.61      0.26       0.4                 13.03
# 3 1871-04-01   4.74      0.26       0.4                 12.56
# 4 1871-05-01   4.86      0.26       0.4                 12.27
#
#    Long Interest Rate  Real Price  Real Dividend  Real Earnings  PE10  \
# 0                5.32       89.00           5.21           8.02   NaN
# 1                5.32       87.53           5.06           7.78   NaN
# 2                5.33       88.36           4.98           7.67   NaN
# 3                5.33       94.29           5.17           7.96   NaN
# 4                5.33       98.93           5.29           8.14   NaN
#
#    Recession
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False

# %%
# Economy in Recession about 30% of the time since 1873
df['Recession'].value_counts(normalize=True)
# Out:
# False    0.700792
# True     0.299208
# Name: Recession, dtype: float64

# %%
# War start and end dates for plot and calculations
# Choosing most impactful wars -- relatively high cost and casualty rates

war_start1, war_end1 = dt.datetime(1898, 4, 1), dt.datetime(1898, 8, 1) # Spanish-American War
war_start2, war_end2 = dt.datetime(1899, 2, 1), dt.datetime(1902, 6, 1) # Philippine-American War
war_start3, war_end3 = dt.datetime(1917, 4, 1), dt.datetime(1918, 11, 1) # WWI
war_start4, war_end4 = dt.datetime(1941, 12, 1), dt.datetime(1945, 8, 1) # WWII
war_start5, war_end5 = dt.datetime(1950, 6, 1), dt.datetime(1953, 7, 1) # Korean War
war_start6, war_end6 = dt.datetime(1965, 3, 1), dt.datetime(1975, 4, 1) # Vietnam War
war_start7, war_end7 = dt.datetime(2001, 7, 1), dt.datetime(2019, 2, 1) # Afghanistan War / Iraq War

# %%
# Creating function similar to the recession function above
# If during impactful war, will return True
test3 = dt.datetime(2010, 1, 3)
test4 = df.loc[0, 'Date']

def is_war(date):
  if (date >= war_start1) & (date <= war_end1):
    return True
  elif (date >= war_start2) & (date <= war_end2):
    return True
  elif (date >= war_start3) & (date <= war_end3):
    return True
  elif (date >= war_start4) & (date <= war_end4):
    return True
  elif (date >= war_start5) & (date <= war_end5):
    return True
  elif (date >= war_start6) & (date <= war_end6):
    return True
  elif (date >= war_start7) & (date <= war_end7):
    return True
  else:
    return False
  
is_war(test4) # Testing function
#test4
# Out:
# False

# %%
# Making new column with above function
df['War'] = df['Date'].apply(is_war)

# %%
df.head()
# Out:
#         Date  SP500  Dividend  Earnings  Consumer Price Index  \
# 0 1871-01-01   4.44      0.26       0.4                 12.46
# 1 1871-02-01   4.50      0.26       0.4                 12.84
# 2 1871-03-01   4.61      0.26       0.4                 13.03
# 3 1871-04-01   4.74      0.26       0.4                 12.56
# 4 1871-05-01   4.86      0.26       0.4                 12.27
#
#    Long Interest Rate  Real Price  Real Dividend  Real Earnings  PE10  \
# 0                5.32       89.00           5.21           8.02   NaN
# 1                5.32       87.53           5.06           7.78   NaN
# 2                5.33       88.36           4.98           7.67   NaN
# 3                5.33       94.29           5.17           7.96   NaN
# 4                5.33       98.93           5.29           8.14   NaN
#
#    Recession    War
# 0      False  False
# 1      False  False
# 2      False  False
# 3      False  False
# 4      False  False

# %%
# US has been in a major war about 27% of the time since 1871
df['War'].value_counts(normalize=True)
# Out:
# False    0.732466
# True     0.267534
# Name: War, dtype: float64

# %%
# Election Years

election_start1, election_end1 = dt.datetime(1872, 1, 1), dt.datetime(1872, 11, 1)
election_start2, election_end2 = dt.datetime(1876, 1, 1), dt.datetime(1876, 11, 1)
election_start3, election_end3 = dt.datetime(1880, 1, 1), dt.datetime(1880, 11, 1)
election_start4, election_end4 = dt.datetime(1884, 1, 1), dt.datetime(1884, 11, 1)
election_start5, election_end5 = dt.datetime(1888, 1, 1), dt.datetime(1888, 11, 1)
election_start6, election_end6 = dt.datetime(1892, 1, 1), dt.datetime(1892, 11, 1)
election_start7, election_end7 = dt.datetime(1896, 1, 1), dt.datetime(1896, 11, 1)
election_start8, election_end8 = dt.datetime(1900, 1, 1), dt.datetime(1900, 11, 1)
election_start9, election_end9 = dt.datetime(1904, 1, 1), dt.datetime(1904, 11, 1)
election_start10, election_end10 = dt.datetime(1908, 1, 1), dt.datetime(1908, 11, 1)
election_start11, election_end11 = dt.datetime(1912, 1, 1), dt.datetime(1912, 11, 1)
election_start12, election_end12 = dt.datetime(1916, 1, 1), dt.datetime(1916, 11, 1)
election_start13, election_end13 = dt.datetime(1920, 1, 1), dt.datetime(1920, 11, 1)
election_start14, election_end14 = dt.datetime(1924, 1, 1), dt.datetime(1924, 11, 1)
election_start15, election_end15 = dt.datetime(1928, 1, 1), dt.datetime(1928, 11, 1)
election_start16, election_end16 = dt.datetime(1932, 1, 1), dt.datetime(1932, 11, 1)
election_start17, election_end17 = dt.datetime(1936, 1, 1), dt.datetime(1936, 11, 1)
election_start18, election_end18 = dt.datetime(1940, 1, 1), dt.datetime(1940, 11, 1)
election_start19, election_end19 = dt.datetime(1944, 1, 1), dt.datetime(1944, 11, 1)
election_start20, election_end20 = dt.datetime(1948, 1, 1), dt.datetime(1948, 11, 1)
election_start21, election_end21 = dt.datetime(1952, 1, 1), dt.datetime(1952, 11, 1)
election_start22, election_end22 = dt.datetime(1956, 1, 1), dt.datetime(1956, 11, 1)
election_start23, election_end23 = dt.datetime(1960, 1, 1), dt.datetime(1960, 11, 1)
election_start24, election_end24 = dt.datetime(1964, 1, 1), dt.datetime(1964, 11, 1)
election_start25, election_end25 = dt.datetime(1968, 1, 1), dt.datetime(1968, 11, 1)
election_start26, election_end26 = dt.datetime(1972, 1, 1), dt.datetime(1972, 11, 1)
election_start27, election_end27 = dt.datetime(1976, 1, 1), dt.datetime(1976, 11, 1)
election_start28, election_end28 = dt.datetime(1980, 1, 1), dt.datetime(1980, 11, 1)
election_start29, election_end29 = dt.datetime(1984, 1, 1), dt.datetime(1984, 11, 1)
election_start30, election_end30 = dt.datetime(1988, 1, 1), dt.datetime(1988, 11, 1)
election_start31, election_end31 = dt.datetime(1992, 1, 1), dt.datetime(1992, 11, 1)
election_start32, election_end32 = dt.datetime(1996, 1, 1), dt.datetime(1996, 11, 1)
election_start33, election_end33 = dt.datetime(2000, 1, 1), dt.datetime(2000, 11, 1)
election_start34, election_end34 = dt.datetime(2004, 1, 1), dt.datetime(2004, 11, 1)
election_start35, election_end35 = dt.datetime(2008, 1, 1), dt.datetime(2008, 11, 1)
election_start36, election_end36 = dt.datetime(2012, 1, 1), dt.datetime(2012, 11, 1)
election_start37, election_end37 = dt.datetime(2016, 1, 1), dt.datetime(2016, 11, 1)

# %%
# Creating election function similar to the war and recession functions
# Will return True if time during an election
test5 = dt.datetime(2016, 1, 3)
test6 = df.loc[0, 'Date']

def is_election(date):
  if (date >= election_start1) & (date <= election_end1):
    return True
  elif (date >= election_start2) & (date <= election_end2):
    return True
  elif (date >= election_start3) & (date <= election_end3):
    return True
  elif (date >= election_start4) & (date <= election_end4):
    return True
  elif (date >= election_start5) & (date <= election_end5):
    return True
  elif (date >= election_start6) & (date <= election_end6):
    return True
  elif (date >= election_start7) & (date <= election_end7):
    return True
  elif (date >= election_start8) & (date <= election_end8):
    return True
  elif (date >= election_start9) & (date <= election_end9):
    return True
  elif (date >= election_start10) & (date <= election_end10):
    return True
  elif (date >= election_start11) & (date <= election_end11):
    return True
  elif (date >= election_start12) & (date <= election_end12):
    return True
  elif (date >= election_start13) & (date <= election_end13):
    return True
  elif (date >= election_start14) & (date <= election_end14):
    return True
  elif (date >= election_start15) & (date <= election_end15):
    return True
  elif (date >= election_start16) & (date <= election_end16):
    return True
  elif (date >= election_start17) & (date <= election_end17):
    return True
  elif (date >= election_start18) & (date <= election_end18):
    return True
  elif (date >= election_start19) & (date <= election_end19):
    return True
  elif (date >= election_start20) & (date <= election_end20):
    return True
  elif (date >= election_start21) & (date <= election_end21):
    return True
  elif (date >= election_start22) & (date <= election_end22):
    return True
  elif (date >= election_start23) & (date <= election_end23):
    return True
  elif (date >= election_start24) & (date <= election_end24):
    return True
  elif (date >= election_start25) & (date <= election_end25):
    return True
  elif (date >= election_start26) & (date <= election_end26):
    return True
  elif (date >= election_start27) & (date <= election_end27):
    return True
  elif (date >= election_start28) & (date <= election_end28):
    return True
  elif (date >= election_start29) & (date <= election_end29):
    return True
  elif (date >= election_start30) & (date <= election_end30):
    return True
  elif (date >= election_start31) & (date <= election_end31):
    return True
  elif (date >= election_start32) & (date <= election_end32):
    return True
  elif (date >= election_start33) & (date <= election_end33):
    return True
  elif (date >= election_start34) & (date <= election_end34):
    return True
  elif (date >= election_start35) & (date <= election_end35):
    return True
  elif (date >= election_start36) & (date <= election_end36):
    return True
  elif (date >= election_start37) & (date <= election_end37):
    return True
  else:
    return False

is_election(test6)
# Out:
# False

# %%
# Making column with that function
df['Election'] = df['Date'].apply(is_election)

# %%
df.head()
# Out:
#         Date  SP500  Dividend  Earnings  Consumer Price Index  \
# 0 1871-01-01   4.44      0.26       0.4                 12.46
# 1 1871-02-01   4.50      0.26       0.4                 12.84
# 2 1871-03-01   4.61      0.26       0.4                 13.03
# 3 1871-04-01   4.74      0.26       0.4                 12.56
# 4 1871-05-01   4.86      0.26       0.4                 12.27
#
#    Long Interest Rate  Real Price  Real Dividend  Real Earnings  PE10  \
# 0                5.32       89.00           5.21           8.02   NaN
# 1                5.32       87.53           5.06           7.78   NaN
# 2                5.33       88.36           4.98           7.67   NaN
# 3                5.33       94.29           5.17           7.96   NaN
# 4                5.33       98.93           5.29           8.14   NaN
#
#    Recession    War  Election
# 0      False  False     False
# 1      False  False     False
# 2      False  False     False
# 3      False  False     False
# 4      False  False     False

# %%
# The US has been in an election year about 23% of the time since 1871
# Pretty intuitive considering we have an election every 4 years
df['Election'].value_counts(normalize=True)
# Out:
# False    0.769796
# True     0.230204
# Name: Election, dtype: float64

# %%
# Setting index to Date for the plot
df = df.set_index('Date')

# %%
# Plotting recessions with grey
import matplotlib.ticker

plt.style.use('seaborn-white')

ax = df['SP500'].plot.line(color='b', linewidth=.8, logy=True, figsize=(10, 8))

plt.axvspan(start1, end1, color='grey', alpha=0.5, lw=0)
plt.axvspan(start2, end2, color='grey', alpha=0.5, lw=0)
plt.axvspan(start3, end3, color='grey', alpha=0.5, lw=0)
plt.axvspan(start4, end4, color='grey', alpha=0.5, lw=0)
plt.axvspan(start5, end5, color='grey', alpha=0.5, lw=0)
plt.axvspan(start6, end6, color='grey', alpha=0.5, lw=0)
plt.axvspan(start7, end7, color='grey', alpha=0.5, lw=0)
plt.axvspan(start8, end8, color='grey', alpha=0.5, lw=0)
plt.axvspan(start9, end9, color='grey', alpha=0.5, lw=0)
plt.axvspan(start10, end10, color='grey', alpha=0.5, lw=0)
plt.axvspan(start11, end11, color='grey', alpha=0.5, lw=0)
plt.axvspan(start12, end12, color='grey', alpha=0.5, lw=0)
plt.axvspan(start13, end13, color='grey', alpha=0.5, lw=0)
plt.axvspan(start14, end14, color='grey', alpha=0.5, lw=0)
plt.axvspan(start15, end15, color='grey', alpha=0.5, lw=0)
plt.axvspan(start16, end16, color='grey', alpha=0.5, lw=0)
plt.axvspan(start17, end17, color='grey', alpha=0.5, lw=0)
plt.axvspan(start18, end18, color='grey', alpha=0.5, lw=0)
plt.axvspan(start19, end19, color='grey', alpha=0.5, lw=0)
plt.axvspan(start20, end20, color='grey', alpha=0.5, lw=0)
plt.axvspan(start21, end21, color='grey', alpha=0.5, lw=0)
plt.axvspan(start22, end22, color='grey', alpha=0.5, lw=0)
plt.axvspan(start23, end23, color='grey', alpha=0.5, lw=0)
plt.axvspan(start24, end24, color='grey', alpha=0.5, lw=0)
plt.axvspan(start25, end25, color='grey', alpha=0.5, lw=0)
plt.axvspan(start26, end26, color='grey', alpha=0.5, lw=0)
plt.axvspan(start27, end27, color='grey', alpha=0.5, lw=0)
plt.axvspan(start28, end28, color='grey', alpha=0.5, lw=0)
plt.axvspan(start29, end29, color='grey', alpha=0.5, lw=0)


ax.set(title="The Stock Market Has Seen 29 Recessions Since 1871")

ax.set(xlabel='Date', ylabel='Price')
ax.get_yaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())

plt.legend()

ax;

# %%
# There's a recession about once every 5 years

#df = df.reset_index() # resetting index
#(df.loc[1767, 'Date'].year - df.loc[0, 'Date'].year) / 29

# %%
# Getting the returns during each recession -- changing to percent format
rec_return1 = (df.loc[end1, 'SP500'] - df.loc[start1, 'SP500']) / df.loc[start1, 'SP500'] * 100
rec_return2 = (df.loc[end2, 'SP500'] - df.loc[start2, 'SP500']) / df.loc[start2, 'SP500'] * 100
rec_return3 = (df.loc[end3, 'SP500'] - df.loc[start3, 'SP500']) / df.loc[start3, 'SP500'] * 100
rec_return4 = (df.loc[end4, 'SP500'] - df.loc[start4, 'SP500']) / df.loc[start4, 'SP500'] * 100
rec_return5 = (df.loc[end5, 'SP500'] - df.loc[start5, 'SP500']) / df.loc[start5, 'SP500'] * 100
rec_return6 = (df.loc[end6, 'SP500'] - df.loc[start6, 'SP500']) / df.loc[start6, 'SP500'] * 100
rec_return7 = (df.loc[end7, 'SP500'] - df.loc[start7, 'SP500']) / df.loc[start7, 'SP500'] * 100
rec_return8 = (df.loc[end8, 'SP500'] - df.loc[start8, 'SP500']) / df.loc[start8, 'SP500'] * 100
rec_return9 = (df.loc[end9, 'SP500'] - df.loc[start9, 'SP500']) / df.loc[start9, 'SP500'] * 100
rec_return10 = (df.loc[end10, 'SP500'] - df.loc[start10, 'SP500']) / df.loc[start10, 'SP500'] * 100
rec_return11 = (df.loc[end11, 'SP500'] - df.loc[start11, 'SP500']) / df.loc[start11, 'SP500'] * 100
rec_return12 = (df.loc[end12, 'SP500'] - df.loc[start12, 'SP500']) / df.loc[start12, 'SP500'] * 100
rec_return13 = (df.loc[end13, 'SP500'] - df.loc[start13, 'SP500']) / df.loc[start13, 'SP500'] * 100
rec_return14 = (df.loc[end14, 'SP500'] - df.loc[start14, 'SP500']) / df.loc[start14, 'SP500'] * 100
rec_return15 = (df.loc[end15, 'SP500'] - df.loc[start15, 'SP500']) / df.loc[start15, 'SP500'] * 100
rec_return16 = (df.loc[end16, 'SP500'] - df.loc[start16, 'SP500']) / df.loc[start16, 'SP500'] * 100
rec_return17 = (df.loc[end17, 'SP500'] - df.loc[start17, 'SP500']) / df.loc[start17, 'SP500'] * 100
rec_return18 = (df.loc[end18, 'SP500'] - df.loc[start18, 'SP500']) / df.loc[start18, 'SP500'] * 100
rec_return19 = (df.loc[end19, 'SP500'] - df.loc[start19, 'SP500']) / df.loc[start19, 'SP500'] * 100
rec_return20 = (df.loc[end20, 'SP500'] - df.loc[start20, 'SP500']) / df.loc[start20, 'SP500'] * 100
rec_return21 = (df.loc[end21, 'SP500'] - df.loc[start21, 'SP500']) / df.loc[start21, 'SP500'] * 100
rec_return22 = (df.loc[end22, 'SP500'] - df.loc[start22, 'SP500']) / df.loc[start22, 'SP500'] * 100
rec_return23 = (df.loc[end23, 'SP500'] - df.loc[start23, 'SP500']) / df.loc[start23, 'SP500'] * 100
rec_return24 = (df.loc[end24, 'SP500'] - df.loc[start24, 'SP500']) / df.loc[start24, 'SP500'] * 100
rec_return25 = (df.loc[end25, 'SP500'] - df.loc[start25, 'SP500']) / df.loc[start25, 'SP500'] * 100
rec_return26 = (df.loc[end26, 'SP500'] - df.loc[start26, 'SP500']) / df.loc[start26, 'SP500'] * 100
rec_return27 = (df.loc[end27, 'SP500'] - df.loc[start27, 'SP500']) / df.loc[start27, 'SP500'] * 100
rec_return28 = (df.loc[end28, 'SP500'] - df.loc[start28, 'SP500']) / df.loc[start28, 'SP500'] * 100
rec_return29 = (df.loc[end29, 'SP500'] - df.loc[start29, 'SP500']) / df.loc[start29, 'SP500'] * 100

# %%
# Making list with all recession returns
rec_returns_list = [rec_return1, rec_return2, rec_return3, rec_return4, rec_return5, rec_return6, rec_return7
                   , rec_return8, rec_return9, rec_return10, rec_return11, rec_return12, rec_return13, rec_return14
                   , rec_return15, rec_return16, rec_return17, rec_return18, rec_return19, rec_return20, rec_return21
                   , rec_return22, rec_return23, rec_return24, rec_return25, rec_return26, rec_return27, rec_return28, rec_return29]

# %%
# Making index list with names of all recession since 1871
index = ['Panic of 1873 and the Long Depression', '1882-85 recession', '1887-88 recession', '1890-91 recession',
         'Panic of 1893', 'Panic of 1896', '1899-1900 recession', '1902-04 recession', 'Panic of 1907', 'Panic of 1910-1911',
         'Recession of 1913–1914', 'Post-World War I recession', 'Depression of 1920–21', '1923-24 recession', '1926–27 recession',
         'Great Depression', 'Recession of 1937–1938', 'Recession of 1945', 'Recession of 1949', 'Recession of 1953', 'Recession of 1958',
         'Recession of 1960–61', 'Recession of 1969–70', '1973–75 recession', '1980 recession', '1981–1982 recession', 'Early 1990s Recession',
         'Early 2000s Recession', 'Great Recession 08-09']

# Making dataframe with recession returns and index names
recession_returns = pd.DataFrame(rec_returns_list, index=index)

# Replacing '0' column name with 'Returns %'
recession_returns = recession_returns.rename({0: 'Returns %'}, axis=1)
recession_returns.head()
# Out:
#                                        Returns %
# Panic of 1873 and the Long Depression -12.887828
# 1882-85 recession                     -25.259516
# 1887-88 recession                     -10.052910
# 1890-91 recession                     -10.649819
# Panic of 1893                         -22.638146

# %%
# Sorting returns in decending order
recession_returns = recession_returns.sort_values(by='Returns %')

# Making function that assigns red font to negative values and green font to positive values
def _color_red_or_green(val):
    color = 'red' if val < 0 else 'green'
    return 'color: %s' % color
  
# Applying color function to dataframe
recession_returns.style.applymap(_color_red_or_green)
# Out:
# <style  type="text/css" >
#     #T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row0_col0 {
#             color:  red;
#         }    #T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row1_col0 {
#             color:  red;
#         }    #T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row2_col0 {
#             color:  red;
#         }    #T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row3_col0 {
#             color:  red;
#         }    #T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row4_col0 {
#             color:  red;
#         }    #T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row5_col0 {
#             color:  red;
#         }    #T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row6_col0 {
#             color:  red;
#         }    #T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row7_col0 {
#             color:  red;
#         }    #T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row8_col0 {
#             color:  red;
#         }    #T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row9_col0 {
#             color:  red;
#         }    #T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row10_col0 {
#             color:  red;
#         }    #T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row11_col0 {
#             color:  red;
#         }    #T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row12_col0 {
#             color:  red;
#         }    #T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row13_col0 {
#             color:  red;
#         }    #T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row14_col0 {
#             color:  red;
#         }    #T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row15_col0 {
#             color:  red;
#         }    #T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row16_col0 {
#             color:  red;
#         }    #T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row17_col0 {
#             color:  red;
#         }    #T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row18_col0 {
#             color:  green;
#         }    #T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row19_col0 {
#             color:  green;
#         }    #T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row20_col0 {
#             color:  green;
#         }    #T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row21_col0 {
#             color:  green;
#         }    #T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row22_col0 {
#             color:  green;
#         }    #T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row23_col0 {
#             color:  green;
#         }    #T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row24_col0 {
#             color:  green;
#         }    #T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row25_col0 {
#             color:  green;
#         }    #T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row26_col0 {
#             color:  green;
#         }    #T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row27_col0 {
#             color:  green;
#         }    #T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row28_col0 {
#             color:  green;
#         }</style>
# <table id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Returns %</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002level0_row0" class="row_heading level0 row0" >Great Depression</th>
#         <td id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row0_col0" class="data row0 col0" >-79.3023</td>
#     </tr>    <tr>
#         <th id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002level0_row1" class="row_heading level0 row1" >Great Recession 08-09</th>
#         <td id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row1_col0" class="data row1 col0" >-37.3913</td>
#     </tr>    <tr>
#         <th id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002level0_row2" class="row_heading level0 row2" >Recession of 1937–1938</th>
#         <td id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row2_col0" class="data row2 col0" >-37.1692</td>
#     </tr>    <tr>
#         <th id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002level0_row3" class="row_heading level0 row3" >Depression of 1920–21</th>
#         <td id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row3_col0" class="data row3 col0" >-26.0476</td>
#     </tr>    <tr>
#         <th id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002level0_row4" class="row_heading level0 row4" >1882-85 recession</th>
#         <td id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row4_col0" class="data row4 col0" >-25.2595</td>
#     </tr>    <tr>
#         <th id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002level0_row5" class="row_heading level0 row5" >Panic of 1893</th>
#         <td id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row5_col0" class="data row5 col0" >-22.6381</td>
#     </tr>    <tr>
#         <th id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002level0_row6" class="row_heading level0 row6" >Recession of 1913–1914</th>
#         <td id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row6_col0" class="data row6 col0" >-20.9677</td>
#     </tr>    <tr>
#         <th id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002level0_row7" class="row_heading level0 row7" >1902-04 recession</th>
#         <td id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row7_col0" class="data row7 col0" >-20.791</td>
#     </tr>    <tr>
#         <th id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002level0_row8" class="row_heading level0 row8" >1973–75 recession</th>
#         <td id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row8_col0" class="data row8 col0" >-17.8627</td>
#     </tr>    <tr>
#         <th id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002level0_row9" class="row_heading level0 row9" >Panic of 1873 and the Long Depression</th>
#         <td id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row9_col0" class="data row9 col0" >-12.8878</td>
#     </tr>    <tr>
#         <th id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002level0_row10" class="row_heading level0 row10" >1890-91 recession</th>
#         <td id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row10_col0" class="data row10 col0" >-10.6498</td>
#     </tr>    <tr>
#         <th id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002level0_row11" class="row_heading level0 row11" >1887-88 recession</th>
#         <td id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row11_col0" class="data row11 col0" >-10.0529</td>
#     </tr>    <tr>
#         <th id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002level0_row12" class="row_heading level0 row12" >Panic of 1910-1911</th>
#         <td id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row12_col0" class="data row12 col0" >-9.52381</td>
#     </tr>    <tr>
#         <th id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002level0_row13" class="row_heading level0 row13" >Recession of 1958</th>
#         <td id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row13_col0" class="data row13 col0" >-7.63525</td>
#     </tr>    <tr>
#         <th id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002level0_row14" class="row_heading level0 row14" >Recession of 1969–70</th>
#         <td id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row14_col0" class="data row14 col0" >-7.49643</td>
#     </tr>    <tr>
#         <th id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002level0_row15" class="row_heading level0 row15" >Panic of 1907</th>
#         <td id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row15_col0" class="data row15 col0" >-5.67901</td>
#     </tr>    <tr>
#         <th id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002level0_row16" class="row_heading level0 row16" >Early 2000s Recession</th>
#         <td id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row16_col0" class="data row16 col0" >-4.73669</td>
#     </tr>    <tr>
#         <th id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002level0_row17" class="row_heading level0 row17" >Panic of 1896</th>
#         <td id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row17_col0" class="data row17 col0" >-1.15741</td>
#     </tr>    <tr>
#         <th id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002level0_row18" class="row_heading level0 row18" >Early 1990s Recession</th>
#         <td id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row18_col0" class="data row18 col0" >3.40249</td>
#     </tr>    <tr>
#         <th id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002level0_row19" class="row_heading level0 row19" >Recession of 1949</th>
#         <td id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002row19_col0" class="data row19 col0" >3.92413</td>
#     </tr>    <tr>
#         <th id="T_7aca3fb8_299f_11e9_bfb5_0242ac1c0002level0_row20" class="row_heading level0 row20" >1923-24 recessio

# %%
# How many recession saw positive returns compared to negative returns, and vice versa
pos_returns = recession_returns[recession_returns['Returns %'] > 0].count()
neg_returns = recession_returns[recession_returns['Returns %'] < 0].count()

print("Percent of positive returns:", pos_returns / (pos_returns + neg_returns))
print("Percent of negative returns:", neg_returns / (pos_returns + neg_returns))
# Out:
# Percent of positive returns: Returns %    0.37931
# dtype: float64
# Percent of negative returns: Returns %    0.62069
# dtype: float64

# %%
# Largest selloffs (i.e. peak to trough) -- without consideration of recessions

selloff_start1, selloff_end1 = dt.datetime(1872, 4, 1), dt.datetime(1877, 6, 1)
selloff_start2, selloff_end2 = dt.datetime(1881, 6, 1), dt.datetime(1896, 8, 1)
selloff_start3, selloff_end3 = dt.datetime(1902, 9, 1), dt.datetime(1903, 10, 1)
selloff_start4, selloff_end4 = dt.datetime(1906, 9, 1), dt.datetime(1907, 11, 1)
selloff_start5, selloff_end5 = dt.datetime(1909, 12, 1), dt.datetime(1914, 12, 1)
selloff_start6, selloff_end6 = dt.datetime(1916, 11, 1), dt.datetime(1917, 12, 1)
selloff_start7, selloff_end7 = dt.datetime(1919, 7, 1), dt.datetime(1921, 8, 1)
selloff_start8, selloff_end8 = dt.datetime(1929, 9, 1), dt.datetime(1932, 6, 1)
selloff_start9, selloff_end9 = dt.datetime(1937, 2, 1), dt.datetime(1942, 4, 1)
selloff_start10, selloff_end10 = dt.datetime(1946, 5, 1), dt.datetime(1949, 6, 1)
selloff_start11, selloff_end11 = dt.datetime(1956, 7, 1), dt.datetime(1957, 12, 1)
selloff_start12, selloff_end12 = dt.datetime(1959, 7, 1), dt.datetime(1960, 10, 1)
selloff_start13, selloff_end13 = dt.datetime(1961, 12, 1), dt.datetime(1962, 10, 1)
selloff_start14, selloff_end14 = dt.datetime(1966, 1, 1), dt.datetime(1966, 10, 1)
selloff_start15, selloff_end15 = dt.datetime(1968, 12, 1), dt.datetime(1970, 6, 1)
selloff_start16, selloff_end16 = dt.datetime(1973, 1, 1), dt.datetime(1974, 12, 1)
selloff_start17, selloff_end17 = dt.datetime(1976, 12, 1), dt.datetime(1978, 3, 1)
selloff_start18, selloff_end18 = dt.datetime(1980, 11, 1), dt.datetime(1982, 7, 1)
selloff_start19, selloff_end19 = dt.datetime(1987, 8, 1), dt.datetime(1987, 12, 1)
selloff_start20, selloff_end20 = dt.datetime(1990, 6, 1), dt.datetime(1990, 10, 1)
selloff_start21, selloff_end21 = dt.datetime(2000, 8, 1), dt.datetime(2003, 2, 1)
selloff_start22, selloff_end22 = dt.datetime(2007, 10, 1), dt.datetime(2009, 3, 1)

# %%
# Plotting largest selloffs with grey
plt.style.use('seaborn-white')

ax = df['SP500'].plot.line(color='b', linewidth=.8, figsize=(10, 8), logy=True, xlim=(dt.datetime(1871,1,1), dt.datetime(2019,1,1)))

plt.axvspan(selloff_start1, selloff_end1, color='grey', alpha=0.5, lw=0)
plt.axvspan(selloff_start2, selloff_end2, color='grey', alpha=0.5, lw=0)
plt.axvspan(selloff_start3, selloff_end3, color='grey', alpha=0.5, lw=0)
plt.axvspan(selloff_start4, selloff_end4, color='grey', alpha=0.5, lw=0)
plt.axvspan(selloff_start5, selloff_end5, color='grey', alpha=0.5, lw=0)
plt.axvspan(selloff_start6, selloff_end6, color='grey', alpha=0.5, lw=0)
plt.axvspan(selloff_start7, selloff_end7, color='grey', alpha=0.5, lw=0)
plt.axvspan(selloff_start8, selloff_end8, color='grey', alpha=0.5, lw=0)
plt.axvspan(selloff_start9, selloff_end9, color='grey', alpha=0.5, lw=0)
plt.axvspan(selloff_start10, selloff_end10, color='grey', alpha=0.5, lw=0)
plt.axvspan(selloff_start11, selloff_end11, color='grey', alpha=0.5, lw=0)
plt.axvspan(selloff_start12, selloff_end12, color='grey', alpha=0.5, lw=0)
plt.axvspan(selloff_start13, selloff_end13, color='grey', alpha=0.5, lw=0)
plt.axvspan(selloff_start14, selloff_end14, color='grey', alpha=0.5, lw=0)
plt.axvspan(selloff_start15, selloff_end15, color='grey', alpha=0.5, lw=0)
plt.axvspan(selloff_start16, selloff_end16, color='grey', alpha=0.5, lw=0)
plt.axvspan(selloff_start17, selloff_end17, color='grey', alpha=0.5, lw=0)
plt.axvspan(selloff_start18, selloff_end18, color='grey', alpha=0.5, lw=0)
plt.axvspan(selloff_start19, selloff_end19, color='grey', alpha=0.5, lw=0)
#plt.axvspan(selloff_start20, selloff_end20, color='grey', alpha=0.5, lw=0)
plt.axvspan(selloff_start21, selloff_end21, color='grey', alpha=0.5, lw=0)
plt.axvspan(selloff_start22, selloff_end22, color='grey', alpha=0.5, lw=0)



ax.set(title="Ever Major Stock Market Selloff Since 1871")

ax.set(xlabel='Date', ylabel='Price')
ax.get_yaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())

plt.legend()

ax;

# %%
# Setting max rows option to dig into data
pd.options.display.max_rows = 2000
#df

# %%
# Used the get_max_min function below to come up with these dates

# Largest selloffs -- with inflation adjusted price

selloff_start1, selloff_end1 = dt.datetime(1906, 9, 1), dt.datetime(1920, 12, 1)
selloff_start2, selloff_end2 = dt.datetime(1929, 9, 1), dt.datetime(1932, 6, 1)
selloff_start3, selloff_end3 = dt.datetime(1968, 12, 1), dt.datetime(1982, 7, 1)
selloff_start4, selloff_end4 = dt.datetime(2000, 8, 1), dt.datetime(2009, 3, 1)

# Largest 'booms' -- with inflation adjusted price

boom_start1, boom_end1 = dt.datetime(1877, 6, 1), dt.datetime(1906, 9, 1)
boom_start2, boom_end2 = dt.datetime(1920, 12, 1), dt.datetime(1929, 9, 1)
boom_start3, boom_end3 = dt.datetime(1932, 6, 1), dt.datetime(1968, 12, 1)
boom_start4, boom_end4 = dt.datetime(1982, 7, 1), dt.datetime(2000, 8, 1)

# %%
# Plotting uptrends and downtrends with above date ranges

ax1 = df['Real Price'].plot.line(color='b', linewidth=.8, figsize=(10, 8), logy=True, 
                                 xlim=(dt.datetime(1871, 1, 1), dt.datetime(2019,1,1)))

# Selloffs
plt.axvspan(selloff_start1, selloff_end1, color='r', alpha=0.4, lw=0)
plt.axvspan(selloff_start2, selloff_end2, color='r', alpha=0.4, lw=0)
plt.axvspan(selloff_start3, selloff_end3, color='r', alpha=0.4, lw=0)
plt.axvspan(selloff_start4, selloff_end4, color='r', alpha=0.4, lw=0)

# Booms
plt.axvspan(boom_start1, boom_end1, color='g', alpha=0.2, lw=0)
plt.axvspan(boom_start2, boom_end2, color='g', alpha=0.2, lw=0)
plt.axvspan(boom_start3, boom_end3, color='g', alpha=0.2, lw=0)
plt.axvspan(boom_start4, boom_end4, color='g', alpha=0.2, lw=0);

# %%
# Creating function that gets max or min value in specified range, and the row
def get_max_min(start, end, direction):

  date_range = df[(df.index > start) & (df.index < end)]
  if direction == 'min':
    max_or_min_value = date_range['Real Price'].min()
  elif direction == 'max':
    max_or_min_value = date_range['Real Price'].max()
  else:
    print("Must enter 'min' or 'max'")
  
  return df[df['Real Price'] == max_or_min_value]

get_max_min(dt.datetime(1871, 8, 1), dt.datetime(1906, 9, 1), 'min')
# Out:
#             SP500  Dividend  Earnings  Consumer Price Index  \
# Date
# 1877-06-01   2.73      0.24      0.29                 10.09
#
#             Long Interest Rate  Real Price  Real Dividend  Real Earnings  \
# Date
# 1877-06-01                 4.4       67.63           6.07           7.18
#
#             PE10  Recession    War  Election
# Date
# 1877-06-01   NaN       True  False     False

# %%
ax2 = df['Real Price'].plot.line(color='b', linewidth=.8, figsize=(10, 8), logy=True, xlim=(dt.datetime(1871, 1, 1), dt.datetime(2019,1,1)))

ax2.arrow(dt.datetime(1906, 9, 1), 292.63, 245, 0,  head_width=20, head_length=20, fc='k', ec='k', lw=1)
# 2006-10-01  26.54      False   True     False
# 2006-11-01  26.93      False   True     False
# 2006-12-01  27.28      False   True     False
# 2007-01-01  27.21      False   True     False
# 2007-02-01  27.32      False   True     False
# 2007-03-01  26.23      False   True     False
# 2007-04-01  26.98      False   True     False
# 2007-05-01  27.55      False   True     False
# 2007-06-01  27.42      False   True     False
# 2007-07-01  27.41      False   True     False
# 2007-08-01  26.15      False   True     False
# 2007-09-01  26.73      False   True     False
# 2007-10-01  27.32      False   True     False
# 2007-11-01  25.73      False   True     False
# 2007-12-01  25.96       True   True     False
# 2008-01-01  24.02       True   True      True
# 2008-02-01  23.50       True   True      True
# 2008-03-01  22.61       True   True      True
# 2008-04-01  23.36       True   True      True
# 2008-05-01  23.70       True   True      True
# 2008-06-01  22.42       True   True      True
# 2008-07-01  20.91       True   True      True
# 2008-08-01  21.40       True   True      True
# 2008-09-01  20.36       True   True      True
# 2008-10-01  16.39       True   True      True
# 2008-11-01  15.26       True   True      True
# 2008-12-01  15.38       True   True     False
# 2009-01-01  15.17       True   True     False
# 2009-02-01  14.12       True   True     False
# 2009-03-01  13.32       True   True     False
# 2009-04-01  14.98       True   True     False
# 2009-05-01  16.00       True   True     False
# 2009-06-01  16.38       True   True     False
# 2009-07-01  16.69      False   True     False
# 2009-08-01  18.09      False   True     False
# 2009-09-01  18.83      False   True     False
# 2009-10-01  19.36      False   True     False
# 2009-11-01  19.81      False   True     False
# 2009-12-01  20.32      False   True     False
# 2010-01-01  20.53      False   True     False
# 2010-02-01  19.92      False   True     False
# 2010-03-01  21.00      False   True     False
# 2010-04-01  21.80      False   True     False
# 2010-05-01  20.48      False   True     False
# 2010-06-01  19.74      False   True     False
# 2010-07-01  19.67      False   True     False
# 2010-08-01  19.77      False   True     False
# 2010-09-01  20.38      False   True     False
# 2010-10-01  21.24      False   True     False
# 2010-11-01  21.70      False   True     False
# 2010-12-01  22.40      False   True     False
# 2011-01-01  22.98      False   True     False
# 2011-02-01  23.49      False   True     False
# 2011-03-01  22.90      False   True     False
# 2011-04-01  23.14      False   True     False
# 2011-05-01  23.06      False   True     False
# 2011-06-01  22.10      False   True     False
# 2011-07-01  22.61      False   True     False
# 2011-08-01  20.05      False   True     False
# 2011-09-01  19.70      False   True     False
# 2011-10-01  20.16      False   True     False
# 2011-11-01  20.35      False   True     False
# 2011-12-01  20.52      False   True     False
# 2012-01-01  21.21      False   True      True
# 2012-02-01  21.80      False   True      True
# 2012-03-01  22.05      False   True      True
# 2012-04-01  21.78      False   True      True
# 2012-05-01  20.94      False   True      True
# 2012-06-01  20.55      False   True      True
# 2012-07-01  21.00      False   True      True
# 2012-08-01  21.41      False   True      True
# 2012-09-01  21.78      False   True      True
# 2012-10-01  21.58      False   True      True
# 2012-11-01  20.90      False   True      True
# 2012-12-01  21.24      False   True     False
# 2013-01-01  21.90      False   True     False
# 2013-02-01  22.05      False   True     False
# 2013-03-01  22.42      False   True     False
# 2013-04-01  22.60      False   True     False
# 2013-05-01  23.41      False   True     False
# 2013-06-01  22.93      False   True     False
# 2013-07-01  23.49      False   True     False
# 2013-08-01  23.36      False   True     False
# 2013-09-01  23.44      False   True     False
# 2013-10-01  23.83      False   True     False
# 2013-11-01  24.64      False   True     False
# 2013-12-01  24.86      False   True     False
# 2014-01-01  24.86      False   True     False
# 2014-02-01  24.59      False   True     False
# 2014-03-01  24.96      False   True     False
# 2014-04-01  24.79      False   True     False
# 2014-05-01  24.94      False   True     False
# 2014-06-01  25.56      False   True     False
# 2014-07-01  25.82      False   True     False
# 2014-08-01  25.62      False   True     False
# 2014-09-01  25.92      False   True     False
# 2014-10-01  25.16      False   True     False
# 2014-11-01  26.61      False   True     False
# 2014-12-01  26.79      False   True     False
# 2015-01-01  26.49      False   True     False
# 2015-02-01  27.00      False   True     False
# 2015-03-01  26.73      False   True     False
# 2015-04-01  26.79      False   True     False
# 2015-05-01  26.81      False   True     False
# 2015-06-01  26.50      False   True     False
# 2015-07-01  26.38      False   True     False
# 2015-08-01  25.69      False   True     False
# 2015-09-01  24.50      False   True     False
# 2015-10-01  25.49      False   True     False
# 2015-11-01  26.23      False   True     False
# 2015-12-01  25.97      False   True     False
# 2016-01-01  24.21      False   True      True
# 2016-02-01  24.00      False   True      True
# 2016-03-01  25.37      False   True      True
# 2016-04-01  25.92      False   True      True
# 2016-05-01  25.69      False   True      True
# 2016-06-01  25.84      False   True      True
# 2016-07-01  26.69      False   True      True
# 2016-08-01  26.95      False   True      True
# 2016-09-01  26.73      False   True      True
# 2016-10-01  26.53      False   True      True
# 2016-11-01  26.85      False   True      True
# 2016-12-01  27.87      False   True     False
# 2017-01-01  28.06      False   True     False
# 2017-02-01  28.66      False   True     False
# 2017-03-01  29.09      False   True     False
# 2017-04-01  28.90      False   True     False
# 2017-05-01  29.31      False   True     False
# 2017-06-01  29.75      False   True     False
# 2017-07-01  30.00      False   True     False
# 2017-08-01  29.91      False   True     False
# 2017-09-01  30.17      False   True     False
# 2017-10-01  30.92      False   True     False
# 2017-11-01  31.30      False   True     False
# 2017-12-01  32.09      False   True     False
# 2018-01-01  33.31      False   True     False
# 2018-02-01  32.12      False   True     False
# 2018-03-01  31.99      False   True     False
# 2018-04-01  31.19      False   True     False

# %%
# Breakeven date ranges

# be_range1 = dt.datetime(1906, 9, 1) - dt.datetime(1928, 5, 1)
# be_range2 = dt.datetime(1929, 9, 1) - dt.datetime(1958, 11, 1)
# be_range3 = dt.datetime(1968, 12, 1) -  dt.datetime(1992, 1, 1)
# be_range4 = dt.datetime(2000, 8, 1) - dt.datetime(2014, 11, 1)
# Out:
# (datetime.datetime(1906, 9, 1, 0, 0), 292.63)

# %%
df.loc[dt.datetime(1906, 9, 1), 'Real Price']
# Out:
# 292.63

# %%
# start_test = dt.datetime(1906, 9, 1)
# end_test = dt.datetime(1930, 9, 1)

# def breakeven(start_date, end_date):
#   be_value = df.loc[start_date, 'Real Price']
#   value_list = [df['Real Price']]
    
  
#   pass

#breakeven(test7)

# %% [markdown]
# ### Storytelling

# %%
df['SP500'].plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-57f0a572db31> in <module>()
# ----> 1 df['SP500'].plot()
#
# NameError: name 'df' is not defined
