# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/James/Desktop/For_Hire_Vehicles__FHV__-_Active_Drivers.csv')
df.T
# Out:
#                                                 0       \
# License Number                                  493092
# Name                                    MAIGA,BOUNAFOU
# Type                           FOR HIRE VEHICLE DRIVER
# Expiration Date                             11/24/2019
# Wheelchair Accessible Trained                      WAV
# Last Date Updated                           04/15/2019
# Last Time Updated                                13:25
#
#                                                 1       \
# License Number                                  681774
# Name                                    GNANARAJ,SINNA
# Type                           FOR HIRE VEHICLE DRIVER
# Expiration Date                             04/03/2020
# Wheelchair Accessible Trained                      WAV
# Last Date Updated                           04/15/2019
# Last Time Updated                                13:25
#
#                                                 2       \
# ...

# %%
df.shape
# Out:
# (188931, 7)

# %%
# df = df['Name'].sort_values()

# %%
# df.to_frame()
# Out:
#                                   Name
# 107335                  A  JEAN,VERLEN
# 61460                       A HANNAN,M
# 174913  A S MOHAMED JAWARD,AYAZ AHAMED
# 46939                AABIZZA,NOURDDINE
# 44504                AAFFOUTE,RADOUANE
# 52584                  AAFOUALLAH,ZIAD
# 168574                      AAKASH,FNU
# 40250                   AALAMI,MOHCINE
# 89973               AALIKAMALUDEEN,A,N
# 91733                   AALLALOU,SIMON
# 188907                      AAMAR,ADIL
# 69190                       AAMAR,ADIL
# 114690                   AAMAR,ZEESHAN
# 182311                   AAMER,ZOUHAIR
# 53374                   AAMIR,MUHAMMAD
# 85485                 AANOUZ,ABDELHADI
# 153343                  AANOUZ,MOHAMED
# 100376                    AAOUINE,SAID
# 61483                    AARICH,HICHAM
# 158269               AARNDELL,KAREEM,D
# 171801                   AARON,DARRELL
# 133038                 AASHAR,MUHAMMAD
# 138701           AASHIQ,SHIPU,MOHAMMED
# ...

# %%
# dv = df.groupby(df['Wheelchair Accessible Trained'])
# dv.head()
# Out:
#       License Number                 Name                     Type  \
# 0             493092       MAIGA,BOUNAFOU  FOR HIRE VEHICLE DRIVER
# 1             681774       GNANARAJ,SINNA  FOR HIRE VEHICLE DRIVER
# 2             498143  KAREEM,LUKMAN,ABDUL  FOR HIRE VEHICLE DRIVER
# 792           502684        BARIKDAR,PAUL  FOR HIRE VEHICLE DRIVER
# 1239          669860       GUANTE,FACUNDO  FOR HIRE VEHICLE DRIVER
# 3302          504529        ALAM,ASHRAFUL  FOR HIRE VEHICLE DRIVER
#
#      Expiration Date Wheelchair Accessible Trained Last Date Updated  \
# 0         11/24/2019                           WAV        04/15/2019
# 1         04/03/2020                           WAV        04/15/2019
# 2         01/03/2021                           WAV        04/15/2019
# 792       11/06/2019                           NaN        04/15/2019
# 1239      08/31/2019                           NaN        04/15/2019
# 3302      06/22/2019                           NaN        04/15/2019
#
# ...

# %%
df['Wheelchair Accessible Trained'].replace(df['Wheelchair Accessible Trained'],{'WAV': 1, 'NaN': 0})
df.head()
# Out:
#    License Number                 Name                     Type  \
# 0          493092       MAIGA,BOUNAFOU  FOR HIRE VEHICLE DRIVER
# 1          681774       GNANARAJ,SINNA  FOR HIRE VEHICLE DRIVER
# 2          498143  KAREEM,LUKMAN,ABDUL  FOR HIRE VEHICLE DRIVER
# 3          686178         TAVERAS,OLGA  FOR HIRE VEHICLE DRIVER
# 4          664245      CORNIEL,PEDRO,A  FOR HIRE VEHICLE DRIVER
#
#   Expiration Date Wheelchair Accessible Trained Last Date Updated  \
# 0      11/24/2019                           WAV        04/15/2019
# 1      04/03/2020                           WAV        04/15/2019
# 2      01/03/2021                           WAV        04/15/2019
# 3      08/21/2019                           WAV        04/15/2019
# 4      04/10/2022                           WAV        04/15/2019
#
#   Last Time Updated
# 0             13:25
# 1             13:25
# 2             13:25
# 3             13:25
# 4             13:25

# %%
df['Wheelchair Accessible Trained'].nunique()
# Out:
# 1

# %%
df['Wheelchair Accessible Trained'].value_counts()
# Out:
# WAV    188849
# Name: Wheelchair Accessible Trained, dtype: int64

# %%
df.shape
# Out:
# (188931, 7)

# %%
print(188931-188849)#non wheelchair accessible vehicle
# Out:
# 82
