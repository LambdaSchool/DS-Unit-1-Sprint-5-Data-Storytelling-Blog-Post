# %% [markdown]
# <a href="https://colab.research.google.com/github/livjab/DS-Unit-1-Sprint-5-Data-Storytelling-Blog-Post/blob/master/LJ_project_week_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# With the incresed awareness of climate change, and the generally agreed upon fact that carbon emissions are causing the changes we are observing, I wanted to explore some of our alternative options for energy production. My goal is to explore which renewable options are the most feasible based on factors such as cost and geographic location, and then determine if there is enough potential in our renewable sources to produce enough energy to eventually phase out the use of fossil fuels in the United States.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## United States Renewable Energy Technical Potential
#
# https://catalog.data.gov/dataset/united-states-renewable-energy-technical-potential
#
# - Renewable energy technical potential as defined in this report represents the achievable energy generation of a particular technology given system performance, topographic limitations, environmental, and land-use constraints.
#
# - The primary benefit of assessing technical potential is that it establishes an upper-boundary estimate of development potential. It is important to understand that there are multiple types of potential—resource, technical, economic, and market—each seen in Figure 1 (below), with key assumptions.

# %%
df = pd.read_csv("https://raw.githubusercontent.com/livjab/energy-project/master/usretechnicalpotential.csv?token=AFRLFL6VDSHXJTBVNOLSIWS4XXZBK")

# %%
df.shape
# Out:
# (51, 31)

# %%
df.head()
# Out:
#    Unnamed: 0  urbanUtilityScalePV_GWh  urbanUtilityScalePV_GW  \
# 0     Alabama                    35850                      20
# 1      Alaska                      166                       0
# 2     Arizona                   121305                      52
# 3    Arkansas                    28960                      15
# 4  California                   246008                     111
#
#    urbanUtilityScalePV_km2  ruralUtilityScalePV_GWh  ruralUtilityScalePV_GW  \
# 0                      426                  3706838                    2114
# 1                        2                  8282976                    9005
# 2                     1096                 11867693                    5147
# 3                      332                  4986388                    2747
# 4                     2320                  8855917                    4010
#
#    ruralUtilityScalePV_km2  rooftopPV_GWh  rooftopPV_GW   CSP_GWh  \
# 0                    44058        15475.0            12         0
# 1                   187608            NaN             1         0
# 2                   107230        22736.0            14  12544333
# 3                    57239         8484.0             6         0
# 4                    83549       106411.0            75   8490916
#
#             ...             biopowerGaseous_GWh  biopowerGaseous_GW  \
# 0           ...                            1533                   0
# 1           ...                              61                   0
# 2           ...                             837                   0
# 3           ...                            1063                   0
# 4           ...                           15510                   1
#
#    biopowerGaseous_Tonnes-CH4  geothermalHydrothermal_GWh  \
# 0                      326186                           0
# 1                       13156                       15437
# 2                      178188                        8329
# 3                      226178                           0
# 4                     3300211                      130921
#
#    geothermalHydrothermal_GW  EGSGeothermal_GWh  EGSGeothermal_GW  \
# 0                          0           535489.0              67.0
# 1                          1                NaN               NaN
# 2                          1          1239147.0             157.0
# 3                          0           628621.0              79.0
# 4                         16          1344179.0             170.0
#
#    hydropower_GWh  hydropower_GW  hydropower_countOfSites
# 0            4102              0                     2435
# 1           23675              5                     3053
# 2            1303              0                     1958
# 3            6093              1                     3268
# 4           30023              6                     9692
#
# [5 rows x 31 columns]

# %%
list(df)
# Out:
# ['Unnamed: 0',
#  'urbanUtilityScalePV_GWh',
#  'urbanUtilityScalePV_GW',
#  'urbanUtilityScalePV_km2',
#  'ruralUtilityScalePV_GWh',
#  'ruralUtilityScalePV_GW',
#  'ruralUtilityScalePV_km2',
#  'rooftopPV_GWh',
#  'rooftopPV_GW',
#  'CSP_GWh',
#  'CSP_GW',
#  'CSP_km2',
#  'onshoreWind_GWh',
#  'onshoreWind_GW',
#  'onshoreWind_km2',
#  'offshoreWind_GWh',
#  'offshoreWind_GW',
#  'offshoreWind_km2',
#  'biopowerSolid_GWh',
#  'biopowerSolid_GW',
#  'biopowerSolid_BDT',
#  'biopowerGaseous_GWh',
#  'biopowerGaseous_GW',
#  'biopowerGaseous_Tonnes-CH4',
#  'geothermalHydrothermal_GWh',
#  'geothermalHydrothermal_GW',
#  'EGSGeothermal_GWh',
#  'EGSGeothermal_GW',
#  'hydropower_GWh',
#  'hydropower_GW',
#  'hydropower_countOfSites']

# %%
# lets stick with only the columns measuring gigawatt hours, since that's 
# what I used to measure fossil fuels below

# %%
df = df.iloc[:, [0, 1, 4, 7, 9, 12, 15, 18, 21, 24, 26, 28]]
df.head()
# Out:
#    Unnamed: 0  urbanUtilityScalePV_GWh  ruralUtilityScalePV_GWh  \
# 0     Alabama                    35850                  3706838
# 1      Alaska                      166                  8282976
# 2     Arizona                   121305                 11867693
# 3    Arkansas                    28960                  4986388
# 4  California                   246008                  8855917
#
#    rooftopPV_GWh   CSP_GWh  onshoreWind_GWh  offshoreWind_GWh  \
# 0        15475.0         0              283               0.0
# 1            NaN         0          1373433               NaN
# 2        22736.0  12544333            26036               NaN
# 3         8484.0         0            22892               NaN
# 4       106411.0   8490916            89862         2662579.0
#
#    biopowerSolid_GWh  biopowerGaseous_GWh  geothermalHydrothermal_GWh  \
# 0              11193                 1533                           0
# 1                513                   61                       15437
# 2               1087                  837                        8329
# 3              14381                 1063                           0
# 4              12408                15510                      130921
#
#    EGSGeothermal_GWh  hydropower_GWh
# 0           535489.0            4102
# 1                NaN           23675
# 2          1239147.0            1303
# 3           628621.0            6093
# 4          1344179.0           30023

# %%
# rename columns

df = df.rename(columns={'Unnamed: 0': 'State', 
                        "urbanUtilityScalePV_GWh": "Urban PV", 
                        "ruralUtilityScalePV_GWh": "Rural PV", 
                        "rooftopPV_GWh": "Rooftop PV", 
                        "CSP_GWh": "CSP", 
                        "onshoreWind_GWh": "Onshore Wind", 
                        "offshoreWind_GWh": "Offshore Wind", 
                        "biopowerSolid_GWh": "Biopower Solid", 
                        "biopowerGaseous_GWh": "Biopower Gaseous", 
                        "geothermalHydrothermal_GWh": "Hydrothermal", 
                        "EGSGeothermal_GWh": "Geothermal", 
                        "hydropower_GWh": "Hydropower"})
df.head()
# Out:
#         State  Urban PV  Rural PV  Rooftop PV       CSP  Onshore Wind  \
# 0     Alabama     35850   3706838     15475.0         0           283
# 1      Alaska       166   8282976         NaN         0       1373433
# 2     Arizona    121305  11867693     22736.0  12544333         26036
# 3    Arkansas     28960   4986388      8484.0         0         22892
# 4  California    246008   8855917    106411.0   8490916         89862
#
#    Offshore Wind  Biopower Solid  Biopower Gaseous  Hydrothermal  Geothermal  \
# 0            0.0           11193              1533             0    535489.0
# 1            NaN             513                61         15437         NaN
# 2            NaN            1087               837          8329   1239147.0
# 3            NaN           14381              1063             0    628621.0
# 4      2662579.0           12408             15510        130921   1344179.0
#
#    Hydropower
# 0        4102
# 1       23675
# 2        1303
# 3        6093
# 4       30023

# %%
# check out nulls
df.isnull().sum()
# Out:
# State                0
# Urban PV             0
# Rural PV             0
# Rooftop PV           2
# CSP                  0
# Onshore Wind         0
# Offshore Wind       22
# Biopower Solid       0
# Biopower Gaseous     0
# Hydrothermal         0
# Geothermal           2
# Hydropower           0
# dtype: int64

# %%
# fill NAs with zeros 
# the amount of energy prodction for any NA value is zero so this makes sense

df = df.fillna(value=0)

# %%
# add columns with totals from each type

df["Solar Power Technologies Total"] = df["Urban PV"] + df["Rural PV"] + df["Rooftop PV"] + df["CSP"]
df["Wind Power Technologies Total"] = df["Onshore Wind"] + df["Offshore Wind"]
df["Biopower Technologies Total"] = df["Biopower Solid"] + df["Biopower Gaseous"]
df["Geothermal Energy Technologies Total"] = df["Hydrothermal"] + df["Geothermal"]
df["Hydropower Technologies Total"] = df["Hydropower"]

# %%
# add total total column

df["Total"] = df["Solar Power Technologies Total"] + df["Wind Power Technologies Total"] + df["Biopower Technologies Total"] + df["Geothermal Energy Technologies Total"] + df["Hydropower Technologies Total"]

df.head()
# Out:
#         State  Urban PV  Rural PV  Rooftop PV       CSP  Onshore Wind  \
# 0     Alabama     35850   3706838     15475.0         0           283
# 1      Alaska       166   8282976         0.0         0       1373433
# 2     Arizona    121305  11867693     22736.0  12544333         26036
# 3    Arkansas     28960   4986388      8484.0         0         22892
# 4  California    246008   8855917    106411.0   8490916         89862
#
#    Offshore Wind  Biopower Solid  Biopower Gaseous  Hydrothermal  Geothermal  \
# 0            0.0           11193              1533             0    535489.0
# 1            0.0             513                61         15437         0.0
# 2            0.0            1087               837          8329   1239147.0
# 3            0.0           14381              1063             0    628621.0
# 4      2662579.0           12408             15510        130921   1344179.0
#
#    Hydropower  Solar Power Technologies Total  Wind Power Technologies Total  \
# 0        4102                       3758163.0                          283.0
# 1       23675                       8283142.0                      1373433.0
# 2        1303                      24556067.0                        26036.0
# 3        6093                       5023832.0                        22892.0
# 4       30023                      17699252.0                      2752441.0
#
#    Biopower Technologies Total  Geothermal Energy Technologies Total  \
# 0                        12726                              535489.0
# 1                          574                               15437.0
# 2                         1924                             1247476.0
# 3                        15444                              628621.0
# 4                        27918                             1475100.0
#
#    Hydropower Technologies Total       Total
# 0                           4102   4310763.0
# 1                          23675   9696261.0
# 2                           1303  25832806.0
# 3                           6093   5696882.0
# 4                          30023  21984734.0

# %%
df.dtypes
# Out:
# State                                    object
# Urban PV                                  int64
# Rural PV                                  int64
# Rooftop PV                              float64
# CSP                                       int64
# Onshore Wind                              int64
# Offshore Wind                           float64
# Biopower Solid                            int64
# Biopower Gaseous                          int64
# Hydrothermal                              int64
# Geothermal                              float64
# Hydropower                                int64
# Solar Power Technologies Total          float64
# Wind Power Technologies Total           float64
# Biopower Technologies Total               int64
# Geothermal Energy Technologies Total    float64
# Hydropower Technologies Total             int64
# Total                                   float64
# dtype: object

# %%
# new df with just totals columns

totals = df[["State", 
             "Solar Power Technologies Total", 
             "Wind Power Technologies Total", 
             "Biopower Technologies Total", 
             "Geothermal Energy Technologies Total", 
             "Hydropower Technologies Total"]]

totals = totals.set_index("State")

# %%
# time to plot some things

totals.plot.bar(stacked=True, figsize=(15, 7), rot=80);

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.6/dist-packages (3.6.1)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.6/dist-packages (from plotly) (1.3.3)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from plotly) (1.11.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.6/dist-packages (from plotly) (2018.9)
# Requirement already satisfied: decorator>=4.0.6 in /usr/local/lib/python3.6/dist-packages (from plotly) (4.4.0)
# Requirement already satisfied: nbformat>=4.2 in /usr/local/lib/python3.6/dist-packages (from plotly) (4.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from plotly) (2.18.4)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2->plotly) (4.4.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2->plotly) (2.6.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2->plotly) (0.2.0)
# Requirement already satisfied: traitlets>=4.1 in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2->plotly) (4.3.2)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->plotly) (2.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->plotly) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->plotly) (2019.3.9)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->plotly) (1.22)

# %%
import plotly 
plotly.tools.set_credentials_file(username='livjab', api_key='wtMvZE3WmACuXMuwMSvH')

# %%
# need to create state codes for plotly to work

df['code'] = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "DC", "FL", "GA", 
              "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", 
              "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", 
              "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", 
              "UT", "VT", "VA", "WA", "WV", "WI", "WY"]

# %%
# choropleth with only solar resources

solar = df.iloc[:, [0, 1, 2, 3, 4, 12, 18]]

#[["State", "Urban PV", "Rural PV", "Rooftop PV", "CSP", "Solar Power Technologies Total", "code"]]

# %%
import plotly.plotly as py
import plotly.graph_objs as go

import pandas as pd

df1 = solar

for col in df1.columns:
    df1[col] = df1[col].astype(str)

scl = [
    [0.0, 'rgb(255, 240, 229)'],
    [0.2, 'rgb(240, 182, 147)'],
    [0.4, 'rgb(229, 138, 88)'],
    [0.6, 'rgb(222, 108, 48)'],
    [0.8, 'rgb(218, 93, 28)'],
    [1.0, 'rgb(215, 79, 9)']
]

df1['text'] = df1['State'] + '<br>' + \
    'Urban PV: ' + df1['Urban PV'] + '<br>' + \
    'Rural PV: ' + df1['Rural PV'] + '<br>' + \
    'Rooftop PV: ' + df1['Rooftop PV'] + '<br>' + \
    'CSP: ' + df1['CSP']


data = [go.Choropleth(
    colorscale = scl,
    autocolorscale = False,
    locations = df1['code'],
    z = df1['Solar Power Technologies Total'].astype(float),
    locationmode = 'USA-states',
    text = df1['text'],
    marker = go.choropleth.Marker(
        line = go.choropleth.marker.Line(
            color = 'rgb(255,255,255)',
            width = 2
        )),
    colorbar = go.choropleth.ColorBar(
        title = "Gigawatt Hours")
)]

layout = go.Layout(
    title = go.layout.Title(
        text = 'Total Solar Power Potential by State<br>(Hover for breakdown)'
    ),
    geo = go.layout.Geo(
        scope = 'usa',
        projection = go.layout.geo.Projection(type = 'albers usa'),
        showlakes = True,
        lakecolor = 'rgb(204, 235, 255)'),
)

fig = go.Figure(data = data, layout = layout)
py.iplot(fig, filename = 'solar-cloropleth-map')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~livjab/4.embed" height="525px" width="100%"></iframe>

# %%
# choropleth with wind technologies

wind = df.iloc[:, [0, 5, 6, 13, 18]]

# %%
for col in wind.columns:
    wind[col] = wind[col].astype(str)

scl = [
    [0.0, 'rgb(216, 221, 253)'],
    [0.2, 'rgb(154, 165, 239)'],
    [0.4, 'rgb(71, 92, 222)'],
    [0.6, 'rgb(51, 73, 217)'],
    [0.8, 'rgb(30, 55, 213)'],
    [1.0, 'rgb(10, 37, 209)']
]

wind['text'] = wind['State'] + '<br>' + \
    'Onshore Wind: ' + wind['Onshore Wind'] + '<br>' + \
    'Offshore Wind: ' + wind['Offshore Wind'] + '<br>'


data = [go.Choropleth(
    colorscale = scl,
    autocolorscale = False,
    locations = wind['code'],
    z = wind['Wind Power Technologies Total'].astype(float),
    locationmode = 'USA-states',
    text = wind['text'],
    marker = go.choropleth.Marker(
        line = go.choropleth.marker.Line(
            color = 'rgb(255,255,255)',
            width = 2
        )),
    colorbar = go.choropleth.ColorBar(
        title = "Gigawatt Hours")
)]

layout = go.Layout(
    title = go.layout.Title(
        text = 'Total Wind Power Potential by State<br>(Hover for breakdown)'
    ),
    geo = go.layout.Geo(
        scope = 'usa',
        projection = go.layout.geo.Projection(type = 'albers usa'),
        showlakes = True,
        lakecolor = 'rgb(204, 235, 255)'),
)

fig = go.Figure(data = data, layout = layout)
py.iplot(fig, filename = 'wind-cloropleth-map')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~livjab/6.embed" height="525px" width="100%"></iframe>

# %%
# biopower technologies

bio = df.iloc[:, [0, 7, 8, 14, 18]]

# %%
for col in bio.columns:
    bio[col] = bio[col].astype(str)

scl = [
    [0.0, 'rgb(216, 243, 217)'],
    [0.2, 'rgb(179, 211, 180)'],
    [0.4, 'rgb(142, 179, 144)'],
    [0.6, 'rgb(105, 148, 107)'],
    [0.8, 'rgb(68, 116, 71)'],
    [1.0, 'rgb(32, 85, 35)']
]

bio['text'] = bio['State'] + '<br>' + \
    'Biopower Solid: ' + bio['Biopower Solid'] + '<br>' + \
    'Biopower Gaseous: ' + bio['Biopower Gaseous'] + '<br>'


data = [go.Choropleth(
    colorscale = scl,
    autocolorscale = False,
    locations = bio['code'],
    z = bio['Biopower Technologies Total'].astype(float),
    locationmode = 'USA-states',
    text = bio['text'],
    marker = go.choropleth.Marker(
        line = go.choropleth.marker.Line(
            color = 'rgb(255,255,255)',
            width = 2
        )),
    colorbar = go.choropleth.ColorBar(
        title = "Gigawatt Hours")
)]

layout = go.Layout(
    title = go.layout.Title(
        text = 'Total Bio Power Potential by State<br>(Hover for breakdown)'
    ),
    geo = go.layout.Geo(
        scope = 'usa',
        projection = go.layout.geo.Projection(type = 'albers usa'),
        showlakes = True,
        lakecolor = 'rgb(204, 235, 255)'),
)

fig = go.Figure(data = data, layout = layout)
py.iplot(fig, filename = 'bio-cloropleth-map')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~livjab/8.embed" height="525px" width="100%"></iframe>

# %%
# geothermal choropleth

geo = df.iloc[:, [0, 9, 10, 15, 18]]

# %%
for col in geo.columns:
    geo[col] = geo[col].astype(str)

scl = [
    [0.0, 'rgb(218, 208, 205)'],
    [0.2, 'rgb(202, 192, 189)'],
    [0.4, 'rgb(170, 160, 157)'],
    [0.6, 'rgb(108, 96, 93)'],
    [0.8, 'rgb(108, 96, 93)'],
    [1.0, 'rgb(81, 78, 75)']
]

geo['text'] = geo['State'] + '<br>' + \
    'Hydrothermal: ' + geo['Hydrothermal'] + '<br>' + \
    'Geothermal: ' + geo['Geothermal'] + '<br>'


data = [go.Choropleth(
    colorscale = scl,
    autocolorscale = False,
    locations = geo['code'],
    z = geo['Geothermal Energy Technologies Total'].astype(float),
    locationmode = 'USA-states',
    text = geo['text'],
    marker = go.choropleth.Marker(
        line = go.choropleth.marker.Line(
            color = 'rgb(255,255,255)',
            width = 2
        )),
    colorbar = go.choropleth.ColorBar(
        title = "Gigawatt Hours")
)]

layout = go.Layout(
    title = go.layout.Title(
        text = 'Total Geothermal Energy Potential by State<br>(Hover for breakdown)'
    ),
    geo = go.layout.Geo(
        scope = 'usa',
        projection = go.layout.geo.Projection(type = 'albers usa'),
        showlakes = True,
        lakecolor = 'rgb(204, 235, 255)'),
)

fig = go.Figure(data = data, layout = layout)
py.iplot(fig, filename = 'geo-cloropleth-map')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~livjab/10.embed" height="525px" width="100%"></iframe>

# %%
#hydro choropleth

hydro = df.iloc[:, [0, 11, 16, 18]]

# %%
for col in hydro.columns:
    hydro[col] = hydro[col].astype(str)

scl = [
    [0.0, 'rgb(192, 204, 231)'],
    [0.2, 'rgb(158, 171, 200)'],
    [0.4, 'rgb(125, 138, 169)'],
    [0.6, 'rgb(108, 122, 154)'],
    [0.8, 'rgb(75, 89, 123)'],
    [1.0, 'rgb(41, 57, 92)']
]

hydro['text'] = hydro['State'] + '<br>'


data = [go.Choropleth(
    colorscale = scl,
    autocolorscale = False,
    locations = hydro['code'],
    z = hydro['Hydropower Technologies Total'].astype(float),
    locationmode = 'USA-states',
    text = hydro['text'],
    marker = go.choropleth.Marker(
        line = go.choropleth.marker.Line(
            color = 'rgb(255,255,255)',
            width = 2
        )),
    colorbar = go.choropleth.ColorBar(
        title = "Gigawatt Hours")
)]

layout = go.Layout(
    title = go.layout.Title(
        text = 'Total Hydropower Potential by State<br>(Hover for breakdown)'
    ),
    geo = go.layout.Geo(
        scope = 'usa',
        projection = go.layout.geo.Projection(type = 'albers usa'),
        showlakes = True,
        lakecolor = 'rgb(204, 235, 255)'),
)

fig = go.Figure(data = data, layout = layout)
py.iplot(fig, filename = 'hydro-cloropleth-map')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~livjab/12.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ## Explore dataset with renewable vs fossil fuel production
#
# https://www.eia.gov/totalenergy/data/monthly/
# - Electricity
# - Total (all sectors)
#
# https://www.eia.gov/totalenergy/data/monthly/pdf/sec7_5.pdf

# %%
df1 = pd.read_csv("https://raw.githubusercontent.com/livjab/energy-project/master/MER_T07_02A.csv?token=AFRLFLYDWFBTKFVOSRC6DGK4XXZOA")

df1.head()
# Out:
#        MSN  YYYYMM       Value  Column_Order  \
# 0  CLETPUS  194913   135451.32             1
# 1  CLETPUS  195013  154519.994             1
# 2  CLETPUS  195113  185203.657             1
# 3  CLETPUS  195213  195436.666             1
# 4  CLETPUS  195313  218846.325             1
#
#                                          Description                   Unit
# 0  Electricity Net Generation From Coal, All Sectors  Million Kilowatthours
# 1  Electricity Net Generation From Coal, All Sectors  Million Kilowatthours
# 2  Electricity Net Generation From Coal, All Sectors  Million Kilowatthours
# 3  Electricity Net Generation From Coal, All Sectors  Million Kilowatthours
# 4  Electricity Net Generation From Coal, All Sectors  Million Kilowatthours

# %%
# drop first column because we have that info elsewhere

df1 = df1.drop(columns=["MSN"])
df1.shape
# Out:
# (8086, 5)

# %%
 # only going to keep the rows with 13th month because it is total for that year
  
 # change dtype to string so I can filter using endswith()
  
df1["YYYYMM"] = df1["YYYYMM"].astype('str')

# %%
# filter for values ending in "13"

df1 = df1[df1["YYYYMM"].str.endswith("13")]
df1.tail()
# Out:
#       YYYYMM        Value  Column_Order  \
# 8033  201413  4093606.006            13
# 8046  201513  4077600.939            13
# 8059  201613  4076674.984            13
# 8072  201713  4034268.432            13
# 8085  201813  4177809.699            13
#
#                                             Description                   Unit
# 8033  Electricity Net Generation Total (including fr...  Million Kilowatthours
# 8046  Electricity Net Generation Total (including fr...  Million Kilowatthours
# 8059  Electricity Net Generation Total (including fr...  Million Kilowatthours
# 8072  Electricity Net Generation Total (including fr...  Million Kilowatthours
# 8085  Electricity Net Generation Total (including fr...  Million Kilowatthours

# %%
# change dtype back to int so i can do math

df1["YYYYMM"] = df1["YYYYMM"].astype("int64")

# %%
df1["Year"] = (df1["YYYYMM"] - 13) / 100
df1.head()
# Out:
#    YYYYMM       Value  Column_Order  \
# 0  194913   135451.32             1
# 1  195013  154519.994             1
# 2  195113  185203.657             1
# 3  195213  195436.666             1
# 4  195313  218846.325             1
#
#                                          Description                   Unit  \
# 0  Electricity Net Generation From Coal, All Sectors  Million Kilowatthours
# 1  Electricity Net Generation From Coal, All Sectors  Million Kilowatthours
# 2  Electricity Net Generation From Coal, All Sectors  Million Kilowatthours
# 3  Electricity Net Generation From Coal, All Sectors  Million Kilowatthours
# 4  Electricity Net Generation From Coal, All Sectors  Million Kilowatthours
#
#      Year
# 0  1949.0
# 1  1950.0
# 2  1951.0
# 3  1952.0
# 4  1953.0

# %%
#drop YYYYMM column and reorder remaining columns

df1 = df1.drop(columns=["YYYYMM"])
df1 = df1[['Year', 'Value', 'Column_Order', 'Description', 'Unit']]
df1.head()
# Out:
#      Year       Value  Column_Order  \
# 0  1949.0   135451.32             1
# 1  1950.0  154519.994             1
# 2  1951.0  185203.657             1
# 3  1952.0  195436.666             1
# 4  1953.0  218846.325             1
#
#                                          Description                   Unit
# 0  Electricity Net Generation From Coal, All Sectors  Million Kilowatthours
# 1  Electricity Net Generation From Coal, All Sectors  Million Kilowatthours
# 2  Electricity Net Generation From Coal, All Sectors  Million Kilowatthours
# 3  Electricity Net Generation From Coal, All Sectors  Million Kilowatthours
# 4  Electricity Net Generation From Coal, All Sectors  Million Kilowatthours

# %%
# check out Unit column

df1["Unit"].describe()
# Out:
# count                       910
# unique                        1
# top       Million Kilowatthours
# freq                        910
# Name: Unit, dtype: object

# %%
# remove column and remember to label any plots with 
# "Million Kilowatthours"

df1 = df1.drop(columns=["Unit"])

# %%
# check out description column

df1["Description"].unique()
# Out:
# array(['Electricity Net Generation From Coal, All Sectors',
#        'Electricity Net Generation From Petroleum, All Sectors',
#        'Electricity Net Generation From Natural Gas, All Sectors',
#        'Electricity Net Generation From Other Gases, All Sectors',
#        'Electricity Net Generation From Nuclear Electric Power, All Sectors',
#        'Electricity Net Generation From Hydroelectric Pumped Storage, All Sectors',
#        'Electricity Net Generation From Conventional Hydroelectric Power, All Sectors',
#        'Electricity Net Generation From Wood, All Sectors',
#        'Electricity Net Generation From Waste, All Sectors',
#        'Electricity Net Generation From Geothermal, All Sectors',
#        'Electricity Net Generation From Solar, All Sectors',
#        'Electricity Net Generation From Wind, All Sectors',
#        'Electricity Net Generation Total (including from sources not shown), All Sectors'],
#       dtype=object)

# %%
# pivot the data to create more columns

table = df1.pivot(index="Year", columns="Description", values="Value")
table
# Out:
# Description Electricity Net Generation From Coal, All Sectors  \
# Year
# 1949.0                                              135451.32
# 1950.0                                             154519.994
# 1951.0                                             185203.657
# 1952.0                                             195436.666
# 1953.0                                             218846.325
# 1954.0                                             239145.966
# 1955.0                                             301362.698
# 1956.0                                             338503.484
# 1952.0                     Not Available   68453.088                      0
# 1953.0                     Not Available   79790.975                      0
#
# Description    Other Gases  Petroleum          Solar          Waste  \
# Year
# 1949.0       Not Available  28547.232  Not Available  Not Available
# 1950.0       Not Available  33734.288  Not Available  Not Available
# 1951.0       Not Available  28712.116  Not Available  Not Available
# 1952.0       Not Available  29749.761  Not Available  Not Available
# 1953.0       Not Available  38404.449  Not Available  Not Available
#
# Description           Wind     Wood       Total
# Year
# 1949.0       Not Available  386.036  296124.289
# 1950.0       Not Available  389.585  334087.601
# 1951.0       Not Available  390.784  375298.355
# 1952.0       Not Available  481.647  403829.413
# 1953.0       Not Available  389.418  447048.563

# %%
table.tail()
# Out:
# Description         Coal Hydroelectric Power Geothermal  \
# Year
# 2014.0        1581710.35          259366.622  15876.941
# 2015.0       1352398.197          249080.085  15917.575
# 2016.0       1239148.654          267812.153  15825.807
# 2017.0       1205835.275          300333.156  15926.765
# 2018.0       1146392.716          291723.816  16728.455
#
# Description Hydroelectric Pumped Storage  Natural Gas Nuclear Electric Power  \
# Year
# 2014.0                         -6173.548  1126608.958             797165.982
# 2015.0                         -5091.488   1333482.11             797177.877
# 2016.0                         -6686.127  1378306.934             805693.948
# 2017.0                         -6494.548  1296414.692             804949.635
# 2018.0                         -5904.539  1468012.599             807077.759
#
# Description Other Gases  Petroleum      Solar      Waste        Wind  \
# Year
# 2014.0        12021.786  30231.862  17691.031  21649.719  181655.282
# 2015.0        13116.698  28248.749  24892.904  21703.372  190718.548
# 2016.0        12807.432  24204.806  36054.121  21813.231  226992.562
# 2017.0        12468.967  21389.958  53286.174  21609.891  254302.662
# 2018.0        12191.182   24571.82  66603.684  21353.868  274951.815
#
# Description       Wood        Total
# Year
# 2014.0       42339.725  4093606.006
# 2015.0       41928.506  4077600.939
# 2016.0       40947.227  4076674.984
# 2017.0       41151.779  4034268.432
# 2018.0        41411.26  4177809.699

# %%
table.dtypes
# Out:
# Description
# Coal                            object
# Hydroelectric Power             object
# Geothermal                      object
# Hydroelectric Pumped Storage    object
# Natural Gas                     object
# Nuclear Electric Power          object
# Other Gases                     object
# Petroleum                       object
# Solar                           object
# Waste                           object
# Wind                            object
# Wood                            object
# Total                           object
# dtype: object

# %%
# need to all be floats to be able to do math and stuff

# but first need to deal with Nan and non numeric values

table.isnull().sum()
# Out:
# Description
# Coal                            0
# Hydroelectric Power             0
# Geothermal                      0
# Hydroelectric Pumped Storage    0
# Natural Gas                     0
# Nuclear Electric Power          0
# Other Gases                     0
# Petroleum                       0
# Solar                           0
# Waste                           0
# Wind                            0
# Wood                            0
# Total                           0
# dtype: int64

# %%
table.describe()
# Out:
# Description         Coal Hydroelectric Power     Geothermal  \
# count                 70                  70             70
# unique                70                  70             60
# top          1583779.139          275572.597  Not Available
# freq                   1                   1             11
#
# Description Hydroelectric Pumped Storage Natural Gas Nuclear Electric Power  \
# count                                 70          70                     70
# unique                                30          70                     63
# top                        Not Available  345777.173                      0
# freq                                  41           1                      8
#
# Description    Other Gases   Petroleum          Solar          Waste  \
# count                   70          70             70             70
# unique                  31          70             36             50
# top          Not Available  100154.163  Not Available  Not Available
# freq                    40           1             35             21
#
# Description           Wind      Wood        Total
# count                   70        70           70
# unique                  37        70           70
# top          Not Available  41411.26  3970555.264
# freq                    34         1            1

# %%
# Looking at the data, it makes sense to replace any "Not Available" entries 
# with "0" because it seems that "Not Available" was used before that specific 
# type of energy production was common, thus making 0 a valid entry to work with.

table = table.replace({"Not Available": 0})

# %%
table = table.astype(float)

# %%
table.dtypes
# Out:
# Description
# Coal                            float64
# Hydroelectric Power             float64
# Geothermal                      float64
# Hydroelectric Pumped Storage    float64
# Natural Gas                     float64
# Nuclear Electric Power          float64
# Other Gases                     float64
# Petroleum                       float64
# Solar                           float64
# Waste                           float64
# Wind                            float64
# Wood                            float64
# Total                           float64
# dtype: object

# %%
# need to set index so that "Year" is a non index column

table = table.reset_index()
table.head()
# Out:
# Description    Year        Coal  Hydroelectric Power  Geothermal  \
# 0            1949.0  135451.320            94772.992         0.0
# 1            1950.0  154519.994           100884.575         0.0
# 2            1951.0  185203.657           104376.120         0.0
# 3            1952.0  195436.666           109708.251         0.0
# 4            1953.0  218846.325           109617.396         0.0
#
# Description  Hydroelectric Pumped Storage  Natural Gas  \
# 0                                     0.0    36966.709
# 1                                     0.0    44559.159
# 2                                     0.0    56615.678
# 3                                     0.0    68453.088
# 4                                     0.0    79790.975
#
# Description  Nuclear Electric Power  Other Gases  Petroleum  Solar  Waste  \
# 0                               0.0          0.0  28547.232    0.0    0.0
# 1                               0.0          0.0  33734.288    0.0    0.0
# 2                               0.0          0.0  28712.116    0.0    0.0
# 3                               0.0          0.0  29749.761    0.0    0.0
# 4                               0.0          0.0  38404.449    0.0    0.0
#
# Description  Wind     Wood       Total
# 0             0.0  386.036  296124.289
# 1             0.0  389.585  334087.601
# 2             0.0  390.784  375298.355
# 3             0.0  481.647  403829.413
# 4             0.0  389.418  447048.563

# %%
current_total = table[table["Year"] == 2018]
current_total
# Out:
# Description    Year         Coal  Hydroelectric Power  Geothermal  \
# 69           2018.0  1146392.716           291723.816   16728.455
#
# Description  Hydroelectric Pumped Storage  Natural Gas  \
# 69                              -5904.539  1468012.599
#
# Description  Nuclear Electric Power  Other Gases  Petroleum      Solar  \
# 69                       807077.759    12191.182   24571.82  66603.684
#
# Description      Waste        Wind      Wood        Total
# 69           21353.868  274951.815  41411.26  4177809.699

# %%
# would like to separate the dataframe into two categories for 
# renewable vs non renewable

renewable = table[["Year", "Hydroelectric Power", "Wood", "Waste", "Geothermal", "Solar", "Wind"]]
non_renewable = table[["Year", "Coal", "Petroleum", "Natural Gas", "Other Gases", "Nuclear Electric Power" ]]

# %%
# now to plot!

x = renewable["Year"]
y1 = renewable["Hydroelectric Power"]
y2 = renewable["Wood"]
y3 = renewable["Waste"]
y4 = renewable["Geothermal"]
y5 = renewable["Solar"]
y6 = renewable["Wind"]

fig, ax = plt.subplots()
fig.set_size_inches(10,7)
ax.stackplot(x, y1, y2, y3, y4, y5, y6, labels=["Hydroelectric Power", "Wood",
                                                 "Waste", "Geothermal",
                                                 "Solar", "Wind"])
ax.legend(loc='upper left')
ax.set_title("Electricity Generation from Renewable Sources")
ax.set_ylabel("Millions of Kilowatthours")
plt.show()

# %%
x = non_renewable["Year"]
y1 = non_renewable["Coal"]
y2 = non_renewable["Petroleum"]
y3 = non_renewable["Natural Gas"]
y4 = non_renewable["Other Gases"]
y5 = non_renewable["Nuclear Electric Power"]

fig, ax = plt.subplots()
fig.set_size_inches(10,7)
ax.stackplot(x, y1, y2, y3, y4, y5, labels=["Coal", "Petroleum", "Natural Gas",
                                            "Other Gases", "Nuclear"])
ax.legend(loc='upper left')
ax.set_title("Electricity Generation from Fossil Fuels and Nuclear")
ax.set_ylabel("Millions of Kilowatthours")
plt.show()

# %%
# would like to show these next to each other so its easy to compare

x1 = renewable["Year"]
x2 = non_renewable["Year"]

y1_1 = renewable["Hydroelectric Power"]
y1_2 = renewable["Wood"]
y1_3 = renewable["Waste"]
y1_4 = renewable["Geothermal"]
y1_5 = renewable["Solar"]
y1_6 = renewable["Wind"]

y2_1 = non_renewable["Coal"]
y2_2 = non_renewable["Petroleum"]
y2_3 = non_renewable["Natural Gas"]
y2_4 = non_renewable["Other Gases"]
y2_5 = non_renewable["Nuclear Electric Power"]


f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
f.suptitle("Electricty Generation from Renewable vs Nonrenewable Sources")

ax1.stackplot(x1, y1_1, y1_2, y1_3, y1_4, y1_5, y1_6, labels=["Hydroelectric Power",
                                                              "Wood", "Waste", 
                                                              "Geothermal",
                                                              "Solar", "Wind"])
#ax1.set_title("Electricity Generation from Renewable Sources")
ax1.set_ylabel("Millions of Kilowatt Hours")
ax1.legend(loc='upper left')



ax2.stackplot(x2, y2_1, y2_2, y2_3, y2_4, y2_5, labels=["Coal", "Petroleum", 
                                                        "Natural Gas", 
                                                        "Other Gases", "Nuclear"])
#ax2.set_title("Electricity Generation from Fossil Fuels and Nuclear")
ax2.legend(loc='upper left')

plt.tight_layout()
plt.show()

# %%
# trying this out in plotly

import plotly.plotly as py
import plotly.graph_objs as go


x= renewable["Year"]

trace0 = dict(
    x=x,
    y=renewable["Hydroelectric Power"],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=0.5,
              color='rgb(8, 48, 135)'),
    stackgroup='one',
    name='Hydroelectric'
)
trace1 = dict(
    x=x,
    y=renewable["Wood"],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=0.5,
              color='rgb(105, 148, 107)'),
    stackgroup='one',
    name='Wood'
)
trace2 = dict(
    x=x,
    y=renewable["Waste"],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=0.5,
              color='rgb(32, 85, 35)'),
    stackgroup='one',
    name='Waste'
)
trace3 = dict(
    x=x,
    y=renewable["Geothermal"],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=0.5,
              color='rgb(81, 78, 75)'),
    stackgroup='one',
    name='Geothermal'
)
trace4 = dict(
    x=x,
    y=renewable["Solar"],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=0.5,
              color='rgb(215, 79, 9)'),
    stackgroup='one',
    name='Solar'
)
trace5 = dict(
    x=x,
    y=renewable["Wind"],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=0.5,
              color='rgb(70, 11, 165)'),
    stackgroup='one',
    name='Wind'
)
data = [trace0, trace1, trace2, trace3, trace4, trace5]
layout = go.Layout(
    title=go.layout.Title(
        text='Electricity Generation From Renewable Sources'
    ),
    yaxis=go.layout.YAxis(
        title=go.layout.yaxis.Title(
            text='Millions of Kilowatt Hours'
        )
    ),
    legend=dict(x=.05, y=1)
)
fig = dict(data=data, layout=layout)
py.iplot(fig, filename='renewable-stacked-area-plot-hover', validate=False)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~livjab/16.embed" height="525px" width="100%"></iframe>

# %%
# now for non renewable

x= non_renewable["Year"]

trace0 = dict(
    x=x,
    y=non_renewable["Coal"],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=0.5,
              color='rgb(8, 48, 135)'),
    stackgroup='one',
    name='Coal'
)
trace1 = dict(
    x=x,
    y=non_renewable["Petroleum"],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=0.5,
              color='rgb(81, 78, 75)'),
    stackgroup='one',
    name='Petroleum'
)
trace2 = dict(
    x=x,
    y=non_renewable["Natural Gas"],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=0.5,
              color='rgb(32, 85, 35)'),
    stackgroup='one',
    name='Natural Gas'
)
trace3 = dict(
    x=x,
    y=non_renewable["Other Gases"],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=0.5,
              color='rgb(105, 148, 107)'),
    stackgroup='one',
    name='Other Gases'
)
trace4 = dict(
    x=x,
    y=non_renewable["Nuclear Electric Power"],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=0.5,
              color='rgb(215, 79, 9)'),
    stackgroup='one',
    name='Nuclear'
)

data = [trace0, trace1, trace2, trace3, trace4]
layout = go.Layout(
    title=go.layout.Title(
        text='Electricity Generation From Non-renewable Sources'
    ),
    yaxis=go.layout.YAxis(
        title=go.layout.yaxis.Title(
            text='Millions of Kilowatt Hours'
        )
    ),
    legend=dict(x=.05, y=1)
)
fig = dict(data=data, layout=layout)
py.iplot(fig, filename='non-renewable-stacked-area-plot-hover', validate=False)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~livjab/18.embed" height="525px" width="100%"></iframe>

# %%
# would like side by side subplots of these two

from plotly import tools

x1= renewable["Year"]
x2= non_renewable["Year"]

trace0 = dict(
    x=x1,
    y=renewable["Hydroelectric Power"],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=0.5,
              color='rgb(8, 48, 135)'),
    stackgroup='one',
    legendgroup='one',
    name='Hydroelectric'
)
trace1 = dict(
    x=x1,
    y=renewable["Wood"],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=0.5,
              color='rgb(105, 148, 107)'),
    stackgroup='one',
    legendgroup='one',
    name='Wood'
)
trace2 = dict(
    x=x1,
    y=renewable["Waste"],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=0.5,
              color='rgb(32, 85, 35)'),
    stackgroup='one',
    legendgroup='one',
    name='Waste'
)
trace3 = dict(
    x=x1,
    y=renewable["Geothermal"],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=0.5,
              color='rgb(81, 78, 75)'),
    stackgroup='one',
    legendgroup='one',
    name='Geothermal'
)
trace4 = dict(
    x=x1,
    y=renewable["Solar"],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=0.5,
              color='rgb(215, 79, 9)'),
    stackgroup='one',
    legendgroup='one',
    name='Solar'
)
trace5 = dict(
    x=x1,
    y=renewable["Wind"],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=0.5,
              color='rgb(70, 11, 165)'),
    stackgroup='one',
    legendgroup='one',
    name='Wind'
)
trace6 = dict(
    x=x2,
    y=non_renewable["Coal"],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=0.5,
              color='rgb(8, 48, 135)'),
    stackgroup='one',
    legendgroup='two',
    name='Coal'
)
trace7 = dict(
    x=x2,
    y=non_renewable["Petroleum"],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=0.5,
              color='rgb(81, 78, 75)'),
    stackgroup='one',
    legendgroup='two',
    name='Petroleum'
)
trace8 = dict(
    x=x2,
    y=non_renewable["Natural Gas"],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=0.5,
              color='rgb(32, 85, 35)'),
    stackgroup='one',
    legendgroup='two',
    name='Natural Gas'
)
trace9 = dict(
    x=x2,
    y=non_renewable["Other Gases"],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=0.5,
              color='rgb(105, 148, 107)'),
    stackgroup='one',
    legendgroup='two',
    name='Other Gases'
)
trace10 = dict(
    x=x2,
    y=non_renewable["Nuclear Electric Power"],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=0.5,
              color='rgb(215, 79, 9)'),
    stackgroup='one',
    legendgroup='two',
    name='Nuclear'
)

fig = tools.make_subplots(rows=1, cols=2, shared_yaxes=True, 
                          subplot_titles=('Renewable Sources', 'Non-renewable sources'))


fig.append_trace(trace0, 1, 1)
fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 1, 1)
fig.append_trace(trace3, 1, 1)
fig.append_trace(trace4, 1, 1)
fig.append_trace(trace5, 1, 1)
fig.append_trace(trace6, 1, 2)
fig.append_trace(trace7, 1, 2)
fig.append_trace(trace8, 1, 2)
fig.append_trace(trace9, 1, 2)
fig.append_trace(trace10, 1, 2)


fig['layout'].update(height=700, width=1100,
                    title='Electricity Generation From Renewable vs Non-renewable Sources',
                    legend=dict(x=.45, y=.90, tracegroupgap=(60)))

fig['layout']['yaxis1'].update(title='Gigawatt Hours')

py.iplot(fig, filename='multiple-subplots-shared-yaxes')
# Out:
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]  [ (1,2) x2,y1 ]
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~livjab/20.embed" height="700px" width="1100px"></iframe>

# %%
# look at electricity production in 2018 vs 
# what the potential renewable sources could produce

# will need to merge the row of totals for the potential dataframe with
# the row of totals for the current dataframe

# %%
current_total
# Out:
# Description    Year         Coal  Hydroelectric Power  Geothermal  \
# 69           2018.0  1146392.716           291723.816   16728.455
#
# Description  Hydroelectric Pumped Storage  Natural Gas  \
# 69                              -5904.539  1468012.599
#
# Description  Nuclear Electric Power  Other Gases  Petroleum      Solar  \
# 69                       807077.759    12191.182   24571.82  66603.684
#
# Description      Waste        Wind      Wood        Total
# 69           21353.868  274951.815  41411.26  4177809.699

# %%
# removing unnecessary columns

current_total = current_total.drop(columns=["Year", "Total"])

# %%
current_total.plot.bar();

# %%
potential_total = df[["Solar Power Technologies Total", 
                      "Wind Power Technologies Total", 
                      "Biopower Technologies Total", 
                      "Geothermal Energy Technologies Total", 
                      "Hydropower Technologies Total"]]

# %%
potential_total.columns = ["Solar", "Wind", "Bio", "Geothermal", "Hydro"]

# %%
potential_total.head()
# Out:
#         Solar       Wind    Bio  Geothermal  Hydro
# 0   3758163.0      283.0  12726    535489.0   4102
# 1   8283142.0  1373433.0    574     15437.0  23675
# 2  24556067.0    26036.0   1924   1247476.0   1303
# 3   5023832.0    22892.0  15444    628621.0   6093
# 4  17699252.0  2752441.0  27918   1475100.0  30023

# %%
potential_total.sum()
# Out:
# Solar         399809805.0
# Wind           49759763.0
# Bio              488278.0
# Geothermal     31646047.0
# Hydro            258929.0
# dtype: float64

# %%
potential_total = pd.DataFrame({"Solar": [399809805.0], "Wind": [49759763.0], "Bio": [488278.0], 
              "Geothermal": [31646047.0], "Hydro": [258929.0]})

potential_total
# Out:
#          Solar        Wind       Bio  Geothermal     Hydro
# 0  399809805.0  49759763.0  488278.0  31646047.0  258929.0

# %%
potential_total.plot.bar();

# %%
# merge potential total with current total
# one million kilowatt hours = 1 gigawatt hour
# so no conversion is needed

# %%
merged = pd.merge(potential_total, current_total, how='outer')
merged
# Out:
#           Solar          Wind       Bio    Geothermal     Hydro         Coal  \
# 0  3.998098e+08  4.975976e+07  488278.0  3.164605e+07  258929.0          NaN
# 1  6.660368e+04  2.749518e+05       NaN  1.672846e+04       NaN  1146392.716
#
#    Hydroelectric Power  Hydroelectric Pumped Storage  Natural Gas  \
# 0                  NaN                           NaN          NaN
# 1           291723.816                     -5904.539  1468012.599
#
#    Nuclear Electric Power  Other Gases  Petroleum      Waste      Wood
# 0                     NaN          NaN        NaN        NaN       NaN
# 1              807077.759    12191.182   24571.82  21353.868  41411.26

# %%
merged = merged.rename({0: "Potential", 1: "Current"}, axis='index')
merged
# Out:
#                   Solar          Wind       Bio    Geothermal     Hydro  \
# Potential  3.998098e+08  4.975976e+07  488278.0  3.164605e+07  258929.0
# Current    6.660368e+04  2.749518e+05       NaN  1.672846e+04       NaN
#
#                   Coal  Hydroelectric Power  Hydroelectric Pumped Storage  \
# Potential          NaN                  NaN                           NaN
# Current    1146392.716           291723.816                     -5904.539
#
#            Natural Gas  Nuclear Electric Power  Other Gases  Petroleum  \
# Potential          NaN                     NaN          NaN        NaN
# Current    1468012.599              807077.759    12191.182   24571.82
#
#                Waste      Wood
# Potential        NaN       NaN
# Current    21353.868  41411.26

# %%
merged.shape
# Out:
# (2, 14)

# %%
ax = merged.plot.bar(stacked=True, 
                    title='Potential Energry Production vs Current Production',
                    figsize=(10, 10));

# %%
# trying a plotly stacked bar

import plotly.plotly as py
import plotly.graph_objs as go


trace1 = go.Bar(
    x=["Potential", "Current"],
    y=merged["Solar"],
    name='Solar',
    marker = dict(
      color='rgb(208,99,8)')
)
trace2 = go.Bar(
    x=["Potential", "Current"],
    y=merged["Wind"],
    name='Wind',
    marker = dict(
      color='rgb(10, 37, 209)')
)
trace3 = go.Bar(
    x=["Potential", "Current"],
    y=merged["Bio"],
    name='Bio',
    marker = dict(
      color='rgb(33,116,56)')
)
trace4 = go.Bar(
    x=["Potential", "Current"],
    y=merged["Geothermal"],
    name='Geothermal',
    marker = dict(
      color='rgb(79,68,51)')
)
trace5 = go.Bar(
    x=["Potential", "Current"],
    y=merged["Hydro"],
    name='Hydro',
    marker = dict(
      color='rgb(33,52,105)')
)
trace6 = go.Bar(
    x=["Potential", "Current"],
    y=merged["Coal"],
    name='Coal',
    marker = dict(
      color='rgb(57,59,66)')
)
trace7 = go.Bar(
    x=["Potential", "Current"],
    y=merged["Hydroelectric Power"],
    name='Hydroelectric Power',
    marker = dict(
      color='rgb(33,52,105)')
)
trace8 = go.Bar(
    x=["Potential", "Current"],
    y=merged["Natural Gas"],
    name='Natural Gas',
    marker = dict(
      color='rgb(169,70,85)')
)
trace9 = go.Bar(
    x=["Potential", "Current"],
    y=merged["Nuclear Electric Power"],
    name='Nuclear Electric Power',
    marker = dict(
      color='rgb(70,169,152)')
)
trace10 = go.Bar(
    x=["Potential", "Current"],
    y=merged["Other Gases"],
    name='Other Gases',
    marker = dict(
      color='rgb(169,150,70)')
)
trace11 = go.Bar(
    x=["Potential", "Current"],
    y=merged["Petroleum"],
    name='Petroleum',
    marker = dict(
      color='rgb(123,70,169)')
)
trace12 = go.Bar(
    x=["Potential", "Current"],
    y=merged["Waste"],
    name='Waste',
    marker = dict(
      color='rgb(114,33,86)')
)
trace13 = go.Bar(
    x=["Potential", "Current"],
    y=merged["Wood"],
    name='Wood',
    marker = dict(
      color='rgb(71,30,20)')
)


data = [trace1, trace2, trace3, trace4, trace5, trace6, trace7, trace8, trace9, 
        trace10, trace11, trace12, trace13]
layout = go.Layout(
    barmode='stack',
    title=go.layout.Title(
        text='Electricity Generation Potential vs Current'),
    yaxis=go.layout.YAxis(
        title=go.layout.yaxis.Title(
            text='Gigawatt Hours')
    )
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='stacked-bar')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~livjab/22.embed" height="525px" width="100%"></iframe>
