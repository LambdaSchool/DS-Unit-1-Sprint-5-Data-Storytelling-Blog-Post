# %% [markdown]
# <a href="https://colab.research.google.com/github/NikuDubenco/DS-Unit-1-Sprint-5-Data-Storytelling-Blog-Post/blob/master/Nicolae%20Dubenco%20Project_week_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import calendar

# %%
# Upload file from local device 
import io
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-20e44d80-ba6c-4c15-a454-dad13c8e11cc" name="files[]" multiple disabled />
#      <output id="result-20e44d80-ba6c-4c15-a454-dad13c8e11cc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving consensus_daily.csv to consensus_daily.csv
# Saving goog_trend_d.csv to goog_trend_d.csv
# Saving GoogleTrendsHistory-2019-05-20.csv to GoogleTrendsHistory-2019-05-20.csv
# Saving traffic_d.csv to traffic_d.csv
# Saving tweet statistics.csv to tweet statistics.csv
# Saving tweets.csv to tweets.csv
# Saving webtraffic_d.csv to webtraffic_d.csv
# Saving webtrafic monthly.csv to webtrafic monthly.csv
# Saving yahoo fin daily.csv to yahoo fin daily.csv
# Saving yahoo fin.csv to yahoo fin.csv

# %%
consensus = pd.read_csv(io.BytesIO(uploaded['consensus_daily.csv']))
goog_trends = pd.read_csv(io.BytesIO(uploaded['goog_trend_d.csv']))
webtraffic = pd.read_csv(io.BytesIO(uploaded['traffic_d.csv']))
tw_stat = pd.read_csv(io.BytesIO(uploaded['tweet statistics.csv']))
tweets = pd.read_csv(io.BytesIO(uploaded['tweets.csv']))
yahfin = pd.read_csv(io.BytesIO(uploaded['yahoo fin daily.csv']))

# %% [markdown]
# ## Consensus dataset / daily data
#
#
# *  start date 2019-03-01
# *  end date 2019-05-22

# %%
consensus.head(20)
# Out:
#     id  ...               twitter_url
# 0    1  ...  https://twitter.com/ASOS
# 1    2  ...  https://twitter.com/ASOS
# 2    3  ...  https://twitter.com/ASOS
# 3    4  ...  https://twitter.com/ASOS
# 4    5  ...  https://twitter.com/ASOS
# 5    6  ...  https://twitter.com/ASOS
# 6    7  ...  https://twitter.com/ASOS
# 7    8  ...  https://twitter.com/ASOS
# 8    9  ...  https://twitter.com/ASOS
# 9   10  ...  https://twitter.com/ASOS
# 10  11  ...  https://twitter.com/ASOS
# 11  12  ...  https://twitter.com/ASOS
# 12  13  ...  https://twitter.com/ASOS
# 13  14  ...  https://twitter.com/ASOS
# 14  15  ...  https://twitter.com/ASOS
# 15  16  ...  https://twitter.com/ASOS
# 16  17  ...  https://twitter.com/ASOS
# 17  18  ...  https://twitter.com/ASOS
# 18  19  ...  https://twitter.com/ASOS
# 19  20  ...  https://twitter.com/ASOS
#
# [20 rows x 20 columns]

# %%
consensus.tail()
# Out:
#      id  ...               twitter_url
# 75  454  ...  https://twitter.com/ASOS
# 76  468  ...  https://twitter.com/ASOS
# 77  482  ...  https://twitter.com/ASOS
# 78  496  ...  https://twitter.com/ASOS
# 79  510  ...  https://twitter.com/ASOS
#
# [5 rows x 20 columns]

# %%
# Extract only informative columns: date, analysis_high, analysis_low, analysis_mean

consensus = consensus[['date', 'analysis_high', 'analysis_low', 'analysis_mean']]
consensus['date'] = pd.to_datetime(consensus['date']).dt.date
consensus.shape, consensus.head()
# Out:
# ((80, 4),          date  analysis_high  analysis_low  analysis_mean
#  0  2019-03-01     2823000000    2749000000     2787650000
#  1  2019-03-02     2823000000    2749000000     2787650000
#  2  2019-03-03     2823000000    2749000000     2787650000
#  3  2019-03-04     2823000000    2749000000     2787650000
#  4  2019-03-05     2823000000    2749000000     2787650000)

# %% [markdown]
# ## Google trends dataset / monthly data
#
# *  start date 2004-01-01
# *  end date 2019-05-22

# %%
goog_trends.head()
# Out:
#    count              date_trunc  web_search  goods_search  ticker
# 0      1  2004-01-01 00:00:00+00         100             0  ASOS.L
# 1      1  2004-02-01 00:00:00+00           0             0  ASOS.L
# 2      1  2004-03-01 00:00:00+00           0             0  ASOS.L
# 3      1  2004-04-01 00:00:00+00           0             0  ASOS.L
# 4      1  2004-05-01 00:00:00+00           0             0  ASOS.L

# %%
goog_trends.tail()
# Out:
#      count              date_trunc  web_search  goods_search  ticker
# 180      1  2019-01-01 00:00:00+00          50             0  ASOS.L
# 181      1  2019-02-01 00:00:00+00          34             0  ASOS.L
# 182      1  2019-03-01 00:00:00+00          42             0  ASOS.L
# 183      1  2019-04-01 00:00:00+00          41             0  ASOS.L
# 184      1  2019-05-01 00:00:00+00          22             0  ASOS.L

# %%
goog_trends.shape
# Out:
# (185, 5)

# %%
goog_trends = goog_trends[['date_trunc',	'web_search']]
goog_trends['date_trunc'] = pd.to_datetime(goog_trends['date_trunc']).dt.date
goog_trends.head()
# Out:
#    date_trunc  web_search
# 0  2004-01-01         100
# 1  2004-02-01           0
# 2  2004-03-01           0
# 3  2004-04-01           0
# 4  2004-05-01           0

# %% [markdown]
# ## Webtraffic dataset / daily data
#
# *  start date 2019-02-13
# *  end date 2019-04-27

# %%
webtraffic.head()
# Out:
#      id  ...               twitter_url
# 0  2059  ...  https://twitter.com/ASOS
# 1   520  ...  https://twitter.com/ASOS
# 2   519  ...  https://twitter.com/ASOS
# 3   518  ...  https://twitter.com/ASOS
# 4   517  ...  https://twitter.com/ASOS
#
# [5 rows x 13 columns]

# %%
webtraffic.tail()
# Out:
#       id  ...               twitter_url
# 79  3960  ...  https://twitter.com/ASOS
# 80  3980  ...  https://twitter.com/ASOS
# 81  4222  ...  https://twitter.com/ASOS
# 82  4242  ...  https://twitter.com/ASOS
# 83  4263  ...  https://twitter.com/ASOS
#
# [5 rows x 13 columns]

# %%
webtraffic = webtraffic[['date',	'traffic']]
webtraffic['date'] = pd.to_datetime(webtraffic['date']).dt.date
webtraffic.head()
# Out:
#          date  traffic
# 0  2019-02-01    60000
# 1  2019-02-13     3279
# 2  2019-02-14     3180
# 3  2019-02-15     3154
# 4  2019-02-16     3314

# %%
webtraffic.plot('date', 'traffic');

# %%
# Delete the outliers - strange numbers
webtraffic = webtraffic[webtraffic.traffic < 30000]
webtraffic.plot()

# %%
webtraffic.head(2), webtraffic.tail(2)
# Out:
# (         date  traffic
#  1  2019-02-13     3279
#  2  2019-02-14     3180,           date  traffic
#  74  2019-04-26     7131
#  75  2019-04-27     7135)

# %%
webtraffic.rename(columns={'traffic': 'web_traffic'}, inplace=True)

# %%
webtraffic.head(2)
# Out:
#          date  web_traffic
# 1  2019-02-13         3279
# 2  2019-02-14         3180

# %% [markdown]
# ## Tweet statistics trends dataset / daily data
# - start date 2019-04-04
# - end date 2019-05-21

# %%
tw_stat.head(2)
# Out:
#    id  likes  ...                   date_updated               twitter_url
# 0   4  94910  ...  2019-05-15 04:06:01.389601+00  https://twitter.com/ASOS
# 1  10  94979  ...  2019-05-15 04:06:01.389601+00  https://twitter.com/ASOS
#
# [2 rows x 14 columns]

# %%
tw_stat.tail(2)
# Out:
#      id   likes  ...                   date_updated               twitter_url
# 46  680  100991  ...  2019-05-15 04:06:01.389601+00  https://twitter.com/ASOS
# 47  702   93719  ...  2019-05-15 04:06:01.389601+00  https://twitter.com/ASOS
#
# [2 rows x 14 columns]

# %%
tw_stat = tw_stat[['likes',	'retweet',	'count_comments',	'followers',	'count_tweets',	'date']]
tw_stat['date'] = pd.to_datetime(tw_stat['date']).dt.date
tw_stat.head()
# Out:
#    likes  retweet  count_comments  followers  count_tweets        date
# 0  94910    12543            7518    1031394           847  2019-04-04
# 1  94979    12547            7542    1031416           848  2019-04-05
# 2  91579    11746            7384    1031489           796  2019-04-06
# 3  91681    11743            7452    1031466           796  2019-04-07
# 4  91761    11735            7975    1031455           796  2019-04-08

# %%
tw_stat.plot('date', 'likes')

# %%
tw_stat.plot('date', 'retweet')

# %%
tw_stat.plot('date', 'followers')

# %% [markdown]
# ## Tweet dataset / daily data
# - start date 2017-07-18
# - end date 2019-05-20

# %%
tweets.head(2)
# Out:
#     id  ...               twitter_url
# 0  846  ...  https://twitter.com/ASOS
# 1  845  ...  https://twitter.com/ASOS
#
# [2 rows x 15 columns]

# %%
tweets.tail(2)
# Out:
#         id  ...               twitter_url
# 950  18995  ...  https://twitter.com/ASOS
# 951  18994  ...  https://twitter.com/ASOS
#
# [2 rows x 15 columns]

# %%
tweets = tweets[['tweet_id',	'likes',	'retweet',	'count_comments',	'date']]
tweets['date'] = pd.to_datetime(tweets['date']).dt.date
tweets.head()
# Out:
#              tweet_id  likes  retweet  count_comments        date
# 0  887362341884624896     34       11               0  2017-07-18
# 1  887582794649567233     21        4               1  2017-07-19
# 2  887756940855607296     12        2               0  2017-07-19
# 3  888350602073436161     42        9               3  2017-07-21
# 4  888384968430415872    104        8               2  2017-07-21

# %%
# Count num likes, num retweets, num comments per day
tt = tweets[['likes',	'retweet',	'count_comments']].groupby(tweets.date).sum()
tt
# Out:
#             likes  retweet  count_comments
# date
# 2017-07-18     34       11               0
# 2017-07-19     33        6               1
# 2017-07-21    146       17               5
# 2017-07-22    100       14               3
# 2017-07-24    241       41               9
# 2017-07-25    111       28              12
# 2017-07-26     78       16               2
# 2017-07-31     35        7               0
# 2017-08-01     41       10               3
# 2017-08-09     96       10               3
# 2017-08-10    138       14               3
# 2017-08-11    156       25               5
# 2017-08-12     36        7               1
# 2017-08-22     38       11               5
# 2017-09-01     34        7               0
# 2017-09-06    321      102              25
# 2017-09-07     38       14               4
# 2017-09-13     21        5               2
# 2017-09-14     41       12               1
# 2017-09-20     62       15               1
# 2017-09-22    106       17               6
# 2017-09-29     36       10               3
# 2017-10-01     37       20               4
# 2017-10-03     42        8               2
# 2017-10-05    130       26              13
# 2017-10-13     25        8               1
# 2017-10-16     35       31               2
# 2017-10-17     91       10               5
# 2017-10-20    181       17               6
# 2017-10-21     77       10               1
# ...           ...      ...             ...
# 2019-04-19     18        0               7
# 2019-04-20     22        3               0
# 2019-04-21    120        8               9
# 2019-04-23    255      169               5
# 2019-04-24    142        7              32
# 2019-04-25    316       24              45
# 2019-04-26    310       27              15
# 2019-04-27     52        3              25
# 2019-04-28     28        1              10
# 2019-04-29     21        2               9
# 2019-04-30    379       21              75
# 2019-05-01    103        8               6
# 2019-05-02    372       60               6
# 2019-05-03    620       91               9
# 2019-05-04     56        2               4
# 2019-05-05    236        2              64
# 2019-05-06   2549      332              50
# 2019-05-08    309       21              92
# 2019-05-09     80        3               0
# 2019-05-10    227       20              13
# 2019-05-11     21        0              14
# 2019-05-12    130       12              12
# 2019-05-13     96        8              64
# 2019-05-14    321       46              47
# 2019-05-15    383       47              57
# 2019-05-16    156        4               3
# 2019-05-17    358       52              22
# 2019-05-18    120        9              12
# 2019-05-19    844      123              27
# 2019-05-20    258       14               9
#
# [472 rows x 3 columns]

# %%
# Count the numbers of tweet per day
ttt = tweets[['tweet_id']].groupby(tweets.date).count()
ttt
# Out:
#             tweet_id
# date
# 2017-07-18         1
# 2017-07-19         2
# 2017-07-21         2
# 2017-07-22         2
# 2017-07-24         4
# 2017-07-25         3
# 2017-07-26         1
# 2017-07-31         1
# 2017-08-01         1
# 2017-08-09         2
# 2017-08-10         2
# 2017-08-11         3
# 2017-08-12         1
# 2017-08-22         1
# 2017-09-01         1
# 2017-09-06         1
# 2017-09-07         1
# 2017-09-13         1
# 2017-09-14         1
# 2017-09-20         1
# 2017-09-22         1
# 2017-09-29         2
# 2017-10-01         1
# 2017-10-03         2
# 2017-10-05         1
# 2017-10-13         1
# 2017-10-16         1
# 2017-10-17         1
# 2017-10-20         2
# 2017-10-21         1
# ...              ...
# 2019-04-19         1
# 2019-04-20         1
# 2019-04-21         1
# 2019-04-23         2
# 2019-04-24         1
# 2019-04-25         4
# 2019-04-26         3
# 2019-04-27         1
# 2019-04-28         1
# 2019-04-29         1
# 2019-04-30         2
# 2019-05-01         1
# 2019-05-02         1
# 2019-05-03         1
# 2019-05-04         1
# 2019-05-05         1
# 2019-05-06        13
# 2019-05-08         3
# 2019-05-09         1
# 2019-05-10         1
# 2019-05-11         1
# 2019-05-12         1
# 2019-05-13         1
# 2019-05-14         4
# 2019-05-15         4
# 2019-05-16         2
# 2019-05-17         3
# 2019-05-18         1
# 2019-05-19        13
# 2019-05-20         2
#
# [472 rows x 1 columns]

# %%
tweets = ttt.merge(tt, left_index=True, right_index=True)
tweets.head(5)
# Out:
#             tweet_id  likes  retweet  count_comments
# date
# 2017-07-18         1     34       11               0
# 2017-07-19         2     33        6               1
# 2017-07-21         2    146       17               5
# 2017-07-22         2    100       14               3
# 2017-07-24         4    241       41               9

# %%
tweets.rename(columns={'tweet_id': 'twts_p_day', 'likes':'likes_p_day', 
                       'retweets_p_day':'retwts_p_day', 'count_comments':'comments_p_day'}, inplace=True)

# %%
tweets.plot()

# %% [markdown]
# ## Yahoo finance dataset / daily data
# - start date 2016-05-23
# - end date 2019-05-21

# %%
yahfin.head(2)
# Out:
#          Date    Open    High     Low   Close  Adj Close  Volume
# 0  2016-05-23  3483.0  3548.0  3472.0  3491.0     3491.0  532884
# 1  2016-05-24  3477.0  3628.0  3450.0  3623.0     3623.0  408667

# %%
yahfin.tail(2)
# Out:
#            Date    Open    High     Low   Close  Adj Close  Volume
# 756  2019-05-20  3650.0  3650.0  3523.0  3527.0     3527.0  275542
# 757  2019-05-21  3538.0  3584.0  3510.0  3535.0     3535.0  288389

# %%
yahfin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 758 entries, 0 to 757
# Data columns (total 7 columns):
# Date         758 non-null object
# Open         758 non-null float64
# High         758 non-null float64
# Low          758 non-null float64
# Close        758 non-null float64
# Adj Close    758 non-null float64
# Volume       758 non-null int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 41.5+ KB

# %%
yahfin['date'] = pd.to_datetime(yahfin['Date']).dt.date

# %% [markdown]
# #### Consensus dataset / daily data
# - start date -----------------------------------------------------------2019-03-01 - end date 2019-05-22
#
# #### Google trends dataset / monthly data
#
# *  start date 2004-01-01 ------------------------------------------------------- *  end date 2019-05-22
#
# #### Webtraffic dataset / daily data
# - start date -----------------------------------------2019-02-13 ----------- end date 2019-04-27--------
#
# #### Tweet statistics trends dataset / daily data
# - start date -----------------------------------------------------------2019-04-04 - end date 2019-05-21
#
# #### Tweet dataset / daily data
# - start date ---------------------2017-07-18 --------------------------------------- end date 2019-05-20
#
# #### Yahoo finance dataset / daily data
# - start date ------------2016-05-23 ------------------------------------------------ end date 2019-05-21

# %%
tweets['date'] = tweets.index.values
df_outer = yahfin.merge(tweets, left_on='date', right_index=True, how='outer')
df_outer = df_outer.drop(['Date', 'date_x', 'Adj Close'], axis=1)

# %%
df_outer.head()
# Out:
#          date    Open    High  ...  retweet  comments_p_day  date_y
# 0  2016-05-23  3483.0  3548.0  ...      NaN             NaN     NaN
# 1  2016-05-24  3477.0  3628.0  ...      NaN             NaN     NaN
# 2  2016-05-25  3646.0  3653.0  ...      NaN             NaN     NaN
# 3  2016-05-26  3577.0  3655.0  ...      NaN             NaN     NaN
# 4  2016-05-27  3484.0  3538.0  ...      NaN             NaN     NaN
#
# [5 rows x 11 columns]

# %%
df_outer = df_outer.merge(tw_stat, on='date', how='outer')

# %%
df_outer = df_outer.merge(webtraffic, on='date', how='outer')

# %%
plt.subplots(figsize=(15,10))
sns.heatmap(df_outer.corr(), annot=True)

# %%
df_outer.head()
# Out:
#          date    Open    High  ...  followers  count_tweets  web_traffic
# 0  2016-05-23  3483.0  3548.0  ...        NaN           NaN          NaN
# 1  2016-05-24  3477.0  3628.0  ...        NaN           NaN          NaN
# 2  2016-05-25  3646.0  3653.0  ...        NaN           NaN          NaN
# 3  2016-05-26  3577.0  3655.0  ...        NaN           NaN          NaN
# 4  2016-05-27  3484.0  3538.0  ...        NaN           NaN          NaN
#
# [5 rows x 17 columns]

# %%
# Delete the column 'date_y'
# Rename the column 'retweet_x' in 'retwt_p_day'
df_outer.drop('date_y', axis=1).rename(columns={'retweet_x':'retwt_p_day'}).head()
# Out:
#          date    Open    High  ...  followers  count_tweets  web_traffic
# 0  2016-05-23  3483.0  3548.0  ...        NaN           NaN          NaN
# 1  2016-05-24  3477.0  3628.0  ...        NaN           NaN          NaN
# 2  2016-05-25  3646.0  3653.0  ...        NaN           NaN          NaN
# 3  2016-05-26  3577.0  3655.0  ...        NaN           NaN          NaN
# 4  2016-05-27  3484.0  3538.0  ...        NaN           NaN          NaN
#
# [5 rows x 16 columns]

# %%
# DataFrame that contains majority of information, but is very short have only a few days
startdate = pd.to_datetime('2019-04-04').date()
enddate = pd.to_datetime('2019-04-27').date()

df_limited = df_outer[(df_outer['date'] >= startdate) and (df_outer['date'] <=enddate)]
df_limited.shape, df_limited.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-116-7c68064a59c9> in <module>()
#       2 enddate = pd.to_datetime('2019-04-27').date()
#       3
# ----> 4 df_limited = df_outer[(df_outer['date'] >= startdate) and (df_outer['date'] <=enddate)]
#       5 df_limited.shape, df_limited.head()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1476         raise ValueError("The truth value of a {0} is ambiguous. "
#    1477                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1478                          .format(self.__class__.__name__))
#    1479
#    1480     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
