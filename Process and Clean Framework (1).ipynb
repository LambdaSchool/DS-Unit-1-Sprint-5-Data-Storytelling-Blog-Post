# %%
import pandas as pd 
import numpy as np

# %%
testdf = pd.read_excel('Lobby_test_data.xls')

# %%
pd.set_option('display.max_columns', 45)
print ('Column names:')
print ('\n')
print (testdf.columns)
# Out:
# Column names:
#
#
# Index(['ID', 'Year', 'Received', 'Amount', 'Type', 'Period',
#        'TerminationEffectiveDate', 'RegistrationEffectiveDate',
#        'AffiliatedOrgsURL', 'RegistrantID', 'RegistrantName',
#        'GeneralDescription', 'Address', 'RegistrantCountry',
#        'RegistrantPPBCountry', 'ClientName', 'GeneralDescription2', 'ClientID',
#        'SelfFiler', 'ContactFullname', 'IsStateOrLocalGov', 'ClientCountry',
#        'ClientPPBCountry', 'ClientState', 'ClientPPBState', 'LobbyistName',
#        'LobbyistCoveredGovPositionIndicator', 'OfficialPosition',
#        'ActivityInformation', 'GovEntityName', 'Code', 'SpecificIssue',
#        'ForeignEntityName', 'ForeignEntityCountry', 'ForeignEntityPPBcountry',
#        'ForeignEntityContribution', 'ForeignEntityOwnershipPercentage',
#        'ForeignEntityStatus', 'AffiliatedOrgName', 'AffiliatedOrgCountry',
#        'AffiliatedOrgPPBCcountry'],
#       dtype='object')

# %%
testdf.shape
# Out:
# (5735, 41)

# %%
testdf.dtypes
# Out:
# ID                                             object
# Year                                            int64
# Received                                       object
# Amount                                        float64
# Type                                           object
# Period                                         object
# TerminationEffectiveDate               datetime64[ns]
# RegistrationEffectiveDate              datetime64[ns]
# AffiliatedOrgsURL                              object
# RegistrantID                                    int64
# RegistrantName                                 object
# GeneralDescription                             object
# Address                                        object
# RegistrantCountry                              object
# RegistrantPPBCountry                           object
# ClientName                                     object
# GeneralDescription2                            object
# ...

# %%
testdf.head(25)
# Out:
#                                       ID  Year                 Received  \
# 0   4FCDF694-216A-4192-8FE8-371E85A63BEB  2018  2018-07-01T08:34:46.880
# 1   4FCDF694-216A-4192-8FE8-371E85A63BEB  2018  2018-07-01T08:34:46.880
# 2   4FCDF694-216A-4192-8FE8-371E85A63BEB  2018  2018-07-01T08:34:46.880
# 3   2FBCD786-DEF8-4DDF-AA9E-AE24D0475D0D  2018  2018-07-01T09:06:50.320
# 4   2FBCD786-DEF8-4DDF-AA9E-AE24D0475D0D  2018  2018-07-01T09:06:50.320
# 5   2FBCD786-DEF8-4DDF-AA9E-AE24D0475D0D  2018  2018-07-01T09:06:50.320
# 6   2FBCD786-DEF8-4DDF-AA9E-AE24D0475D0D  2018  2018-07-01T09:06:50.320
# 7   99442D99-57F1-415E-A04B-6C39D0F99675  2018  2018-07-01T10:04:52.873
# 8   99442D99-57F1-415E-A04B-6C39D0F99675  2018  2018-07-01T10:04:52.873
# 9   99442D99-57F1-415E-A04B-6C39D0F99675  2018  2018-07-01T10:04:52.873
# 10  99442D99-57F1-415E-A04B-6C39D0F99675  2018  2018-07-01T10:04:52.873
# 11  99442D99-57F1-415E-A04B-6C39D0F99675  2018  2018-07-01T10:04:52.873
# ...

# %%
testdf['Amount'].min()
# This reflects the $5,000 minimum for lobbying expenditure disclosure
# Out:
# 5000.0

# %%
testdf['Code'].nunique()
# There are 79 possible unique lobbying general issue codes
# Out:
# 73

# %%
testdf['ID'].nunique()
# I am going to go ahead and guess that the maximum disclosures per xml file is 1,000
# Out:
# 1000

# %%
df_for_testing = testdf.head(50)

# %%
def test_amt_remapper (df)
    for
# Out:
#                                       ID  Year                 Received  \
# 0   4FCDF694-216A-4192-8FE8-371E85A63BEB  2018  2018-07-01T08:34:46.880
# 1   4FCDF694-216A-4192-8FE8-371E85A63BEB  2018  2018-07-01T08:34:46.880
# 2   4FCDF694-216A-4192-8FE8-371E85A63BEB  2018  2018-07-01T08:34:46.880
# 3   2FBCD786-DEF8-4DDF-AA9E-AE24D0475D0D  2018  2018-07-01T09:06:50.320
# 4   2FBCD786-DEF8-4DDF-AA9E-AE24D0475D0D  2018  2018-07-01T09:06:50.320
# 5   2FBCD786-DEF8-4DDF-AA9E-AE24D0475D0D  2018  2018-07-01T09:06:50.320
# 6   2FBCD786-DEF8-4DDF-AA9E-AE24D0475D0D  2018  2018-07-01T09:06:50.320
# 7   99442D99-57F1-415E-A04B-6C39D0F99675  2018  2018-07-01T10:04:52.873
# 8   99442D99-57F1-415E-A04B-6C39D0F99675  2018  2018-07-01T10:04:52.873
# 9   99442D99-57F1-415E-A04B-6C39D0F99675  2018  2018-07-01T10:04:52.873
# 10  99442D99-57F1-415E-A04B-6C39D0F99675  2018  2018-07-01T10:04:52.873
# 11  99442D99-57F1-415E-A04B-6C39D0F99675  2018  2018-07-01T10:04:52.873
# ...

# %%
for i in
# Out:
# 0     30000.0
# 1     30000.0
# 2     30000.0
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12    20000.0
# 13    20000.0
# 14    20000.0
# 15    20000.0
# 16    20000.0
# 17        NaN
# 18        NaN
# 19        NaN
# 20    20000.0
# 21    20000.0
# 22    20000.0
# 23    20000.0
# 24    20000.0
# 25    20000.0
# 26    20000.0
# 27    18000.0
# 28    18000.0
# 29    18000.0
# Name: Amount, dtype: float64
