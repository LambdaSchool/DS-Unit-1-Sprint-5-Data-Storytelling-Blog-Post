# %%
sqlite_file = '/Users/karthikmahendra/Downloads/billboard-200.db'

# %%
import sqlite3
conn = sqlite3.connect(sqlite_file)
c = conn.cursor()

# %%
c.execute("SELECT * FROM acoustic_features")
data = c.fetchall()

# %%
import pandas as pd
acoustic_data = pd.DataFrame(data)

# %%
acoustic_data.head()
# Out:
#                        0                                   1           2   \
# 0  0Veyvc3n9AcLSoK3r1dA12                   Voices In My Head  Hoodie SZN
# 1  77JzXZonNumWsuXKy9vr3U                              Beasty  Hoodie SZN
# 2  18yllZD0TdF7ykcREib8Z1                            I Did It  Hoodie SZN
# 3  1wJRveJZLSb1rjhnUHQiv6             Swervin (feat. 6ix9ine)  Hoodie SZN
# 4  0jAfdqv18goRTUxm3ilRjb  Startender (feat. Offset and Tyga)  Hoodie SZN
#
#                        3       4      5         6      7         8    9   \
# 0  A Boogie Wit da Hoodie  0.0555  0.754  142301.0  0.663  0.000000  6.0
# 1  A Boogie Wit da Hoodie  0.2920  0.860  152829.0  0.418  0.000000  7.0
# 2  A Boogie Wit da Hoodie  0.1530  0.718  215305.0  0.454  0.000046  8.0
# 3  A Boogie Wit da Hoodie  0.0153  0.581  189487.0  0.662  0.000000  9.0
# 4  A Boogie Wit da Hoodie  0.0235  0.736  192779.0  0.622  0.000000  6.0
#
#       10     11   12     13       14   15     16                      17  \
# ...

# %%
names = list(map(lambda x: x[0], c.description))

# %%
names
# Out:
# ['id',
#  'song',
#  'album',
#  'artist',
#  'acousticness',
#  'danceability',
#  'duration_ms',
#  'energy',
#  'instrumentalness',
#  'key',
#  'liveness',
#  'loudness',
#  'mode',
#  'speechiness',
#  'tempo',
#  'time_signature',
#  'valence',
#  'album_id',
#  'date']

# %%
acoustic_data.columns = names

# %%
acoustic_data.sample (10)
# Out:
#                             id  \
# 205930  1Fi04MpPpqAYTK9H8wAuue
# 251912  4Yy5d21CJvXQ8cOuaTiCRD
# 309383  7KBTwgVeJxYMycdNap3jI7
# 60096   2eqDUxbd0JPEhNrJdPlHLs
# 202859  3UPBvEmEMGvDl77amannLf
# 253546  2p2nE25HHSWYL2MLU6GGSi
# 216903  0WtSransZDYQlEbIj7ewX4
# 199850  63jTFfw28goWhITbN70W64
# 127209  0fzCtVM9D5UEwiLqcY8Ouq
# 48778   7DHPEpcWL0u4i8am5henEG
#
#                                                      song  \
# 205930                                          My Melody
# 251912                                          Why Worry
# 309383  Für ein paar Dollar mehr - Discovered - Sequenz 4
# 60096                                          Adrenalina
# 202859                   What The World Needs Now Is Love
# 253546                                Hollywood Boulevard
# 216903  The Christmas Song (Chestnuts Roasting on an O...
# 199850                           Welcome To The Goodtimes
# 127209                                           Hard Sun
# ...

# %%
c.execute("SELECT * FROM albums")
data = c.fetchall()
billboard_200 = pd.DataFrame(data)

# %%
names = list(map(lambda x: x[0], c.description))
billboard_200.columns = names

# %%
billboard_200.sample(10)
# Out:
#             id        date           artist  \
# 93564    93565  2010-02-06    Kenny Chesney
# 87796    87797  2010-08-28           The xx
# 457632  457633  1975-03-15   Bobbi Humphrey
# 37577    37578  2015-06-20        James Bay
# 541756  541757  1967-02-04  The Association
# 156621  156622  2004-01-17      Rod Stewart
# 265001  265002  1993-08-28       Billy Joel
# 304868  304869  1989-11-04    Dwight Yoakam
# 42621    42622  2014-12-20  Various Artists
# 363927  363928  1984-03-10      Teena Marie
#
#                                                     album rank  length  \
# 93564                                    Greatest Hits II  164    17.0
# 87796                                                  xx  196    11.0
# 457632                                         Satin Doll   32     8.0
# 37577                                  Chaos And The Calm  177    12.0
# 541756                                        Renaissance   60    12.0
# ...
